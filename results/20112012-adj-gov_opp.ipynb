# %% [markdown]
# # View CPT Results for experiment "20112012-adj-gov_opp"

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (10, 7)

# %% [markdown]
# ## Topic word perplexity

# %%
import os

def load_perplexity_results(results_dir):
    perplexity_topic = pd.read_csv(os.path.join(results_dir, 'perplexity_topic.csv'), index_col=0)
    perplexity_opinion = pd.read_csv(os.path.join(results_dir, 'perplexity_opinion.csv'), index_col=0)
    
    return perplexity_topic, perplexity_opinion

# %%
results_dir = '/home/jvdzwaan/data/dilipad/results/20112012/adj/'

# %%
perplexity_topic, perplexity_opinion = load_perplexity_results(results_dir)
perplexity_topic.plot();
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=medium. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
# change intervals if needed
intervals = ['20', '100', '180', '200']

# %%
perplexity_topic[intervals].plot();

# %% [markdown]
# ## Opinion word perplexity

# %%
perplexity_opinion.plot();

# %%
# change intervals if needed
intervals = ['20', '40', '60', '80', '100']

# %%
perplexity_opinion[intervals].plot();

# %% [markdown]
# ## Results for topics and opinions

# %%
# choose optimal number of topics based on perplexity results
nTopics = 100

# %%
# load results
import glob
import os
import re

def load_experiment_results(nTopics, results_dir):

    # document topic matrix (theta)
    theta = pd.read_csv(os.path.join(results_dir, 'theta_{}.csv'.format(nTopics)), index_col=0)

    # phi topic (transposed)
    phi_topic_t = pd.read_csv(os.path.join(results_dir, 'topics_{}.csv'.format(nTopics)), index_col=0, encoding='utf-8')

    # phi opinion (transposed) per perspective
    opinion_files = glob.glob('{}/opinions_*_{}.csv'.format(results_dir, nTopics))
    phis_opinion_t = {}
    for f in opinion_files:
        m = re.match(r'.+opinions_(.+).csv', f)
        name = m.group(1).replace('_{}'.format(nTopics), '')
        phis_opinion_t[name] = pd.read_csv(f, index_col=0, encoding='utf-8')
    return theta, phi_topic_t, phis_opinion_t

# %%
theta, phi_topic_t, phis_opinion_t = load_experiment_results(nTopics, results_dir)

# %% [markdown]
# ### 'Weight' of the most important topic per document
#
# Each topic has a certain weight in the document. We would like to see one (or a few) topics with high weight per document. Below are some basic statistics on the most important topic (highest weight) per document.

# %%
def print_topic_weights(theta):
    a = theta.copy().apply(max, axis=1)
    a.sort(ascending=False)

    print 'Mean weight of most important topic: {} (std: {})'.format(a.mean(), a.std())
    print 'Min and max of most important topic: min: {}, max: {}'.format(a.min(), a.max())
    print 'Median weight of most important topic: ', a.median()

print_topic_weights(theta)
# Out:
# Mean weight of most important topic: 0.223526932487 (std: 0.167017693959)
# Min and max of most important topic: min: 0.01, max: 0.716528361345
# Median weight of most important topic:  0.189742243051

# %% [markdown]
# Line graph of the sorted topic weigths:

# %%
def plot_topic_weights(theta):
    theta.copy().apply(lambda row:sorted(row)[::-1], axis=1).transpose().plot(legend=None);

plot_topic_weights(theta)

# %% [markdown]
# ### Number of topics per document
#
# The number of topics per document is calculated by counting the number of topic with weight above a certain threshold. The numer of topics per document should (roughly) be equivalent to the number of ``pm:topic``s per document (however, at the moment we do not have statistics of this).

# %%
def display_number_of_topics_per_document(theta, threshold=0.05):
    topic_counts = theta.apply(lambda row: np.sum(row > threshold), axis=1)
    print topic_counts.value_counts(sort=False)
    topic_counts.hist(bins=len(topic_counts.value_counts()), figsize=(5,3));

display_number_of_topics_per_document(theta)
# Out:
# 0    247
# 1    369
# 2    420
# 3    268
# 4    108
# 5     29
# 6      9
# 7      1
# dtype: int64

# %% [markdown]
# ### Topics

# %%
def show_topic(t, top=10):
    """Return dataframe containing <top> topic words, weights of topic words and per perspective opinion words and
    weigths of opinion words.
    
    Parameters
        t : str - index of topic number
        top : int - the number of words to store in the dataframe
    
    Returns Pandas DataFrame
    """
    topic = phi_topic_t[t].copy()
    topic.sort(ascending=False)
    topic = topic[0:top]
    df_t = pd.DataFrame(topic)
    df_t.reset_index(level=0, inplace=True)
    df_t.columns = ['topic_{}'.format(t), 'weights_topic_{}'.format(t)]

    dfs = [df_t]

    for p, o in phis_opinion_t.iteritems():
        opinion = o[t].copy()
        opinion.sort(ascending=False)
        opinion = opinion[0:top]
        df_o = pd.DataFrame(opinion)
        df_o.reset_index(level=0, inplace=True)
        df_o.columns = ['opinion_{}_{}'.format(t, p), 'weights_opinion_{}_{}'.format(t, p)]
        dfs.append(df_o)
        
    return pd.concat(dfs, axis=1)

def print_topics(phi_topic_t, phis_opinion_t, nTopics):
    jsd = None
    jsdFile = os.path.join(results_dir, 'jsd_{}.csv'.format(nTopics))
    if os.path.isfile(jsdFile):
        print 'Ordering topics by Jensen-Shannon divergence of the opinions'
        print
        jsd = pd.read_csv(jsdFile, index_col=0)
        r = jsd.sort(['jsd'], ascending=False)
        print 'Min jsd: {}, max jsd: {}'.format(np.min(jsd['jsd']), np.max(jsd['jsd']))
        print 'Average jsd: {} (std: {}), median jsd: {}'.format(np.mean(jsd['jsd']), np.std(jsd['jsd']), np.median(jsd['jsd']))
        print
        loop = r.index
    else:
        print 'Ordering topics by topic number'
        print '(To order topics by Jensen-Shannon divergence of the opinions run the experiment_jsd_opinions script.)'
        print
        loop = range(nTopics)
    for i in loop:
        if not jsd is None:
            print 'JSD:', jsd.at[i, 'jsd']
        pLabels = ['opinion_{}_{}'.format(i, p) for p, o in phis_opinion_t.iteritems()]
        print show_topic(str(i))[['topic_{}'.format(i)] + pLabels]
        print

# %%
print_topics(phi_topic_t, phis_opinion_t, nTopics)
# Out:
# Ordering topics by Jensen-Shannon divergence of the opinions
#
# Min jsd: 0.229841948576, max jsd: 0.417400074589
# Average jsd: 0.342775205184 (std: 0.0416798330972), median jsd: 0.342817992431
#
# JSD: 0.417400074589
#        topic_25 opinion_25_Opposition opinion_25_Government
# 0        advies             feitelijk                   vol
# 1       besluit            allereerst              redelijk
# 2      verschil              tevreden            definitief
# 3        proces             wenselijk           interessant
# 4  verplichting               voldoen             praktisch
# 5         tekst                   gek             volstrekt
# 6       twijfel          gebruikelijk                 reëel
# 7         state                 vroeg           enthousiast
# 8      voordeel           interessant              prachtig
# 9       periode                  fout             voorlopig
#
# [10 rows x 3 columns]
#
# JSD: 0.416756626285
#              topic_44 opinion_44_Opposition opinion_44_Government
# 0            defensie            veelzijdig           gezamenlijk
# 1        samenwerking              illegaal                 links
# 2                   f                online           structureel
# 3         krijgsmacht                intern               continu
# 4  kansspelautoriteit                divers                modern
# 5         organisatie           zelfstandig             jaarlijks
# 6             toestel                 turks          buitengewoon
# 7            kansspel             inzetbaar          operationeel
# 8          vervanging             objectief             technisch
# 9       reorganisatie             technisch                civiel
#
# [10 rows x 3 columns]
#
# JSD: 0.414550125506
#        topic_28 opinion_28_Opposition opinion_28_Government
# 0   cda-fractie             blijkbaar            allereerst
# 1   vvd-fractie             eindelijk             volstrekt
# 2    buitenland               kwalijk             eindelijk
# 3       gebruik              goedkoop           persoonlijk
# 4        betoog              langzaam                recent
# 5          idee                  leuk            sympathiek
# 6  uitgangspunt                   oké                strikt
# 7   pvv-fractie                 recht               normaal
# 8    betrekking           procedureel           realistisch
# 9          hart            ontzettend                 dicht
#
# [10 rows x 3 columns]
#
# JSD: 0.41306218765
#       topic_53 opinion_53_Opposition opinion_53_Government
# 0        visie               normaal           beschikbaar
# 1      verhaal          fundamenteel            uitstekend
# 2         huis           voortdurend                  duur
# 3         idee          nadrukkelijk                 vroeg
# 4      terrein                volgen                  half
# 5       betoog            essentieel              aanwezig
# 6         hoop             kwetsbaar         desbetreffend
# 7    opvatting                stevig                bewust
# 8  beschouwing     toekomstbestendig              pijnlijk
# 9        begin                divers             gemiddeld
#
# [10 rows x 3 columns]
#
# JSD: 0.408455334632
#       topic_32 opinion_32_Opposition opinion_32_Government
# 0         euro          democratisch                grieks
# 1       schuld              centraal                   gek
# 2   vertrouwen             werkelijk             permanent
# 3      sanctie                  zwak         onverantwoord
# 4  bevoegdheid                   vol                stevig
# 5    bevolking           automatisch                  waar
# 6        regel                  diep               normaal
# 7        inzet              failliet           automatisch
# 8         munt                 vroeg            hoofdelijk
# 9      miljard              langzaam          onmiddellijk
#
# [10 rows x 3 columns]
#
# JSD: 0.405022000448
#        topic_45 opinion_45_Opposition opinion_45_Government
# 0          auto             landelijk           buitenlands
# 1       gegeven          elektronisch               publiek
# 2       dossier               publiek             technisch
# 3        omroep       onderwijskundig           automatisch
# 4  uitwisseling              digitaal             zogenaamd
# 5        hoogte             regionaal                bewust
# 6  wereldomroep            decentraal              identiek
# 7   versobering              maximaal             voormalig
# 8      kenteken         professioneel             mondeling
# 9        gevaar           commercieel              centraal
#
# [10 rows x 3 columns]
#
# JSD: 0.400920986765
#                topic_12 opinion_12_Opposition opinion_12_Government
# 0         regeerakkoord                 waard            ontzettend
# 1              rekening             werkelijk              liberaal
# 2                budget              pijnlijk           interessant
# 3                cijfer                  rijk             eindeloos
# 4             begroting                 exact             eindelijk
# 5        tegenbegroting              redelijk             kwetsbaar
# 6                 leven                 klaar           beschikbaar
# 7                wereld                  bang              pijnlijk
# 8  verkiezingsprogramma                 links              volkomen
# 9               kritiek           afhankelijk                 trots
#
# [10 rows x 3 columns]
#
# JSD: 0.39656359359
#       topic_96 opinion_96_Opposition opinion_96_Government
# 0  mensenrecht                welkom           indonesisch
# 1      verdrag          rechtstreeks              speciaal
# 2       comité                britse           buitenlands
# 3       klacht           rechterlijk          democratisch
# 4          hof          fundamenteel            bilateraal
# 5         unie           structureel             jaarlijks
# 6   toetreding          democratisch             religieus
# 7      dialoog                recent                actief
# 8       margin                 turks            historisch
# 9      verband           automatisch                moreel
#
# [10 rows x 3 columns]
#
# JSD: 0.394778605805
#        topic_58 opinion_58_Opposition opinion_58_Government
# 0    instrument             werkelijk               primair
# 1          doel            ontzettend               zodanig
# 2        middel              cruciaal                scherp
# 3         regel                scherp              duurzaam
# 4        ruimte            onmogelijk                nuttig
# 5      richting             volstrekt           zelfstandig
# 6       gebruik           gemakkelijk         aantrekkelijk
# 7   organisatie              goedkoop                 reëel
# 8  doelstelling                  slim                bewust
# 9      praktijk               onnodig           onvoldoende
#
# [10 rows x 3 columns]
#
# JSD: 0.394507468038
#        topic_69 opinion_69_Opposition opinion_69_Government
# 0   begeleiding      persoonsgebonden             langdurig
# 1          awbz            palliatief             landelijk
# 2        cliënt            kortdurend        verpleegkundig
# 3           pgb         huishoudelijk           gehandicapt
# 4        budget             integraal           beschikbaar
# 5  mantelzorger         verstandelijk           persoonlijk
# 6    verzorging          gemeentelijk            ontzettend
# 7  overheveling             landelijk                actief
# 8         regie               complex             afgelopen
# 9     indicatie         psychiatrisch              regelarm
#
# [10 rows x 3 columns]
#
# JSD: 0.393643119852
#       topic_49 opinion_49_Opposition opinion_49_Government
# 0        prijs             efficiënt              duurzaam
# 1        markt              redelijk              redelijk
# 2      systeem              mondiaal           commercieel
# 3      energie             gemiddeld              mondiaal
# 4       tarief                scherp                  slim
# 5         lijn             jaarlijks             efficiënt
# 6    consument               zodanig            decentraal
# 7    aanbieder          aanmerkelijk                 groen
# 8  marktpartij            consistent                gratis
# 9      product             zogenoemd        administratief
#
# [10 rows x 3 columns]
#
# JSD: 0.392125517776
#      topic_15 opinion_15_Opposition opinion_15_Government
# 0    argument           ingewikkeld           ingewikkeld
# 1        lijn                  waar               voldoen
# 2     oordeel             makkelijk                divers
# 3        slag              maximaal              destijds
# 4  voorwaarde                  bang                nuttig
# 5     systeem             eenvoudig                   gek
# 6       tafel             blijkbaar           principieel
# 7       licht           afhankelijk              tevreden
# 8   suggestie            behoorlijk               logisch
# 9  sp-fractie                simpel           onwenselijk
#
# [10 rows x 3 columns]
#
# JSD: 0.392102916131
#       topic_98 opinion_98_Opposition opinion_98_Government
# 0   bestuurder           beschikbaar               publiek
# 1      bestuur            letterlijk           bestuurlijk
# 2          roc             volstrekt                  bang
# 3    personeel                 flink            ontzettend
# 4    wanbeleid              aanwezig                actief
# 5       gebouw              failliet                 klaar
# 6      signaal       vanzelfsprekend           interessant
# 7  huisvesting                   gek           fatsoenlijk
# 8    directeur           zelfstandig           voortdurend
# 9      functie             voormalig                  saai
#
# [10 rows x 3 columns]
#
# JSD: 0.390524544488
#            topic_52 opinion_52_Opposition opinion_52_Government
# 0           student              maximaal             landelijk
# 1         opleiding                streng            voortijdig
# 2        instelling             onterecht             eenduidig
# 3           diploma             technisch             onterecht
# 4            docent           interessant               pervers
# 5            studie              negatief            preventief
# 6               hbo             surinaams               primair
# 7       leenstelsel               primair                   gek
# 8        hogeschool                 klaar          onmiddellijk
# 9  langstudeerboete             selectief               bevoegd
#
# [10 rows x 3 columns]
#
# JSD: 0.390173063969
#           topic_38 opinion_38_Opposition opinion_38_Government
# 0  dienstverlening              digitaal              digitaal
# 1    ondersteuning              werkloos             afgelopen
# 2          systeem           werkzoekend           onvoldoende
# 3           cijfer             langdurig             volstrekt
# 4          contact           beschikbaar             diezelfde
# 5          afstand           persoonlijk          laagopgeleid
# 6           middel             regionaal             hartelijk
# 7             doel             kwetsbaar           onwenselijk
# 8       bewindsman               publiek                    na
# 9         internet             succesvol                 dicht
#
# [10 rows x 3 columns]
#
# JSD: 0.388821004934
#            topic_66 opinion_66_Opposition opinion_66_Government
# 0             boete               logisch         energiezuinig
# 1            woning               zodanig           automatisch
# 2             label             gemiddeld             eenvoudig
# 3         richtlijn                  raar            onmogelijk
# 4      energielabel             feitelijk               onnodig
# 5      verplichting                   net            ontzettend
# 6           sanctie                simpel           beschikbaar
# 7             koper             eenvoudig                handig
# 8  energiebesparing            symbolisch           bestuurlijk
# 9            gebouw               normaal         bouwtechnisch
#
# [10 rows x 3 columns]
#
# JSD: 0.387885376877
#               topic_10 opinion_10_Opposition  opinion_10_Government
# 0                gezin          kindgebonden                 veilig
# 1                ouder                  fors                   waar
# 2         kinderopvang   inkomensafhankelijk               redelijk
# 3                vrouw           zelfstandig                  jarig
# 4               budget              liberaal                 tijdig
# 5        kinderbijslag               keihard               pijnlijk
# 6              armoede             volwassen           kindgebonden
# 7          voedselbank           onwenselijk              werkelijk
# 8  kinderopvangtoeslag           beschikbaar  inkomensonafhankelijk
# 9               moeder               dakloos           verdedigbaar
#
# [10 rows x 3 columns]
#
# JSD: 0.386733835391
#            topic_31 opinion_31_Opposition opinion_31_Government
# 0             dwang           rechterlijk               jeugdig
# 1        instelling         psychiatrisch           particulier
# 2          praktijk         verstandelijk         verstandelijk
# 3        gevangenis             psychisch           structureel
# 4             toets             strafbaar           rechterlijk
# 5               ggz          onvrijwillig            justitieel
# 6           patiënt            justitieel             vreselijk
# 7  dwangbehandeling              regulier             volwassen
# 8         personeel    vrijheidsbeperkend             deskundig
# 9            cliënt               verward              relevant
#
# [10 rows x 3 columns]
#
# JSD: 0.384454261024
#           topic_48 opinion_48_Opposition opinion_48_Government
# 0            regio            zorgvuldig            zorgvuldig
# 1  belastingdienst              redelijk                 duits
# 2        provincie                  vals          buitengewoon
# 3          kantoor                  fijn              aanwezig
# 4           gebied                  zwak                 dicht
# 5       medewerker                  raak                intern
# 6          besluit            definitief            uitstekend
# 7          afstand                aardig               normaal
# 8     taakstelling             evenredig              optimaal
# 9         sluiting           fantastisch                fysiek
#
# [10 rows x 3 columns]
#
# JSD: 0.383374454989
#             topic_30 opinion_30_Opposition opinion_30_Government
# 0             eiland            caraïbisch                 duits
# 1         koninkrijk           staatkundig             voormalig
# 2         informatie             caribisch              autonoom
# 3            bestuur                extern            ruimtelijk
# 4       bes-eilanden               geboren               correct
# 5          begroting              autonoom           jongstleden
# 6          bevolking                bewust           beschikbaar
# 7  rijksministerraad              duurzaam           voortvarend
# 8  veiligheidsdienst          fundamenteel          onmiddellijk
# 9         verhouding               dubieus               voldoen
#
# [10 rows x 3 columns]
#
# JSD: 0.381971750178
#          topic_0 opinion_0_Opposition opinion_0_Government
# 0     immigratie               humaan                links
# 1     integratie               dubbel         niet-westers
# 2      resultaat               streng           marokkaans
# 3           stad               actief                  vol
# 4    pvv-fractie          realistisch             speciaal
# 5  gedoogakkoord         niet-westers              kansarm
# 6          grens            makkelijk              extreem
# 7           wijk                  gek            blijkbaar
# 8        migrant                 bang               humaan
# 9    vluchteling         substantieel            crimineel
#
# [10 rows x 3 columns]
#
# JSD: 0.38176868569
#           topic_57 opinion_57_Opposition opinion_57_Government
# 0             baan           beschikbaar              regulier
# 1      minimumloon             tijdelijk             tijdelijk
# 2         vermogen           gehandicapt             integraal
# 3        werkgever                  rijk              centraal
# 4          armoede             werkelijk           beschikbaar
# 5       werkplaats                   arm                actief
# 6        beperking           afhankelijk               normaal
# 7        uitkering              geweldig           nauwlettend
# 8  loondispensatie            ontzettend             succesvol
# 9      begeleiding             gemiddeld     arbeidsongeschikt
#
# [10 rows x 3 columns]
#
# JSD: 0.379823071957
#          topic_8 opinion_8_Opposition opinion_8_Government
# 0         bedrag          transparant          transparant
# 1  transparantie            technisch              oprecht
# 2           gift              publiek          principieel
# 3       kiesraad            landelijk         buitengewoon
# 4       subsidie            ongewenst         terughoudend
# 5     identiteit                reëel             compleet
# 6       politiek            regionaal                 warm
# 7        invloed                 bang       administratief
# 8          regel             maximaal            blijkbaar
# 9          grens       administratief                waard
#
# [10 rows x 3 columns]
#
# JSD: 0.378959405828
#          topic_40 opinion_40_Opposition opinion_40_Government
# 0      veiligheid                veilig                veilig
# 1         politie                streng               keihard
# 2           agent           beschikbaar           structureel
# 3        Justitie              digitaal           gemakkelijk
# 4  bewindspersoon             zogenaamd                 turks
# 5         pakkans                   mis              tevreden
# 6          straat               voldoen           bestuurlijk
# 7            wijk      wetenschappelijk             jaarlijks
# 8           inzet                  duur                scherp
# 9         privacy              onveilig              aanwezig
#
# [10 rows x 3 columns]
#
# JSD: 0.378945895743
#           topic_29 opinion_29_Opposition opinion_29_Government
# 0             stad               publiek               privaat
# 1          vervoer            decentraal           interessant
# 2     aanbesteding                intern             efficiënt
# 3         reiziger            onderhands              destijds
# 4         indiener               complex             volstrekt
# 5              bus             regionaal                 links
# 6      aanbesteden              liberaal                  waar
# 7       stadsregio               privaat              constant
# 8             tram           commercieel           automatisch
# 9  initiatiefnemer             efficiënt              liberaal
#
# [10 rows x 3 columns]
#
# JSD: 0.377394839429
#       topic_62 opinion_62_Opposition opinion_62_Government
# 0      artikel             expliciet          democratisch
# 1     grondwet              relevant          fundamenteel
# 2      werking                   vol               zodanig
# 3    wijziging               primair               unaniem
# 4     bepaling          rechtstreeks             werkelijk
# 5      positie             jaarlijks              destijds
# 6     noodzaak                recent             expliciet
# 7    standpunt             wezenlijk               onnodig
# 8  voorstander         uitdrukkelijk          rechtstreeks
# 9     beginsel               zodanig                intern
#
# [10 rows x 3 columns]
#
# JSD: 0.375508178735
#        topic_18 opinion_18_Opposition opinion_18_Government
# 0  ontwikkeling           beschikbaar                actief
# 1       inzicht        administratief               normaal
# 2        middel                 vroeg                 apart
# 3       systeem           ingewikkeld                stevig
# 4    informatie             momenteel               voldoen
# 5       verband              aanwezig             deskundig
# 6        gebied              minimaal                simpel
# 7       verhaal                scherp           ingewikkeld
# 8         leven           principieel               zodanig
# 9   voorstander                bewust            uitbreiden
#
# [10 rows x 3 columns]
#
# JSD: 0.375114664807
#         topic_92 opinion_92_Opposition opinion_92_Government
# 0        premier            koninklijk            koninklijk
# 1          state            zorgvuldig                  duur
# 2      procedure               publiek      staatsrechtelijk
# 3      benoeming              generiek                  rood
# 4       koningin           ceremonieel        institutioneel
# 5         koning          ministerieel             expliciet
# 6      begroting       constitutioneel           automatisch
# 7  vicepresident              destijds              regulier
# 8        functie              liberaal             hypocriet
# 9           huis                geheim               analoog
#
# [10 rows x 3 columns]
#
# JSD: 0.374007326298
#       topic_19 opinion_19_Opposition opinion_19_Government
# 0         taak                actief                   vol
# 1  organisatie           uitsluitend           voorliggend
# 2      college          nadrukkelijk              optimaal
# 3    instituut                nuttig                dubbel
# 4       advies                overig          democratisch
# 5     controle        institutioneel               onnodig
# 6    instantie                intern            vrijwillig
# 7    evaluatie             zichtbaar           onevenredig
# 8      terrein           interessant           persoonlijk
# 9   grondrecht              optimaal             overbodig
#
# [10 rows x 3 columns]
#
# JSD: 0.372331124493
#        topic_79 opinion_79_Opposition opinion_79_Government
# 0        effect                 reëel                  fors
# 1    percentage             werkelijk             jaarlijks
# 2  onderbouwing              negatief              tevreden
# 3        omvang                  fijn            behoorlijk
# 4           weg                    na             zogenaamd
# 5     resultaat            allereerst              aanwezig
# 6      uitkomst                recent                  slim
# 7        hoogte                  bang              negatief
# 8       verband              haalbaar               extreem
# 9    sp-fractie           onvoldoende             nauwgezet
#
# [10 rows x 3 columns]
#
# JSD: 0.372220599395
#           topic_59 opinion_59_Opposition opinion_59_Government
# 0       toezegging                  fors          nadrukkelijk
# 1           cijfer              relevant              tevreden
# 2       experiment              creatief          beleidsmatig
# 3      tegenvaller           onwenselijk               conform
# 4        begroting             selectief            allereerst
# 5  begrotingsregel            uitbreiden                rustig
# 6        meevaller            plotseling           gezamenlijk
# 7             dank             makkelijk          eerstvolgend
# 8       informatie           interessant                  bang
# 9         voorjaar                 mager             overbodig
#
# [10 rows x 3 columns]
#
# JSD: 0.371178741572
#           topic_46 opinion_46_Opposition opinion_46_Government
# 0           gebied             permanent             landelijk
# 1        wijziging                dubbel               complex
# 2          project             tijdelijk             permanent
# 3       herstelwet             intensief             zogenaamd
# 4  bestemmingsplan            zorgvuldig              flexibel
# 5             nota           significant               globaal
# 6           natuur               bevoegd                  dood
# 7      beoordeling              gevoelig             overbodig
# 8      veehouderij             landelijk               oprecht
# 9           effect               globaal           ingewikkeld
#
# [10 rows x 3 columns]
#
# JSD: 0.369566175373
#                 topic_2 opinion_2_Opposition opinion_2_Government
# 0               premier          structureel         nadrukkelijk
# 1              economie                groen                 zwak
# 2            hervorming            eindelijk          structureel
# 3                 groei     persoonsgebonden                links
# 4                  baan            kwetsbaar               somber
# 5                schuld         buitengewoon      vanzelfsprekend
# 6           woningmarkt             liberaal               solide
# 7       werkgelegenheid                 fors              onzeker
# 8  hypotheekrenteaftrek             duurzaam             failliet
# 9    overheidsfinanciën                kapot          ideologisch
#
# [10 rows x 3 columns]
#
# JSD: 0.367628594622
#       topic_70 opinion_70_Opposition opinion_70_Government
# 0      project                stevig             zogenaamd
# 1  investering               voldoen           fantastisch
# 2       kennis              duurzaam                 klaar
# 3        inzet              prachtig              centraal
# 4       middel              aanwezig                  fijn
# 5      ambitie                 klaar              prachtig
# 6        winst                actief             regionaal
# 7   ministerie                 groen                  waar
# 8    begroting                  waar               privaat
# 9     subsidie             overbodig           interessant
#
# [10 rows x 3 columns]
#
# JSD: 0.36742959609
#          topic_73 opinion_73_Opposition opinion_73_Government
# 0      informatie          nadrukkelijk             feitelijk
# 1   duidelijkheid              cruciaal               normaal
# 2          ruimte            definitief            allereerst
# 3         gesprek          buitengewoon                  enig
# 4         oordeel               formeel             volstrekt
# 5        behoefte            essentieel          buitengewoon
# 6             weg              negatief               voldoen
# 7         bezwaar               logisch           aanzienlijk
# 8          inhoud           onduidelijk             langdurig
# 9  onderhandeling             volstrekt                 exact
#
# [10 rows x 3 columns]
#
# JSD: 0.363555591002
#                topic_87 opinion_87_Opposition opinion_87_Government
# 0            verkiezing           ingewikkeld                  leuk
# 1           meerderheid              pijnlijk                gezond
# 2          lenteakkoord          demissionair              goedkoop
# 3  verkiezingsprogramma          onverstandig             tijdelijk
# 4                 tafel               akkoord                vreemd
# 5               akkoord            budgettair                 vroeg
# 6     overgangsregeling               prettig           gemakkelijk
# 7             standpunt                simpel                 kwijt
# 8         kunduzakkoord             eindelijk           gezamenlijk
# 9               gebruik           interessant                simpel
#
# [10 rows x 3 columns]
#
# JSD: 0.35902455643
#       topic_34 opinion_34_Opposition opinion_34_Government
# 0      rechter           rechterlijk                 licht
# 1    taakstraf                 licht                 deels
# 2     wetgever          begrijpelijk             deskundig
# 3  rechtspraak      onvoorwaardelijk                bewust
# 4  rechtsstaat          buitengewoon                 recht
# 5       beroep      wetenschappelijk             somalisch
# 6    bedoeling           principieel           rechterlijk
# 7        macht             deskundig              ongelijk
# 8   toepassing                  kaal              geschikt
# 9    conclusie            onmogelijk                  gauw
#
# [10 rows x 3 columns]
#
# JSD: 0.356731101541
#       topic_16 opinion_16_Opposition opinion_16_Government
# 0    uitkering           principieel               privaat
# 1      partner                tijdig          kindgebonden
# 2    zekerheid              relatief              negatief
# 3  voorziening             integraal  uitkeringsgerechtigd
# 4   aanpassing                 reëel              eenmalig
# 5          gat                  half         desbetreffend
# 6          cao            budgettair             uitvoerig
# 7      stelsel                  fors           particulier
# 8        datum           structureel           afhankelijk
# 9      uitstel           interessant            collectief
#
# [10 rows x 3 columns]
#
# JSD: 0.352827017502
#     topic_61 opinion_61_Opposition opinion_61_Government
# 0  conclusie               voorbij             makkelijk
# 1     betoog             feitelijk                scherp
# 2  standpunt                bewust                 waard
# 3       huis            ontzettend                 flink
# 4   principe               logisch              minimaal
# 5     tekort          fundamenteel          ongelooflijk
# 6     indruk             blijkbaar                stevig
# 7       druk             jarenlang                aardig
# 8       maat             makkelijk            ontzettend
# 9   stelling            allereerst          rechtstreeks
#
# [10 rows x 3 columns]
#
# JSD: 0.35189109147
#       topic_11 opinion_11_Opposition opinion_11_Government
# 0         taal            vrijwillig               privaat
# 1  inburgering                 turks            allochtoon
# 2       examen             volwassen            allereerst
# 3       schuld                actief              goedkoop
# 4      migrant               voldoen              redelijk
# 5   integratie               kansarm                   gek
# 6       niveau                vreemd            vrijwillig
# 7  leenstelsel             succesvol             gemiddeld
# 8       cursus  inburgeringsplichtig               westers
# 9  inburgeraar              centraal              centraal
#
# [10 rows x 3 columns]
#
# JSD: 0.351250778684
#                 topic_55 opinion_55_Opposition opinion_55_Government
# 0               bijstand          meerderjarig          niet-westers
# 1              uitkering   bijstandsgerechtigd          meerderjarig
# 2                 fraude           zelfstandig               keihard
# 3     bijstandsuitkering          alleenstaand            ontzettend
# 4              zekerheid            beslagvrij            beslagvrij
# 5               vermogen           afhankelijk              redelijk
# 6                   huis          gemeentelijk            allochtoon
# 7                vangnet              werkloos            moedwillig
# 8  huishoudinkomenstoets                streng              centraal
# 9                   slag           verwijtbaar         herhaaldelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.350440416563
#         topic_76 opinion_76_Opposition opinion_76_Government
# 0          markt               extreem                mobiel
# 1      consument                mobiel              maximaal
# 2   concurrentie            collectief           beschikbaar
# 3  duidelijkheid             oneerlijk             blijkbaar
# 4     vertraging              hopelijk             onbeperkt
# 5       stemming                streng            volwaardig
# 6        veiling          slechthorend            hoofdelijk
# 7      aanbieder             jarenlang                  bang
# 8     nieuwkomer                  doof              geschikt
# 9     frequentie           gezamenlijk         onomstotelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.350395069971
#           topic_75 opinion_75_Opposition opinion_75_Government
# 0           pakket                grieks                grieks
# 1              top              houdbaar              zwitsers
# 2        noodfonds                stevig              houdbaar
# 3          akkoord               akkoord              failliet
# 4  eurocommissaris               privaat                  zwak
# 5            markt                streng                  diep
# 6       referendum           afhankelijk                  druk
# 7            inzet                 groen             blijkbaar
# 8       voorwaarde                  fors                stevig
# 9    faillissement              cruciaal             aanstaand
#
# [10 rows x 3 columns]
#
# JSD: 0.350160626868
#        topic_13 opinion_13_Opposition opinion_13_Government
# 0          boek      wetenschappelijk      wetenschappelijk
# 1     evaluatie              digitaal               onnodig
# 2   boekenprijs            btw-tarief                  duur
# 3         markt              destijds             pluriform
# 4    boekhandel           interessant             gemiddeld
# 5         prijs                papier          optimistisch
# 6        aanbod       cultuurpolitiek                gezond
# 7  ontwikkeling                divers                  rijk
# 8      uitgever               publiek             wezenlijk
# 9         titel                zinvol         vergelijkbaar
#
# [10 rows x 3 columns]
#
# JSD: 0.350023295588
#      topic_74 opinion_74_Opposition opinion_74_Government
# 0      bedrag           beschikbaar          nadrukkelijk
# 1      niveau                divers              maximaal
# 2     periode              maximaal           structureel
# 3     dekking                bewust           interessant
# 4       stand             wenselijk             eenvoudig
# 5     signaal          substantieel             feitelijk
# 6  verhouding                   vol              relatief
# 7   verlaging           onwenselijk               prettig
# 8       licht                  duur                 kwijt
# 9   bedoeling                 klaar                  enig
#
# [10 rows x 3 columns]
#
# JSD: 0.349756401107
#           topic_67 opinion_67_Opposition opinion_67_Government
# 0         economie              duurzaam                streng
# 1           aanpak                schoon                schoon
# 2           gebied        gebiedsgericht               bevoegd
# 3             norm                  half              negatief
# 4          energie                  duur           voortdurend
# 5           ruimte   grensoverschrijdend               voorbij
# 6         principe               fossiel                  duur
# 7       vervuiling             inclusief        gebiedsgericht
# 8        grondstof               voldoen                veilig
# 9  verontreiniging               logisch              centraal
#
# [10 rows x 3 columns]
#
# JSD: 0.348477725936
#         topic_88 opinion_88_Opposition opinion_88_Government
# 0       toezicht             gemiddeld                  zwak
# 1      inspectie                  zwak                   mis
# 2    bekostiging               publiek            preventief
# 3     instelling          onmiddellijk              liberaal
# 4     vertrouwen             zichtbaar              cruciaal
# 5      stichting              destijds           islamitisch
# 6        bestuur             jaarlijks                  fout
# 7            eis               bevoegd               bevoegd
# 8        artikel            limitatief         desbetreffend
# 9  schoolbestuur         professioneel          onmiddellijk
#
# [10 rows x 3 columns]
#
# JSD: 0.344348852779
#        topic_97 opinion_97_Opposition opinion_97_Government
# 0     verhoging                  ziek                 kwijt
# 1        premie           structureel           beheersbaar
# 2       systeem              solidair               akkoord
# 3      stijging   inkomensafhankelijk              houdbaar
# 4     evaluatie                  bang           automatisch
# 5   compensatie                 kwijt           alternatief
# 6     begroting            collectief             chronisch
# 7       miljoen            betaalbaar         socialistisch
# 8       stelsel                  fors                  fors
# 9  solidariteit             regionaal              solidair
#
# [10 rows x 3 columns]
#
# JSD: 0.344025763575
#      topic_50 opinion_50_Opposition opinion_50_Government
# 0     positie                scherp                  waar
# 1    richting           gemakkelijk          buitengewoon
# 2      gevoel                actief                vreemd
# 3    verschil                  raar                  leuk
# 4        idee            letterlijk            essentieel
# 5  vertrouwen           interessant             efficiënt
# 6        hart             werkelijk               voorbij
# 7        rest                  waar              prachtig
# 8    verleden           persoonlijk                bewust
# 9         man                lekker              geweldig
#
# [10 rows x 3 columns]
#
# JSD: 0.34340193912
#           topic_83 opinion_83_Opposition opinion_83_Government
# 0            spoor                veilig            gevaarlijk
# 1               km            gevaarlijk                veilig
# 2          vervoer              omwonend               onnodig
# 3            trein                  slim                   gek
# 4              weg           beschikbaar            ruimtelijk
# 5        onderhoud                 groen                  rood
# 6   luchtkwaliteit             gemiddeld                 uniek
# 7       veiligheid             efficiënt           automatisch
# 8  maximumsnelheid            ruimtelijk            consequent
# 9             stad           ingewikkeld                mobiel
#
# [10 rows x 3 columns]
#
# JSD: 0.342234045741
#     topic_95 opinion_95_Opposition opinion_95_Government
# 0      fonds                grieks                streng
# 1  begroting           structureel              centraal
# 2   garantie      macro-economisch                 duits
# 3  parlement           onduidelijk      macro-economisch
# 4  noodfonds                heilig             anderhalf
# 5     lening              failliet               stabiel
# 6     bedrag         geloofwaardig         zuid-europees
# 7       euro             anderhalf                blanco
# 8     schuld            suppletoir             uitvoerig
# 9    uitgaaf          onverstandig                 klaar
#
# [10 rows x 3 columns]
#
# JSD: 0.342199647118
#                topic_22 opinion_22_Opposition opinion_22_Government
# 0                   aow              flexibel             gemiddeld
# 1           aowleeftijd             gemiddeld          buitengewoon
# 2       pensioenakkoord           geleidelijk     arbeidsongeschikt
# 3             verhoging            zorgvuldig              maximaal
# 4              pensioen               fiscaal     toekomstbestendig
# 5              leeftijd                 jarig              werkloos
# 6               partner    pensioengerechtigd          begrijpelijk
# 7               akkoord                gezond                 jarig
# 8  verkiezingsprogramma            budgettair          betrekkelijk
# 9     levensverwachting          buitengewoon          fundamenteel
#
# [10 rows x 3 columns]
#
# JSD: 0.342136921664
#           topic_93 opinion_93_Opposition opinion_93_Government
# 0         veteraan              militair              militair
# 1         militair            geestelijk             tijdelijk
# 2           missie                actief             langdurig
# 3         indiener          substantieel                gewond
# 4  initiatiefnemer                divers         vergelijkbaar
# 5         defensie                 apart            gevaarlijk
# 6        erkenning             menselijk                 apart
# 7        ombudsman              aanwezig          operationeel
# 8        definitie              centraal                actief
# 9       uitzending            gevaarlijk            ruimhartig
#
# [10 rows x 3 columns]
#
# JSD: 0.338243976124
#        topic_78 opinion_78_Opposition opinion_78_Government
# 0     wetgeving            zorgvuldig           ingewikkeld
# 1     criterium             uitvoerig            zorgvuldig
# 2         grond             wenselijk               formeel
# 3       bezwaar                    na              aanwezig
# 4      praktijk           afhankelijk               uiterst
# 5      afweging              redelijk              adequaat
# 6  uitzondering          fundamenteel             wenselijk
# 7      argument          buitengewoon                simpel
# 8  uitgangspunt           voorliggend             eenduidig
# 9     definitie               formeel            uitbreiden
#
# [10 rows x 3 columns]
#
# JSD: 0.33806971706
#           topic_65 opinion_65_Opposition opinion_65_Government
# 0       kunstenaar           zelfstandig               privaat
# 1          cultuur             succesvol           zelfstandig
# 2       ondernemer             cultureel             technisch
# 3            kunst                 apart             cultureel
# 4  ondernemerschap          fundamenteel             regionaal
# 5       instelling            zorgvuldig            innovatief
# 6           succes              creatief                 apart
# 7     beroepsgroep           principieel                extern
# 8   overgangsrecht              destijds              generiek
# 9        stichting             praktisch             succesvol
#
# [10 rows x 3 columns]
#
# JSD: 0.337623518683
#         topic_82 opinion_82_Opposition opinion_82_Government
# 0    staatshoofd          democratisch          democratisch
# 1       indiener           transparant      staatsrechtelijk
# 2       formatie      staatsrechtelijk          ongeschreven
# 3      reglement              aanwezig            allereerst
# 4         proces               formeel          parlementair
# 5     initiatief                 vroeg             uitvoerig
# 6    informateur       constitutioneel              gevoelig
# 7    meerderheid           theoretisch          terughoudend
# 8  transparantie            toekomstig               onnodig
# 9       koningin               plenair                zuiver
#
# [10 rows x 3 columns]
#
# JSD: 0.337465378447
#         topic_71 opinion_71_Opposition opinion_71_Government
# 0  pensioenfonds            toekomstig             gemiddeld
# 1       pensioen             gemiddeld            toekomstig
# 2      werkgever            collectief        administratief
# 3        bestuur         belanghebbend           ingewikkeld
# 4      deelnemer            historisch           commercieel
# 5          fonds                actief               onnodig
# 6  dekkingsgraad           evenwichtig            kunstmatig
# 7          rente     toekomstbestendig              beperken
# 8        korting               actueel                  raar
# 9      werknemer               privaat                 reëel
#
# [10 rows x 3 columns]
#
# JSD: 0.337198408561
#         topic_64 opinion_64_Opposition opinion_64_Government
# 0         woning            betaalbaar              maximaal
# 1        huurder             integraal              redelijk
# 2           huur           beschikbaar              goedkoop
# 3     verhuurder              maximaal             jaarlijks
# 4    woningmarkt             tijdelijk                keurig
# 5  huurverhoging                  duur                   net
# 6     huurwoning           principieel            betaalbaar
# 7        gegeven             eenzijdig          marktconform
# 8    huurtoeslag          marktconform         aantrekkelijk
# 9     corporatie                scheef            zorgvuldig
#
# [10 rows x 3 columns]
#
# JSD: 0.335867337082
#        topic_56 opinion_56_Opposition opinion_56_Government
# 0     werknemer              werkloos              werkloos
# 1     werkgever              flexibel              maximaal
# 2  arbeidsmarkt           fatsoenlijk           werkzoekend
# 3          baan                  duur                  fors
# 4  werkloosheid              maximaal           afhankelijk
# 5        dienst                  fors             tijdelijk
# 6           cao                simpel           beschikbaar
# 7     zekerheid         aantrekkelijk          nadrukkelijk
# 8            er                actief                gezond
# 9        arbeid                   vol             ongewenst
#
# [10 rows x 3 columns]
#
# JSD: 0.334219022311
#       topic_54 opinion_54_Opposition opinion_54_Government
# 0    uitspraak                intern           rechterlijk
# 1     lidstaat          fundamenteel            zorgvuldig
# 2          hof              strijdig             expliciet
# 3    parlement           onwenselijk           jongstleden
# 4    procedure         klip-en-klaar           procedureel
# 5        stage     gemeenschappelijk           theoretisch
# 6  meerderheid              ongepast           structureel
# 7    wetgeving            zorgvuldig             volstrekt
# 8    instantie             wezenlijk               voldoen
# 9    standpunt               uiterst         uitdrukkelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.333569264241
#          topic_42 opinion_42_Opposition opinion_42_Government
# 0         alcohol            schadelijk             makkelijk
# 1      handhaving             strafbaar            gevaarlijk
# 2           ouder           minderjarig             strafbaar
# 3  leeftijdsgrens      wetenschappelijk                 waard
# 4  alcoholgebruik                gezond              negatief
# 5         gebruik             gemiddeld                divers
# 6           drank             makkelijk            preventief
# 7         verkoop                streng             eenvoudig
# 8        leeftijd                 vroeg                stevig
# 9     hennepteelt             landelijk             technisch
#
# [10 rows x 3 columns]
#
# JSD: 0.331620280197
#         topic_35 opinion_35_Opposition opinion_35_Government
# 0      werkgever                  ziek                  ziek
# 1     vangnetter             tijdelijk               privaat
# 2       contract     arbeidsongeschikt             gemiddeld
# 3        prikkel                streng             langdurig
# 4     flexwerker              duurzaam               publiek
# 5      uitkering         psychosociaal                recent
# 6      werknemer               onnodig           uitsluitend
# 7  dienstverband             eenzijdig             eenduidig
# 8         ziekte              relatief             technisch
# 9         arbeid             volstrekt     eigenrisicodrager
#
# [10 rows x 3 columns]
#
# JSD: 0.330630400796
#         topic_90 opinion_90_Opposition opinion_90_Government
# 0        salaris             dagelijks               publiek
# 1          bonus              variabel           semipubliek
# 2  aandeelhouder               publiek              variabel
# 3    onderneming              maximaal              maximaal
# 4       beloning                moreel            zorgvuldig
# 5     bestuurder         staatssteunen              redelijk
# 6     instelling           principieel             onbedoeld
# 7    commissaris             arbitrair               medisch
# 8    bonusverbod             inclusief             arbitrair
# 9       toezicht             zogenaamd           buitenlands
#
# [10 rows x 3 columns]
#
# JSD: 0.330322030377
#         topic_24 opinion_24_Opposition opinion_24_Government
# 0      beperking         huishoudelijk             landelijk
# 1      wethouder                zeeuws           voorliggend
# 2    voorziening             kwetsbaar          nadrukkelijk
# 3  ondersteuning           beschikbaar             overbodig
# 4           taak           automatisch         huishoudelijk
# 5         tarief           voorliggend          gemeentelijk
# 6          model               zodanig            letterlijk
# 7        positie                  bang              werkzaam
# 8     verzorging           fatsoenlijk              aanwezig
# 9   aanbesteding             overbodig                zinvol
#
# [10 rows x 3 columns]
#
# JSD: 0.330243459495
#         topic_20 opinion_20_Opposition opinion_20_Government
# 0     ondernemer               onnodig        administratief
# 1       opdracht           onduidelijk             zogenaamd
# 2         dienst               logisch         professioneel
# 3  bedrijfsleven               privaat               publiek
# 4   aanbesteding              goedkoop             jaarlijks
# 5            eis        administratief              duurzaam
# 6            mkb                    na            innovatief
# 7           last              speciaal              maximaal
# 8           gids            innovatief             voordelig
# 9          markt            regelmatig             overbodig
#
# [10 rows x 3 columns]
#
# JSD: 0.329680386831
#      topic_84 opinion_84_Opposition opinion_84_Government
# 0      natuur             agrarisch              duurzaam
# 1   provincie            ecologisch             agrarisch
# 2        boer     gemeenschappelijk           beschikbaar
# 3        dier              duurzaam                 groen
# 4      gebied             jaarlijks              prachtig
# 5     akkoord               akkoord           realistisch
# 6       markt             integraal            ecologisch
# 7       water           afhankelijk             integraal
# 8        doel                   vol                  fors
# 9  ondernemer           beschikbaar            definitief
#
# [10 rows x 3 columns]
#
# JSD: 0.328303085303
#             topic_1 opinion_1_Opposition opinion_1_Government
# 0         brandweer         gemeentelijk            regionaal
# 1      burgemeester         operationeel    gemeenschappelijk
# 2      vrijwilliger            regionaal         gemeentelijk
# 3             regio                dicht           zorgvuldig
# ...
# 6         dader              aanwezig             gruwelijk
# 7      Justitie              centraal               keihard
# 8         vrouw          parlementair         onbevredigend
# 9      misdrijf             landelijk              schuldig
#
# [10 rows x 3 columns]
#
# JSD: 0.303195974133
#          topic_6 opinion_6_Opposition    opinion_6_Government
# 0        notaris    gemeenschappelijk               voorlopig
# 1       advocaat            voorlopig       gemeenschappelijk
# 2          gezag          gemakkelijk  nationaliteitsvereiste
# 3        rechter         prejudicieel            prejudicieel
# 4      procedure       administratief          administratief
# 5  echtscheiding              onnodig              burgerlijk
# 6    vvd-fractie            mondeling             onvoldoende
# 7      scheiding               simpel              onderhavig
# 8        toegang            huwelijks              essentieel
# 9  nationaliteit            notarieel         klaarblijkelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.301969610029
#         topic_85 opinion_85_Opposition opinion_85_Government
# 0        memorie           voorliggend           voorliggend
# 1      wijziging                divers                    na
# 2           nota              negatief               plenair
# 3    toelichting             eenvoudig             zogenaamd
# 4        verslag           aanzienlijk           gezamenlijk
# 5  wetswijziging              adequaat              relatief
# 6           maat               zodanig             tijdelijk
# 7     uitvoering              relevant             voorlopig
# 8       rekening           uitsluitend             inclusief
# 9  voorbereiding                recent                divers
#
# [10 rows x 3 columns]
#
# JSD: 0.300273587307
#                  topic_68 opinion_68_Opposition opinion_68_Government
# 0               belasting               fiscaal               fiscaal
# 1           belastingplan                 groen             cultureel
# 2                     btw             cultureel                vreemd
# 3                    anbi              duurzaam           buitenlands
# 4                  tarief           structureel          buitengewoon
# 5      inkomstenbelasting            innovatief            budgettair
# 6                    auto                    na     belastingplichtig
# 7                 geefwet               fossiel              eenmalig
# 8  vennootschapsbelasting              relatief                 groen
# 9            vrijstelling           voorliggend        administratief
#
# [10 rows x 3 columns]
#
# JSD: 0.299091820834
#      topic_72 opinion_72_Opposition opinion_72_Government
# 0  vereniging       strafrechtelijk       strafrechtelijk
# 1  ministerie              seksueel       verschrikkelijk
# 2     rechter      civielrechtelijk                civiel
# 3    vrijheid            ontzettend               beslist
# 4     verdrag              schuldig              seksueel
# 5      verbod          verwerpelijk                scherp
# 6    misbruik             strafbaar                   oké
# 7      aanpak             kwetsbaar      civielrechtelijk
# 8     website            onschuldig                  leeg
# 9      strijd              tevreden             walgelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.295302677678
#          topic_7 opinion_7_Opposition opinion_7_Government
# 0     coffeeshop             illegaal            strafbaar
# 1           drug            crimineel             illegaal
# 2  criminaliteit         grootschalig            crimineel
# 3      crimineel              normaal              keihard
# 4          lijst               legaal            succesvol
# 5       overlast            succesvol                 slim
# 6        politie               lekker               simpel
# 7           hasj               veilig         grootschalig
# 8    bouwmeester          fantastisch          ingewikkeld
# 9         verbod           repressief            eenvoudig
#
# [10 rows x 3 columns]
#
# JSD: 0.294337211934
#              topic_3 opinion_3_Opposition      opinion_3_Government
# 0          ambtenaar            ambtelijk                   publiek
# 1         ministerie          principieel                burgerlijk
# 2         informatie               bewust                 ambtelijk
# 3             bedrag            olympisch                   privaat
# 4  arbeidsvoorwaarde              privaat  overeenstemmingsvereiste
# 5           indiener                  net                 eenzijdig
# 6          draagvlak               intern                collectief
# 7             cijfer               stevig         publiekrechtelijk
# 8           argument    publiekrechtelijk                 olympisch
# 9      rechtspositie         nadrukkelijk             klip-en-klaar
#
# [10 rows x 3 columns]
#
# JSD: 0.293579945742
#                topic_63 opinion_63_Opposition opinion_63_Government
# 0              leerling              speciaal              speciaal
# 1                 ouder                  zwak              regulier
# 2                leraar               primair               primair
# 3                docent                gratis                  zwak
# 4                  klas              regulier             werkelijk
# 5  samenwerkingsverband               bevoegd           zelfstandig
# 6          zorgleerling             kwetsbaar               bevoegd
# 7                   mbo             technisch            middelbaar
# 8         schoolbestuur              centraal              ambulant
# 9                  veld               voldoen                   mis
#
# [10 rows x 3 columns]
#
# JSD: 0.292374892941
#         topic_89 opinion_89_Opposition opinion_89_Government
# 0        product              duurzaam              duurzaam
# 1   duurzaamheid                extern             efficiënt
# 2        voedsel             intensief            biologisch
# 3          vlees            biologisch          buitengewoon
# 4           dier              dierlijk               primair
# 5    veehouderij                  duur           interessant
# 6      consument            wereldwijd             intensief
# 7       megastal                actief             succesvol
# 8  verduurzaming                 groen             agrarisch
# 9         milieu          kleinschalig           betrouwbaar
#
# [10 rows x 3 columns]
#
# JSD: 0.292130146761
#            topic_43 opinion_43_Opposition opinion_43_Government
# 0            kracht                gratis                gratis
# 1         uitspraak          fundamenteel            zorgvuldig
# 2          id-kaart           principieel           jongstleden
# 3  identiteitskaart   individualiseerbaar              destijds
# 4          paspoort                geldig          fundamenteel
# 5             kaart          gemeentelijk            sympathiek
# 6         grondslag           oneigenlijk   individualiseerbaar
# 7             leges            zorgvuldig          gemeentelijk
# 8         wetgeving                 klaar          onzorgvuldig
# 9         rijbewijs               fiscaal               spoedig
#
# [10 rows x 3 columns]
#
# JSD: 0.29166940766
#          topic_80 opinion_80_Opposition opinion_80_Government
# 0     rechtspraak           rechterlijk          gerechtelijk
# 1       rechtbank          gerechtelijk           rechterlijk
# 2         rechter             efficiënt               voldoen
# 3           macht           voorliggend           geografisch
# 4           kaart                recent             efficiënt
# 5  arrondissement             kwetsbaar             regionaal
# 6             vis           bestuurlijk             landelijk
# 7    visstroperij             regionaal           kwalitatief
# 8      handhaving                 dicht             expliciet
# 9     organisatie                gering             werkelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.288930966999
#        topic_14 opinion_14_Opposition opinion_14_Government
# 0     terugkeer            vrijwillig            vrijwillig
# 1        opvang                veilig            zorgvuldig
# 2      herkomst               irakees               medisch
# 3        straat              onveilig                veilig
# 4  illegaliteit                humaan                iraaks
# 5    tentenkamp              adequaat          rechtvaardig
# 6   asielzoeker            onmogelijk              negatief
# 7  problematiek           menswaardig                humaan
# 8     procedure             tijdelijk            plotseling
# 9     resultaat                iraaks           rechterlijk
#
# [10 rows x 3 columns]
#
# JSD: 0.287912681555
#                     topic_60 opinion_60_Opposition opinion_60_Government
# 0             arbeidsmigrant             tijdelijk              malafide
# 1            arbeidsmigratie              malafide             oneerlijk
# 2                    verkeer              illegaal              werkloos
# 3  tewerkstellingsvergunning         oost-europees                recent
# 4              uitzendbureau                recent          nadrukkelijk
# 5                huisvesting                 pools             tijdelijk
# 6                 uitbuiting             oneerlijk         oost-europees
# 7               concurrentie           buitenlands                stevig
# 8                      grens                   dik           zelfstandig
# 9                   overlast               keihard              bonafide
#
# [10 rows x 3 columns]
#
# JSD: 0.281279544469
#       topic_41 opinion_41_Opposition opinion_41_Government
# 0       geweld                 joods           islamitisch
# 1  gemeenschap           islamitisch                 joods
# 2        vrouw              seksueel             egyptisch
# 3   instelling           structureel        multicultureel
# 4        islam           buitenlands           structureel
# 5      gesprek             religieus           gewelddadig
# 6     klaveren        multicultureel            marokkaans
# 7   bedreiging                veilig               anoniem
# 8     incident                 recht           particulier
# 9          man                moreel            hedendaags
#
# [10 rows x 3 columns]
#
# JSD: 0.279608368992
#               topic_99 opinion_99_Opposition opinion_99_Government
# 0          bevoegdheid         discretionair         discretionair
# 1            procedure           minderjarig                  bang
# 2          vreemdeling          alleenstaand              illegaal
# 3          asielzoeker          terughoudend            schrijnend
# 4             aanvraag                streng              kansrijk
# 5         burgemeester                  bang              regulier
# 6  verblijfsvergunning                  vals             feitelijk
# 7              gebruik             voormalig        doorslaggevend
# 8                asiel            schrijnend          terughoudend
# 9             verblijf              regulier                actief
#
# [10 rows x 3 columns]
#
# JSD: 0.271759604517
#              topic_21 opinion_21_Opposition opinion_21_Government
# 0           convenant      wetenschappelijk      wetenschappelijk
# 1                dier               ritueel               ritueel
# 2              slacht             religieus             religieus
# 3       dierenwelzijn                 joods            onbedwelmd
# 4            vrijheid           industrieel               ethisch
# 5          indienster              regulier           industrieel
# 6  godsdienstvrijheid         wetstechnisch                 joods
# 7          godsdienst           islamitisch          godsdienstig
# 8          wetenschap          godsdienstig               koosjer
# 9         verbetering              aanwezig             werkelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.270759894468
#             topic_81 opinion_81_Opposition opinion_81_Government
# 0          richtlijn              illegaal              illegaal
# 1        vreemdeling             strafbaar             strafbaar
# 2  strafbaarstelling       strafrechtelijk              relevant
# 3       inreisverbod             kwetsbaar       strafrechtelijk
# 4           verblijf               onjuist             uitvoerig
# 5       illegaliteit             onbepaald       afschrikwekkend
# 6            sanctie          onrechtmatig            vrijwillig
# 7          terugkeer            vrijwillig                legaal
# 8      implementatie    bestuursrechtelijk             ongewenst
# 9          wetgeving               medisch              cruciaal
#
# [10 rows x 3 columns]
#
# JSD: 0.269358255541
#                     topic_51 opinion_51_Opposition opinion_51_Government
# 0                     wereld           buitenlands           buitenlands
# 1                    relatie              arabisch              arabisch
# 2                     gebied              militair          nadrukkelijk
# 3               ontwikkeling            palestijns                 turks
# 4                      regio            israëlisch                actief
# 5               overeenkomst                 turks                geacht
# 6                 betrekking           indonesisch                iraans
# 7                       unie              illegaal             menselijk
# 8                 buitenland           diplomatiek            bilateraal
# 9  ontwikkelingssamenwerking              nucleair              aanwezig
#
# [10 rows x 3 columns]
#
# JSD: 0.26494063622
#           topic_36 opinion_36_Opposition opinion_36_Government
# 0       ziekenhuis                 acuut                 acuut
# 1    verloskundige               medisch             tijdelijk
# 2             norm             landelijk               onnodig
# 3        inspectie             tijdelijk           spoedeisend
# 4  ambulancezorgen             regionaal                veilig
# 5     concentratie           spoedeisend            bereikbaar
# 6         afdeling              dichtbij            volwaardig
# 7      verloskunde            bereikbaar               publiek
# 8           minuut              klinisch                  dood
# 9   geboortezorgen              centraal                   wit
#
# [10 rows x 3 columns]
#
# JSD: 0.264753619573
#          topic_77 opinion_77_Opposition opinion_77_Government
# 0  tegemoetkoming             chronisch                  ziek
# 1           grens                  ziek   inkomensafhankelijk
# 2     zorgtoeslag   inkomensafhankelijk             chronisch
# 3          bedrag           gehandicapt          kindgebonden
# 4       beperking                modaal           evenwichtig
# 5          ziekte              destijds           gehandicapt
# 6          effect             zogenaamd          buitengewoon
# 7       stapeling               fiscaal            betaalbaar
# 8   inkomensgrens           onevenredig              relatief
# 9      huishouden             onterecht                rechts
#
# [10 rows x 3 columns]
#
# JSD: 0.249698272563
#          topic_4 opinion_4_Opposition opinion_4_Government
# 0            uur          roostervrij          roostervrij
# 1            ure       oorspronkelijk            feitelijk
# 2         leraar          kwalitatief          horizontaal
# 3           norm          horizontaal          kwalitatief
# 4       vakantie                  vol           uitstekend
# 5       urennorm            feitelijk              bevoegd
# 6       leerling           ontzettend                  vol
# 7            les            uitdagend            eenvoudig
# 8  onderwijstijd            werkelijk         kwantitatief
# 9         docent              formeel               zinvol
#
# [10 rows x 3 columns]
#
# JSD: 0.229841948576
#                 topic_9 opinion_9_Opposition opinion_9_Government
# 0               bericht              plenair              plenair
# 1              stemming            aanstaand            aanstaand
# 2                agenda              spoedig              spoedig
# 3      dertigledendebat          buitenlands            mondeling
# 4                   uur                apart          buitenlands
# 5               uitstel            mondeling              akkoord
# 6  procedurevergadering         onbeantwoord                apart
# 7              behoefte            inclusief                waard
# 8                 reces       controversieel           uitbreiden
# 9            sp-fractie             aanwezig              gedegen
#
# [10 rows x 3 columns]
