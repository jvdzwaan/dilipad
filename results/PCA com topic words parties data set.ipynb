# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 10)

# %%
data = pd.read_csv("/home/jvdzwaan/data/dilipad/results/all_years-adj-selected_parties_100/pca_correlation_words_100.csv", index_col=0, encoding='utf-8')
#data

# %%
print data.shape
np.sum(data !='n.s.') / data.shape[0] * 100.0
# Out:
# (38145, 60)
# pca0_lrgen_kendalltau        4.097523
# pca0_lrgen_kendalltau_R      4.034605
# pca0_lrgen_spearmanr        11.403854
# pca0_lrecon_kendalltau       4.236466
# pca0_lrecon_kendalltau_R     2.015992
# pca0_lrecon_spearmanr        8.978896
# pca1_lrgen_kendalltau        4.878752
# pca1_lrgen_kendalltau_R      4.980994
# pca1_lrgen_spearmanr         8.475554
# pca1_lrecon_kendalltau       5.691441
# pca1_lrecon_kendalltau_R     3.984795
# pca1_lrecon_spearmanr        7.198847
# pca2_lrgen_kendalltau        4.239088
# pca2_lrgen_kendalltau_R      4.501245
# pca2_lrgen_spearmanr        12.722506
# pca2_lrecon_kendalltau       4.191899
# pca2_lrecon_kendalltau_R     2.490497
# pca2_lrecon_spearmanr       10.352602
# pca3_lrgen_kendalltau        3.945471
# pca3_lrgen_kendalltau_R      4.784375
# pca3_lrgen_spearmanr         6.957662
# pca3_lrecon_kendalltau       2.996461
# pca3_lrecon_kendalltau_R     4.228601
# pca3_lrecon_spearmanr        8.058723
# ...

# %%
filtered = data[data['pca0_lrgen_spearmanr'] != 'n.s.']
filtered['pca0_lrgen_spearmanr'] = pd.to_numeric(filtered['pca0_lrgen_spearmanr'])
print np.sum(filtered['pca0_lrgen_spearmanr'] > 0.0)
print np.sum(filtered['pca0_lrgen_spearmanr'] < 0.0)
# Out:
# 2504
# 1846
# /home/jvdzwaan/.virtualenvs/dilip/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
for w in data.index[data['pca0_lrgen_spearmanr'] != 'n.s.']:
    print w
# Out:
# 06-dea
# 2
# 2-ef
# 2-em
# a-onderzoek
# aai
# aal
# aalbeheerplan
# aalherstelplan
# aalstand
# aanbestedingsbeleid
# aanbestedingsbestek
# aanbouw
# aanbrengst
# aanjager
# aankoopbeleid
# aankoopplicht
# aankoopsubsidieregeling
# aanlanding
# aanlandingsplicht
# aanlegvergunning
# aanpassingsvermogen
# aanplant
# aanschaf
# aanschafbesluit
# aanschaffing
# aanschrijvingsbevoegdheid
# aanval
# aanvaller
# aanvalsoorlog
# aanvalswapen
# aanvoerlijn
# aanvoernorm
# aanvoerroute
# aanwezigheid
# aanwijzingsbesluit
# aanzitjacht
# aardappel
# aardbol
# aarde
# aartsvijand
# abm-verdrag
# absint
# abstractieniveau
# accountmanager
# achterdeurproblematiek
# achterloper
# achtwekentermijn
# act
# actualisering
# actualiseringsbrief
# acuutheid
# ad-hoccoalitie
# ad-hocoplossing
# ad-hocplanologie
# adaptatie
# adaptatieprogramma
# additionaliteit
# administratievelast
# admiraal
# adolescentenstrafrecht
# adr-systeem
# adviesrecht
# afbraakbeleid
# afdrachtpercentage
# affichering
# ...
