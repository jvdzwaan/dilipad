# %% [markdown]
# # Government/opposition distinction in parties through time data

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 15)

# %%
from cptm.utils.experiment import load_topics, load_opinions

config = {
    "inputData": "/path/to/input/data/*",
    "outDir": "/home/jvdzwaan/data/dilipad/results/all_years-adj-cabinets_selected-parties/{}",
    "nTopics": 100
}

topics = load_topics(config)
opinions = load_opinions(config)

# %%
ches_data = pd.read_csv('/home/jvdzwaan/data/dilipad/CHES/data/nl_ches_data.csv', index_col=0, encoding='utf-8')
print ches_data.columns
ches_data[['year', 'party', 'family','govt']]
# Out:
# Index([u'country', u'eastwest', u'eumember', u'year', u'expert', u'party_id',
#        u'cmp_id', u'party', u'vote', u'seat', u'electionyear', u'epvote',
#        u'family', u'govt', u'position', u'eu_salience', u'eu_dissent',
#        u'eu_benefit', u'eu_ep', u'eu_fiscal', u'eu_intmark', u'eu_employ',
#        u'eu_budgets', u'eu_agri', u'eu_cohesion', u'eu_environ', u'eu_asylum',
#        u'eu_foreign', u'eu_turkey', u'lrgen', u'lrecon', u'galtan',
#        u'lrecon_salience', u'galtan_salience', u'spendvtax',
#        u'spendvtax_salience', u'deregulation', u'dereg_salience',
#        u'redistribution', u'redist_salience', u'civlib_laworder',
#        u'civlib_salience', u'sociallifestyle', u'social_salience',
#        u'religious_principle', u'relig_salience', u'immigrate_policy',
#        u'immigra_salience', u'multiculturalism', u'multicult_salience',
#        u'urban_rural', u'urban_salience', u'environment', u'enviro_salience',
#        u'cosmo', u'cosmo_salience', u'regions', u'region_salience',
#        u'international_security', u'international_salience', u'us',
#        u'us_salience', u'ethnic_minorities', u'ethnic_salience',
#        u'econ_interven', u'nationalism', u'antielite_salience',
#        u'corrupt_salience', u'mip_one', u'mip_two', u'mip_three'],
#       dtype='object')
#      year         party        family               govt
# 395  1999           CDA     christdem  not in government
# 396  2002           CDA     christdem      in government
# 397  2006           CDA     christdem      in government
# 398  2010           CDA     christdem      in government
# 400  1999          PvdA     socialist      in government
# 401  2002          PvdA     socialist  not in government
# 402  2006          PvdA     socialist  not in government
# 403  2010          PvdA     socialist  not in government
# 405  1999           VVD       liberal      in government
# 406  2002           VVD       liberal      in government
# 407  2006           VVD       liberal      in government
# 408  2010           VVD       liberal      in government
# 410  1999           D66       liberal      in government
# 411  2002           D66       liberal      in government
# 412  2006           D66       liberal                0.5
# 413  2010           D66       liberal  not in government
# 415  1999    GroenLinks         green  not in government
# 416  2002    GroenLinks         green  not in government
# 417  2006    GroenLinks         green  not in government
# 418  2010    GroenLinks         green  not in government
# 420  1999           SGP  confessional  not in government
# 421  2002           SGP  confessional  not in government
# 422  2010           SGP  confessional  not in government
# 424  1999           GPV  confessional  not in government
# 425  1999           RPF  confessional  not in government
# 426  1999            CD     rad right  not in government
# 427  1999            SP      rad left  not in government
# 428  2002            SP      rad left  not in government
# 429  2006            SP      rad left  not in government
# 430  2010            SP      rad left  not in government
# 432  2002           LPF     rad right  not in government
# 433  2002  ChristenUnie  confessional  not in government
# 434  2006  ChristenUnie  confessional  not in government
# 435  2010  ChristenUnie  confessional  not in government
# 437  2006           PVV     rad right  not in government
# 438  2010           PVV     rad right  not in government
# 440  2010          PvdD         green  not in government

# %%
from sklearn.manifold import MDS
