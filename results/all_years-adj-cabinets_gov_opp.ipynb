# %% [markdown]
# # View CPT Results for experiment "all_years-adj-cabinets_gov_opp"

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (10, 7)

# %% [markdown]
# ## Topic word perplexity

# %%
import os

def load_perplexity_results(results_dir):
    perplexity_topic = pd.read_csv(os.path.join(results_dir, 'perplexity_topic.csv'), index_col=0)
    perplexity_opinion = pd.read_csv(os.path.join(results_dir, 'perplexity_opinion.csv'), index_col=0)
    
    return perplexity_topic, perplexity_opinion

# %%
results_dir = '/home/jvdzwaan/data/dilipad/results/all_years/all_years-adj-cabinets_gov_opp/'

# %%
perplexity_topic, perplexity_opinion = load_perplexity_results(results_dir)
perplexity_topic.plot();
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=medium. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
# change intervals if needed
intervals = ['20', '60', '80', '100', '180', '200']

# %%
perplexity_topic[intervals].plot();

# %% [markdown]
# ## Opinion word perplexity

# %%
perplexity_opinion.plot();

# %%
perplexity_opinion[intervals].plot();

# %% [markdown]
# ## Results for topics and opinions

# %%
# choose optimal number of topics based on perplexity results
nTopics = 100

# %%
# load results
import glob
import os
import re

def load_experiment_results(nTopics, results_dir):

    # document topic matrix (theta)
    theta = pd.read_csv(os.path.join(results_dir, 'theta_{}.csv'.format(nTopics)), index_col=0)

    # phi topic (transposed)
    phi_topic_t = pd.read_csv(os.path.join(results_dir, 'topics_{}.csv'.format(nTopics)), index_col=0, encoding='utf-8')

    # phi opinion (transposed) per perspective
    opinion_files = glob.glob('{}/opinions_*_{}.csv'.format(results_dir, nTopics))
    phis_opinion_t = {}
    for f in opinion_files:
        m = re.match(r'.+opinions_(.+).csv', f)
        name = m.group(1).replace('_{}'.format(nTopics), '')
        phis_opinion_t[name] = pd.read_csv(f, index_col=0, encoding='utf-8')
    return theta, phi_topic_t, phis_opinion_t

# %%
theta, phi_topic_t, phis_opinion_t = load_experiment_results(nTopics, results_dir)

# %% [markdown]
# ### 'Weight' of the most important topic per document
#
# Each topic has a certain weight in the document. We would like to see one (or a few) topics with high weight per document. Below are some basic statistics on the most important topic (highest weight) per document.

# %%
def print_topic_weights(theta):
    a = theta.copy().apply(max, axis=1)
    a.sort(ascending=False)

    print 'Mean weight of most important topic: {} (std: {})'.format(a.mean(), a.std())
    print 'Min and max of most important topic: min: {}, max: {}'.format(a.min(), a.max())
    print 'Median weight of most important topic: ', a.median()

print_topic_weights(theta)
# Out:
# Mean weight of most important topic: 0.22070665001 (std: 0.131158078641)
# Min and max of most important topic: min: 0.01, max: 0.740963203463
# Median weight of most important topic:  0.201637899427

# %% [markdown]
# Line graph of the sorted topic weigths:

# %%
def plot_topic_weights(theta):
    theta.copy().apply(lambda row:sorted(row)[::-1], axis=1).transpose().plot(legend=None);

plot_topic_weights(theta)

# %% [markdown]
# ### Number of topics per document
#
# The number of topics per document is calculated by counting the number of topic with weight above a certain threshold. The numer of topics per document should (roughly) be equivalent to the number of ``pm:topic``s per document (however, at the moment we do not have statistics of this).

# %%
def display_number_of_topics_per_document(theta, threshold=0.05):
    topic_counts = theta.apply(lambda row: np.sum(row > threshold), axis=1)
    print topic_counts.value_counts(sort=False)
    topic_counts.hist(bins=len(topic_counts.value_counts()), figsize=(5,3));

display_number_of_topics_per_document(theta)
# Out:
# 0     982
# 8       9
# 1    2174
# 9       1
# 2    2913
# 3    2881
# 4    1990
# 5     970
# 6     324
# 7      62
# dtype: int64

# %% [markdown]
# ### Topics

# %%
def show_topic(t, top=10):
    """Return dataframe containing <top> topic words, weights of topic words and per perspective opinion words and
    weigths of opinion words.
    
    Parameters
        t : str - index of topic number
        top : int - the number of words to store in the dataframe
    
    Returns Pandas DataFrame
    """
    topic = phi_topic_t[t].copy()
    topic.sort(ascending=False)
    topic = topic[0:top]
    df_t = pd.DataFrame(topic)
    df_t.reset_index(level=0, inplace=True)
    df_t.columns = ['topic_{}'.format(t), 'weights_topic_{}'.format(t)]

    dfs = [df_t]

    for p, o in phis_opinion_t.iteritems():
        opinion = o[t].copy()
        opinion.sort(ascending=False)
        opinion = opinion[0:top]
        df_o = pd.DataFrame(opinion)
        df_o.reset_index(level=0, inplace=True)
        df_o.columns = ['opinion_{}_{}'.format(t, p), 'weights_opinion_{}_{}'.format(t, p)]
        dfs.append(df_o)
        
    return pd.concat(dfs, axis=1)

def print_topics(phi_topic_t, phis_opinion_t, nTopics):
    jsd = None
    jsdFile = os.path.join(results_dir, 'jsd_{}.csv'.format(nTopics))
    if os.path.isfile(jsdFile):
        print 'Ordering topics by Jensen-Shannon divergence of the opinions'
        print
        jsd = pd.read_csv(jsdFile, index_col=0)
        r = jsd.sort(['jsd'], ascending=False)
        print 'Min jsd: {}, max jsd: {}'.format(np.min(jsd['jsd']), np.max(jsd['jsd']))
        print 'Average jsd: {} (std: {}), median jsd: {}'.format(np.mean(jsd['jsd']), np.std(jsd['jsd']), np.median(jsd['jsd']))
        print
        loop = r.index
    else:
        print 'Ordering topics by topic number'
        print '(To order topics by Jensen-Shannon divergence of the opinions run the experiment_jsd_opinions script.)'
        print
        loop = range(nTopics)
    for i in loop:
        if not jsd is None:
            print 'JSD:', jsd.at[i, 'jsd']
        pLabels = ['opinion_{}_{}'.format(i, p) for p, o in phis_opinion_t.iteritems()]
        pLabels.sort()
        print show_topic(str(i))[['topic_{}'.format(i)] + pLabels]
        print

# %%
print_topics(phi_topic_t, phis_opinion_t, nTopics)
# Out:
# Ordering topics by Jensen-Shannon divergence of the opinions
#
# Min jsd: 0.692443739776, max jsd: 1.07040576234
# Average jsd: 0.889623730242 (std: 0.0619989778887), median jsd: 0.896501102926
#
# JSD: 1.07040576234
#             topic_64 opinion_64_Balkenende I-Government  \
# 0          werknemer                        afhankelijk
# 1          werkgever                          meerjarig
# 2            partner                       substantieel
# 3                cao                           cruciaal
# 4             arbeid                     werkgeverschap
# 5            vakbond                               bang
# 6       reïntegratie                          onbepaald
# 7             advies                       contractueel
# 8            ontslag                         behoorlijk
# 9  arbeidsvoorwaarde                        fatsoenlijk
#
#   opinion_64_Balkenende I-Opposition opinion_64_Balkenende II-Government  \
# 0                  arbeidsongeschikt                          zorgvuldig
# 1                          meerjarig                            flexibel
# 2                       gedeeltelijk                        gedeeltelijk
# 3                           asociaal                            duurzaam
# 4                           relevant                             privaat
# 5                           gevoelig                                ziek
# 6                          intensief                         gezamenlijk
# 7                       rechtvaardig                             uiterst
# 8                        principieel                            optimaal
# 9                      professionnel                            solidair
#
#   opinion_64_Balkenende II-Opposition opinion_64_Balkenende III-Government  \
# 0                   arbeidsongeschikt                            permanent
# 1                        gedeeltelijk                               dubbel
# 2                                ziek                            ongewenst
# 3                           menselijk                                 wild
# 4                            flexibel                     civielrechtelijk
# 5                          zorgvuldig                          transparant
# 6                              dubbel                             zakelijk
# 7                           volstrekt                            uiterlijk
# 8                              streng                            blijkbaar
# 9                             privaat                                recht
#
#   opinion_64_Balkenende III-Opposition opinion_64_Balkenende IV-Government  \
# 0                           collectief                           tijdelijk
# 1                             maximaal                             privaat
# 2                               streng                            tevreden
# 3                    publiekrechtelijk                             primair
# 4                         hiërarchisch                          collectief
# 5                             flexibel                           feitelijk
# 6                            onderling                           eindelijk
# 7                               ultiem                       onafhankelijk
# 8                        psychosociaal                            flexibel
# 9                         godsdienstig                             uiterst
#
#   opinion_64_Balkenende IV-Opposition opinion_64_Kok II-Government  \
# 0                            flexibel                         ziek
# 1                                lief                      privaat
# 2                           eindelijk                    regionaal
# 3                         fatsoenlijk             persoonsgebonden
# 4                                 gek                     redelijk
# 5                             keihard                   collectief
# 6                           wezenlijk                       scherp
# 7                         hardwerkend                    landelijk
# 8                          acceptabel                      onnodig
# 9                            cruciaal                     aanwezig
#
#   opinion_64_Kok II-Opposition opinion_64_Rutte I-Government  \
# 0                         ziek                       privaat
# 1                    regionaal                    burgerlijk
# 2                      privaat                    collectief
# 3            arbeidsongeschikt                     eenzijdig
# 4                    landelijk      overeenstemmingsvereiste
# 5                  principieel             publiekrechtelijk
# 6                 fundamenteel            bedrijfseconomisch
# 7               bovenwettelijk                 desbetreffend
# 8           sociaal-economisch                      eenmalig
# 9                    voorlopig                     materieel
#
#   opinion_64_Rutte I-Opposition
# 0                       privaat
# 1                     eenzijdig
# 2                          half
# 3                   fatsoenlijk
# 4                     praktisch
# 5                        stevig
# 6                      werkzaam
# 7                    collectief
# 8                       normaal
# 9                administratief
#
# [10 rows x 13 columns]
#
# JSD: 1.01353801713
#            topic_58 opinion_58_Balkenende I-Government  \
# 0           vervoer                      achterstallig
# 1     nationaliteit                         sympathiek
# 2          reiziger                        voortdurend
# 3              stad                             jammer
# 4      aanbesteding                             majeur
# 5             trein                      vergelijkbaar
# 6         concessie                         essentieel
# 7             spoor                        comfortabel
# 8        vervoerder                             veilig
# 9  nederlanderschap                           voornaam
#
#   opinion_58_Balkenende I-Opposition opinion_58_Balkenende II-Government  \
# 0                      achterstallig                              dubbel
# 1                          regionaal                         gehandicapt
# 2                         collectief                        onmiddellijk
# 3                          meerjarig                              vitaal
# 4                               stil                               waard
# 5                         gevaarlijk                           inclusief
# 6                         decentraal                          acceptabel
# 7                           minimaal                              aardig
# 8                     teleurstellend                        bespreekbaar
# 9                          eindeloos                             zinloos
#
#   opinion_58_Balkenende II-Opposition opinion_58_Balkenende III-Government  \
# 0                         gehandicapt                               dubbel
# 1                        toegankelijk                           marokkaans
# 2                          decentraal                           meervoudig
# 3                              gratis                            blijkbaar
# 4                          welwillend                               latent
# 5                            minimaal                               papier
# 6                           wezenlijk                                reëel
# 7                           zichtbaar                             deelbaar
# 8                         principieel                              geboren
# 9                                duur                               actief
#
#   opinion_58_Balkenende III-Opposition opinion_58_Balkenende IV-Government  \
# 0                               dubbel                                krom
# 1                           meervoudig                              veilig
# 2                           marokkaans                              dubbel
# 3                          principieel                          decentraal
# 4                              geboren                 grensoverschrijdend
# 5                       oorspronkelijk                        toegankelijk
# 6                               bewust                              vreemd
# 7                          onwenselijk                          essentieel
# 8                             ongelijk                               stads
# 9                               vreemd                           feitelijk
#
#   opinion_58_Balkenende IV-Opposition opinion_58_Kok II-Government  \
# 0                              dubbel               oorspronkelijk
# 1                          marokkaans                   meervoudig
# 2                               turks            publiekrechtelijk
# 3                                krom                    mondeling
# 4                          decentraal                       vreemd
# 5                          meervoudig                    dagelijks
# 6                              gratis                    feitelijk
# 7                               blind                  voorliggend
# 8                      oorspronkelijk                onafhankelijk
# 9                                duur                    ambtelijk
#
#   opinion_58_Kok II-Opposition opinion_58_Rutte I-Government  \
# 0            publiekrechtelijk                          duur
# 1                    regionaal                        veilig
# 2            privaatrechtelijk                       privaat
# 3                       vreemd                  gemeentelijk
# 4                      privaat                   betrouwbaar
# 5               oorspronkelijk                      kritisch
# 6                  binnenlands                     efficiënt
# 7                   decentraal                   automatisch
# 8                   essentieel                           net
# 9                       dubbel                        lastig
#
#   opinion_58_Rutte I-Opposition
# 0                    decentraal
# 1                     regionaal
# 2                        dubbel
# 3                        veilig
# 4                         reëel
# 5                        totaal
# 6                       privaat
# 7                       complex
# 8                    onderhands
# 9                      benieuwd
#
# [10 rows x 13 columns]
#
# JSD: 1.00713028896
#                topic_34 opinion_34_Balkenende I-Government  \
# 0                 ouder                           regulier
# 1         schoolbestuur                            primair
# 2       medezeggenschap                        tussentijds
# 3               bestuur                          werkelijk
# 4  medezeggenschapsraad                           geweldig
# 5             autonomie                           kritisch
# 6   samenwerkingsschool                               zwak
# 7                 fusie                           creatief
# 8              leerling                         gemonitord
# 9              vrijheid                        geleidelijk
#
#   opinion_34_Balkenende I-Opposition opinion_34_Balkenende II-Government  \
# 0                           speciaal                             primair
# 1                           regulier                         structureel
# 2                          gemiddeld                         automatisch
# 3                        gehandicapt                           vierdaags
# 4                               druk                         gezamenlijk
# 5                             ideaal                           expliciet
# 6                        pedologisch                     vanzelfsprekend
# 7                   leerlinggebonden                             bevoegd
# 8                         regelmatig                              totaal
# 9                     schoolgebonden                        afzonderlijk
#
#   opinion_34_Balkenende II-Opposition opinion_34_Balkenende III-Government  \
# 0                             primair                              bevoegd
# 1                           vierdaags                        buitenschools
# 2                             bevoegd                            naschools
# 3                         gezamenlijk                           onmogelijk
# 4                         principieel                          gezamenlijk
# 5                               zwart                                 half
# 6                               duaal                            dagelijks
# 7                              jammer                           definitief
# 8                         inhoudelijk                            informeel
# 9                             voldoen                             neutraal
#
#   opinion_34_Balkenende III-Opposition opinion_34_Balkenende IV-Government  \
# 0                              bevoegd                                zwak
# 1                        buitenschools                             bevoegd
# 2                             speciaal                           menselijk
# 3                            naschools                              lastig
# 4                         fundamenteel                            kritisch
# 5                              voldoen                       onafhankelijk
# 6                            landelijk                         pedagogisch
# 7                             regulier                             formeel
# 8                                  vol                         zelfstandig
# 9                               intern                         islamitisch
#
#   opinion_34_Balkenende IV-Opposition opinion_34_Kok II-Government  \
# 0                            maximaal                      privaat
# 1                              actief                    vierjarig
# 2                                 wit                      voldoen
# 3                           menselijk                    materieel
# 4                                zwak                        duaal
# 5                           regionaal                     regulier
# 6                             voldoen                        vroeg
# 7                               zwart                  kwalitatief
# 8                                 mis                    eenvoudig
# 9                       professioneel                 toegankelijk
#
#   opinion_34_Kok II-Opposition opinion_34_Rutte I-Government  \
# 0                        duaal                   zelfstandig
# 1                  structureel                       primair
# 2                    integraal                     succesvol
# 3                  principieel                      maximaal
# 4                         bang                     volwassen
# 5                        zwart                        paraat
# 6                      primair                      creatief
# 7               grondwettelijk                 discretionair
# 8                 toegankelijk                     feitelijk
# 9                    materieel                   ondoelmatig
#
#   opinion_34_Rutte I-Opposition
# 0                       primair
# 1                     succesvol
# 2                     expliciet
# 3                   zelfstandig
# 4                         apart
# 5                       bevoegd
# 6                     menselijk
# 7                     praktisch
# 8                    behoorlijk
# 9                   pedagogisch
#
# [10 rows x 13 columns]
#
# JSD: 1.00464237532
#         topic_48 opinion_48_Balkenende I-Government  \
# 0      richtlijn                        onevenredig
# 1  implementatie                      desbetreffend
# 2       lidstaat                          ongewenst
# 3           stof                           destijds
# 4            kop                     administratief
# 5     toepassing                         schadelijk
# 6      procedure                             nuttig
# 7    verordening                          onbepaald
# 8      toelating                               duur
# 9   harmonisatie                       doeltreffend
#
#   opinion_48_Balkenende I-Opposition opinion_48_Balkenende II-Government  \
# 0                             gezond                            relevant
# 1                          momenteel                           materieel
# 2                                 na                              tijdig
# 3                        donkerbruin                           menselijk
# 4                       verwerpelijk                 grensoverschrijdend
# 5                               dood                               grijs
# 6                       substantieel                         procedureel
# 7                             gereed                       vergelijkbaar
# 8                          onbetwist                           wenselijk
# 9                               nauw                            vergaand
#
#   opinion_48_Balkenende II-Opposition opinion_48_Balkenende III-Government  \
# 0                               haags                            eenvoudig
# 1                           onderling                                   na
# 2                              dubbel                        uitdrukkelijk
# 3                         inhoudelijk                             chemisch
# 4                             formeel                             aanwezig
# 5                              tijdig                              onnodig
# 6                           praktisch                             werkzaam
# 7                         onduidelijk                        aantrekkelijk
# 8                             onjuist                             geregeld
# 9                             normaal                               modern
#
#   opinion_48_Balkenende III-Opposition opinion_48_Balkenende IV-Government  \
# 0                             chemisch                          decentraal
# 1                           gevaarlijk                         voorliggend
# 2                           schadelijk                              intern
# 3                               actief                         onduidelijk
# 4                             aanwezig                         inhoudelijk
# 5                              perfect                             bevoegd
# 6                             werkzaam                               licht
# 7                           deugdelijk                            digitaal
# 8                             maximaal                              tijdig
# 9                                trots                                raar
#
#   opinion_48_Balkenende IV-Opposition opinion_48_Kok II-Government  \
# 0                 grensoverschrijdend               landbouwkundig
# 1                      oorspronkelijk                    zogenaamd
# 2                           uitvoerig                    onmisbaar
# 3                              strikt                      logisch
# 4                              gerust                        groen
# 5                              lastig                     strijdig
# 6                             onjuist                         rood
# 7                            relatief                     werkzaam
# 8                         aanzienlijk                      akkoord
# 9                              simpel                     maximaal
#
#   opinion_48_Kok II-Opposition opinion_48_Rutte I-Government  \
# 0               landbouwkundig                        actief
# 1                    onmisbaar                 vergelijkbaar
# 2            milieuvriendelijk                 uitdrukkelijk
# 3                     chemisch                         trots
# 4                    technisch                     expliciet
# 5               onaanvaardbaar                    regelmatig
# 6                  afhankelijk                        scherp
# 7                      spoedig                      kritisch
# 8                desbetreffend                         apart
# 9                   gevaarlijk                   onwenselijk
#
#   opinion_48_Rutte I-Opposition
# 0                    gevaarlijk
# 1                    allereerst
# 2                     kwetsbaar
# 3                    schadelijk
# 4                         trots
# 5                    essentieel
# 6                        dubbel
# 7                      omwonend
# 8                      chemisch
# 9                   afhankelijk
#
# [10 rows x 13 columns]
#
# JSD: 0.994657982017
#       topic_30 opinion_30_Balkenende I-Government  \
# 0      verdrag                          onderling
# 1     grondwet                                arm
# 2   minderheid                           kritisch
# 3  meerderheid                          jaarlijks
# 4     bepaling                          afrikaans
# 5  goedkeuring                                vol
# 6    parlement                          intensief
# 7      werking                           belgisch
# 8       strijd                          voormalig
# 9  ratificatie                          uitvoerig
#
#   opinion_30_Balkenende I-Opposition opinion_30_Balkenende II-Government  \
# 0                             dubbel                          bilateraal
# 1                           belgisch                     constitutioneel
# 2                          integraal                         buitenlands
# 3                           redelijk                       uitdrukkelijk
# 4                      desbetreffend                           expliciet
# 5                         uitstekend                           materieel
# 6                           werkzaam                          uitbreiden
# 7                        persoonlijk                               duits
# 8                         rechtmatig                      grondwettelijk
# 9                             gering                         interessant
#
#   opinion_30_Balkenende II-Opposition opinion_30_Balkenende III-Government  \
# 0                         buitenlands                           kamerbreed
# 1                           expliciet                                 puur
# 2                              vreemd                          buitenlands
# 3                           blijkbaar                          bezwaarlijk
# 4                         interessant                               zuinig
# 5                          bilateraal                             speciaal
# 6                         inhoudelijk                      respectievelijk
# 7                       uitdrukkelijk                           israëlisch
# 8                            destijds                                  vol
# 9                                bang                             denkbaar
#
#   opinion_30_Balkenende III-Opposition opinion_30_Balkenende IV-Government  \
# 0                         onacceptabel                      grondwettelijk
# 1                               gering                     constitutioneel
# 2                             relevant                 grensoverschrijdend
# 3                             geschikt                        parlementair
# 4                         fundamenteel                        rechtstreeks
# 5                          gezamenlijk                           tweederde
# 6                    gemeenschappelijk                           praktisch
# 7                            diezelfde                       uitdrukkelijk
# 8                            impliciet                               haags
# 9                           historisch                              vreemd
#
#   opinion_30_Balkenende IV-Opposition opinion_30_Kok II-Government  \
# 0                      grondwettelijk                  amerikaanse
# 1                     constitutioneel                    tweederde
# 2                         buitenlands                    wezenlijk
# 3                                rood                 rechtstreeks
# 4                                iers                desbetreffend
# 5                       uitdrukkelijk                    feitelijk
# 6                        communautair                     destijds
# 7                      institutioneel                  binnenlands
# 8                             logisch                    overbodig
# 9                        rechtstreeks              constitutioneel
#
#   opinion_30_Kok II-Opposition opinion_30_Rutte I-Government  \
# 0                 rechtstreeks                  fundamenteel
# 1                  amerikaanse                        intern
# 2                      etnisch                    definitief
# 3              constitutioneel                     effectief
# 4                   historisch               verdragsluitend
# 5                  buitenlands                       correct
# 6                    uitvoerig                       onjuist
# 7                      primair                ondemocratisch
# 8                      formeel                       actueel
# 9                      terzake                    bilateraal
#
#   opinion_30_Rutte I-Opposition
# 0                    bilateraal
# 1                        vreemd
# 2                        recent
# 3                      benieuwd
# 4                      relevant
# 5                     deskundig
# 6                      haalbaar
# 7                         turks
# 8                 problematisch
# 9                       analoog
#
# [10 rows x 13 columns]
#
# JSD: 0.971830055382
#               topic_7 opinion_7_Balkenende I-Government  \
# 0            pensioen                          regulier
# 1                 aow                            jammer
# 2       pensioenfonds                          illegaal
# 3               fonds                      gedeeltelijk
# 4             partner                      rechtvaardig
# 5         aowleeftijd                       voortvarend
# 6           werknemer                          geregeld
# 7           werkgever                              raar
# 8  levensloopregeling                           bejaard
# 9     pensioenakkoord                          adequaat
#
#   opinion_7_Balkenende I-Opposition opinion_7_Balkenende II-Government  \
# 0               inkomensafhankelijk                            fiscaal
# 1                             super                        zelfstandig
# 2                            vreemd                               ziek
# 3                               net                         collectief
# 4                        behoorlijk                         vrijwillig
# 5                           gewezen                         actuarieel
# 6                         technisch                      aantrekkelijk
# 7                   nieuw-zeelandse                          inclusief
# 8                        regelmatig                             dubbel
# 9                        deugdelijk                       gedeeltelijk
#
#   opinion_7_Balkenende II-Opposition opinion_7_Balkenende III-Government  \
# 0                            fiscaal                          vrijwillig
# 1                         collectief                            negatief
# 2                        zelfstandig                                fors
# 3                             dubbel                         jongstleden
# 4                      aantrekkelijk                               jarig
# 5                               rijk                              keurig
# 6                              jarig                           zogenoemd
# 7                             tegoed                         zelfstandig
# 8                          feitelijk                            maximaal
# 9                             vreemd                          startklaar
#
#   opinion_7_Balkenende III-Opposition opinion_7_Balkenende IV-Government  \
# 0                    onvoorwaardelijk                        zelfstandig
# 1                           onbedoeld                       ministerieel
# 2                      voorwaardelijk                        transparant
# 3                                fors                          eenzijdig
# 4                                 wit                         collectief
# 5                         evenwichtig                         toekomstig
# 6                      administratief                         principaal
# 7                            minimaal                              trots
# 8                           toenmalig                            privaat
# 9                        conservatief                           aanwezig
#
#   opinion_7_Balkenende IV-Opposition opinion_7_Kok II-Government  \
# 0                        evenwichtig                  vrijwillig
# 1                 pensioengerechtigd                  essentieel
# 2                         toekomstig                     fiscaal
# 3                            onnodig                    flexibel
# 4                     oorspronkelijk                     gewezen
# 5                          evenredig                  collectief
# 6                      belanghebbend                 commercieel
# 7                           aanwezig                   selectief
# 8                        fatsoenlijk                 verdergaand
# 9                           relatief                  decentraal
#
#   opinion_7_Kok II-Opposition opinion_7_Rutte I-Government  \
# 0                  vrijwillig                  zelfstandig
# 1                  collectief                    gemiddeld
# 2                alleenstaand                   toekomstig
# 3                     fictief                   definitief
# 4                       mager                        jarig
# 5              onoverkomelijk                    tijdelijk
# 6                     fiscaal                 fundamenteel
# 7                    houdbaar                   historisch
# 8                   feitelijk                    uitvoerig
# 9               sekseneutraal           pensioengerechtigd
#
#   opinion_7_Rutte I-Opposition
# 0                     flexibel
# 1                    gemiddeld
# 2                   toekomstig
# 3                        jarig
# 4                   historisch
# 5                  geleidelijk
# 6                         rijk
# 7                   budgettair
# 8           pensioengerechtigd
# 9                      uiterst
#
# [10 rows x 13 columns]
#
# JSD: 0.970459240037
#         topic_97 opinion_97_Balkenende I-Government  \
# 0        notaris                     oorspronkelijk
# 1     vereniging                          wenselijk
# 2   beroepsgroep                          praktisch
# 3       register                         rechtmatig
# 4         beroep                         amsterdams
# 5            eis                            medisch
# 6      kwaliteit                           prachtig
# 7    registratie                             divers
# 8     tuchtrecht                             geldig
# 9  certificering                          feitelijk
#
#   opinion_97_Balkenende I-Opposition opinion_97_Balkenende II-Government  \
# 0                        buitenlands                         interessant
# 1                         thematisch                   publiekrechtelijk
# 2                            actueel                           notarieel
# 3                          voordelig                           onroerend
# 4                       gebruikelijk                      administratief
# 5                      vergelijkbaar                             kenbaar
# 6                        bezwaarlijk                           praktisch
# 7                          tijdelijk                     respectievelijk
# 8                             gemeen                    civielrechtelijk
# 9                         preventief                           deskundig
#
#   opinion_97_Balkenende II-Opposition opinion_97_Balkenende III-Government  \
# 0                          vrijwillig                            onderling
# 1                           notarieel                            agrarisch
# 2                           onroerend                    publiekrechtelijk
# 3                           eenvoudig                         afzonderlijk
# 4                               reëel                              bevoegd
# 5                         transparant                          onvoldoende
# 6                   publiekrechtelijk                             cruciaal
# 7                                  na                           koninklijk
# 8                           effectief                             eenmalig
# 9                         particulier                             ultimate
#
#   opinion_97_Balkenende III-Opposition opinion_97_Balkenende IV-Government  \
# 0                          zelfstandig                        elektronisch
# 1                            landelijk                      administratief
# 2                       administratief                               apart
# 3                               actief                          onderhands
# 4                             eenmalig                            benieuwd
# 5                          plaatselijk                           praktisch
# 6                           authentiek                            tevreden
# 7                               intern                           overbodig
# 8                              normaal                           deskundig
# 9                               nuttig                           preferent
#
#   opinion_97_Balkenende IV-Opposition opinion_97_Kok II-Government  \
# 0                           deskundig                  alternatief
# 1                           voorlopig                       friees
# 2                              civiel                     regulier
# 3                              actief                    onroerend
# 4                        onmiddellijk                   schadelijk
# 5                           technisch                   vrijwillig
# 6                         commercieel                   regelmatig
# 7                           eenvoudig               ongebruikelijk
# 8                           toevallig                  uitsluitend
# 9                              totaal                    voormalig
#
#   opinion_97_Kok II-Opposition opinion_97_Rutte I-Government  \
# 0                  alternatief                   zelfstandig
# 1                     regulier             gemeenschappelijk
# 2                   vrijwillig                 professioneel
# 3                 aanmerkelijk        nationaliteitsvereiste
# 4                onafhankelijk                     deskundig
# 5                    landelijk                     praktisch
# 6                  betrouwbaar                    ontzettend
# 7            publiekrechtelijk                   ingewikkeld
# 8                    overbodig                     voorlopig
# 9                     malafide                     eenvoudig
#
#   opinion_97_Rutte I-Opposition
# 0                verpleegkundig
# 1                   zelfstandig
# 2                     tijdelijk
# 3                     eenvoudig
# 4                   ingewikkeld
# 5                     zichtbaar
# 6                     gemiddeld
# 7                     plastisch
# 8                        divers
# 9                   uitsluitend
#
# [10 rows x 13 columns]
#
# JSD: 0.969881644358
#             topic_36 opinion_36_Balkenende I-Government  \
# 0          parlement                             intern
# 1       samenwerking                        buitenlands
# 2        bevoegdheid                       communautair
# 3          conventie                             dubbel
# 4     besluitvorming               intergouvernementeel
# 5           controle                             extern
# 6          opvatting                           krachtig
# 7  vertegenwoordiger                           creatief
# 8        versterking                              apart
# 9         instelling                             vitaal
#
#   opinion_36_Balkenende I-Opposition opinion_36_Balkenende II-Government  \
# 0                       democratisch                        democratisch
# 1                       parlementair                        parlementair
# 2                           federaal                              actief
# 3                           krachtig                            relevant
# 4                       rechtstreeks                           effectief
# 5                        binnenlands                      institutioneel
# 6                              vroeg                   gemeenschappelijk
# 7                       afzonderlijk                           wezenlijk
# 8                           monetair                    staatsrechtelijk
# 9                           creatief                           cultureel
#
#   opinion_36_Balkenende II-Opposition opinion_36_Balkenende III-Government  \
# 0                        parlementair                        archeologisch
# 1                              actief                       bouwhistorisch
# 2                           wezenlijk                    cultuurhistorisch
# 3                        democratisch                             onverlet
# 4                             formeel                            effectief
# 5                       archeologisch                               bewust
# 6                           cultureel                               ultiem
# 7                         realistisch                            integraal
# 8                   joods-christelijk                                 fout
# 9                   gemeenschappelijk                               fysiek
#
#   opinion_36_Balkenende III-Opposition opinion_36_Balkenende IV-Government  \
# 0                        archeologisch                        democratisch
# 1                     wetenschappelijk                              actief
# 2                                vroeg                        parlementair
# 3                             tevreden                         gezamenlijk
# 4                            excessief                           praktisch
# 5                            cultureel                           cultureel
# 6                            toenmalig                 grensoverschrijdend
# 7                           indicatief                           effectief
# 8                                stads                              extern
# 9                            zogenaamd                                nauw
#
#   opinion_36_Balkenende IV-Opposition opinion_36_Kok II-Government  \
# 0                        democratisch                 parlementair
# 1                        parlementair                 democratisch
# 2                              actief                    onderling
# 3                             normaal            gemeenschappelijk
# 4                           zogenaamd                  gezamenlijk
# 5                           praktisch                      normaal
# 6                           effectief                      formeel
# 7                         slagvaardig                         bang
# 8                               duits                       totaal
# 9                            tevreden                  interessant
#
#   opinion_36_Kok II-Opposition opinion_36_Rutte I-Government  \
# 0                     kritisch                  democratisch
# 1                        klaar         financieel-economisch
# 2                 parlementair                   interessant
# 3                  interessant                  parlementair
# 4                    werkelijk                     volstrekt
# 5                      formeel                        lastig
# 6                       aardig                        intern
# 7                  voortdurend                     cultureel
# 8                 fundamenteel                         reëel
# 9                  aanzienlijk                        extern
#
#   opinion_36_Rutte I-Opposition
# 0                  democratisch
# 1                   automatisch
# 2                   gezamenlijk
# 3                     onderling
# 4                       formeel
# 5                    historisch
# 6                     soeverein
# 7                         vroeg
# 8                   voortdurend
# 9                          nauw
#
# [10 rows x 13 columns]
#
# JSD: 0.965729941094
#           topic_47 opinion_47_Balkenende I-Government  \
# 0             dier                          gemiddeld
# 1    dierenwelzijn                       zelfslachten
# 2  volksgezondheid                              zwart
# 3            vlees                            normaal
# 4           verbod                           belgisch
# 5            jacht                       bovengenoemd
# 6           slacht                               wild
# 7             hond                          landelijk
# 8            zwijn                         ruimhartig
# 9       dierenarts                         antiviraal
#
#   opinion_47_Balkenende I-Opposition opinion_47_Balkenende II-Government  \
# 0                         ruimhartig                                ziek
# 1                         preventief                              streng
# 2                         kamerbreed                          preventief
# 3                          intensief                             ethisch
# 4                         israëlisch                             extreem
# 5                        voorzichtig                           menselijk
# 6                          langdurig                            geschikt
# 7                           volkomen                        handhaafbaar
# 8                    landschappelijk                            dusdanig
# 9                         antiviraal                              strikt
#
#   opinion_47_Balkenende II-Opposition opinion_47_Balkenende III-Government  \
# 0                           landelijk                              inheems
# 1                                wild                                wreed
# 2                            illegaal                             uitheems
# 3                            destijds                                kaaps
# 4                         commercieel                              primair
# 5                            prachtig                             parallel
# 6                            canadees                            gruwelijk
# 7                        substantieel                             barbaars
# 8                    wetenschappelijk                           zorgvuldig
# 9                           effectief                              genegen
#
#   opinion_47_Balkenende III-Opposition opinion_47_Balkenende IV-Government  \
# 0                            intensief                           ontuchtig
# 1                      diervriendelijk                          forensisch
# 2                            eindelijk                            seksueel
# 3                             duurzaam                                wild
# 4                    dieronvriendelijk                        gemeentelijk
# 5                                 wild                         minderjarig
# 6                              ethisch                           deskundig
# 7                             gangbaar                           effectief
# 8                               jammer                                dood
# 9                          plantaardig                    wetenschappelijk
#
#   opinion_47_Balkenende IV-Opposition opinion_47_Kok II-Government  \
# 0                           intensief                   veterinair
# 1                                wild                uitdrukkelijk
# 2                           deskundig                   preventief
# 3                         commercieel                        reëel
# 4                          preventief                     illegaal
# 5                     diervriendelijk                         wild
# 6                           effectief                       rustig
# 7                          houdverbod                         dood
# 8                                dood                    afrikaans
# 9                            seksueel                       gezond
#
#   opinion_47_Kok II-Opposition opinion_47_Rutte I-Government  \
# 0                    effectief                       ritueel
# 1                   preventief              wetenschappelijk
# 2                    afkomstig                     religieus
# 3                         wild                         joods
# 4                      ethisch                    intrinsiek
# 5                   veterinair                      regulier
# 6                      onnodig                    veterinair
# 7                       gezond                        humaan
# 8                   intrinsiek                    onbedwelmd
# 9                     algeheel                    sympathiek
#
#   opinion_47_Rutte I-Opposition
# 0              wetenschappelijk
# 1                       ritueel
# 2                 onafhankelijk
# 3                     religieus
# 4                    intrinsiek
# 5                      regulier
# 6                          dood
# 7                     intensief
# 8                          wild
# 9                    preventief
#
# [10 rows x 13 columns]
#
# JSD: 0.958278700399
#            topic_46 opinion_46_Balkenende I-Government  \
# 0      aanbesteding                            voldoen
# 1          opdracht                          uitvoerig
# 2             wapen                               duur
# 3            dienst                             bewust
# 4              bouw                             lastig
# 5  enquêtecommissie                             civiel
# 6     opdrachtgever                       parlementair
# 7        ministerie                           aanwezig
# 8           enquête                             rechts
# 9              goed                            privaat
#
#   opinion_46_Balkenende I-Opposition opinion_46_Balkenende II-Government  \
# 0                       parlementair                               zwart
# 1                          regionaal                              streng
# 2                           adequaat                          kamerbreed
# 3                        gezamenlijk                               mager
# 4                            voldoen                               licht
# 5                             actief                          vrijwillig
# 6                                mis                           makkelijk
# 7                            passief                          toekomstig
# 8                        structureel                           praktisch
# 9                        ondergronds                         voortdurend
#
#   opinion_46_Balkenende II-Opposition opinion_46_Balkenende III-Government  \
# 0                       huishoudelijk                         ministerieel
# 1                              divers                             belgisch
# 2                           uitvoerig                         onbelangrijk
# 3                            destijds                              integer
# 4                              scherp                          gemotiveerd
# 5                            tevreden                             benieuwd
# 6                              actief                             liberaal
# ...
# 5                   integraal                   biologisch
# 6                    ggo-vrij                    integraal
# 7                    duurzaam               oorspronkelijk
# 8            wetenschappelijk                    efficiënt
# 9                       groen                      primair
#
#   opinion_3_Rutte I-Opposition
# 0                     duurzaam
# 1                   ecologisch
# 2                    agrarisch
# 3                    intensief
# 4            gemeenschappelijk
# 5                   biologisch
# 6                    landelijk
# 7                       extern
# 8                  fatsoenlijk
# 9               programmatisch
#
# [10 rows x 13 columns]
#
# JSD: 0.767265440792
#                     topic_79 opinion_79_Balkenende I-Government  \
# 0                mensenrecht                        buitenlands
# 1  ontwikkelingssamenwerking                      terroristisch
# 2                     wereld                         bilateraal
# 3                organisatie                          egyptisch
# 4               ontwikkeling                             totaal
# 5                 terrorisme                          succesvol
# 6                       hulp                        binnenlands
# 7                    relatie                          volstrekt
# 8          ontwikkelingsland                           arabisch
# 9                      inzet                         israëlisch
#
#   opinion_79_Balkenende I-Opposition opinion_79_Balkenende II-Government  \
# 0                        buitenlands                         buitenlands
# 1                        amerikaanse                           effectief
# 2                           militair                              recent
# 3                         bilateraal                          bilateraal
# 4                         israëlisch                       multilateraal
# 5                          effectief                            mondiaal
# 6                               druk                            speciaal
# 7                             actief                         amerikaanse
# 8                         preventief                         gezamenlijk
# 9                            westers                          palestijns
#
#   opinion_79_Balkenende II-Opposition opinion_79_Balkenende III-Government  \
# 0                         buitenlands                            cultureel
# 1                           effectief                               iraaks
# 2                         amerikaanse                            technisch
# 3                            militair                            circulair
# 4                          palestijns                            evenredig
# 5                          humanitair                      rooms-katholiek
# 6                          bilateraal                          buitenlands
# 7                     transatlantisch                         onverstandig
# 8                          wereldwijd                          zorgwekkend
# 9                       terroristisch                      verschrikkelijk
#
#   opinion_79_Balkenende III-Opposition opinion_79_Balkenende IV-Government  \
# 0                          buitenlands                         buitenlands
# 1                               actief                           effectief
# 2                          amerikaanse                         diplomatiek
# 3                           palestijns                             fragiel
# 4                        terroristisch                         amerikaanse
# 5                             kritisch                          bilateraal
# 6                             sudanees                          palestijns
# 7                               iraans                            kritisch
# 8                            afrikaans                             westers
# 9                         reproductief                          humanitair
#
#   opinion_79_Balkenende IV-Opposition opinion_79_Kok II-Government  \
# 0                         buitenlands                     militair
# 1                         amerikaanse                  buitenlands
# 2                           effectief                   humanitair
# 3                              geheim                  amerikaanse
# 4                         diplomatiek                   bilateraal
# 5                          palestijns                          arm
# 6                                 arm                      westers
# 7                          wereldwijd                       actief
# 8                         islamitisch                     aanwezig
# 9                          israëlisch                terroristisch
#
#   opinion_79_Kok II-Opposition opinion_79_Rutte I-Government  \
# 0                     militair                        iraans
# 1                   palestijns                   buitenlands
# 2                  buitenlands                   islamitisch
# 3                  amerikaanse                         turks
# 4                   humanitair                   indonesisch
# 5                terroristisch                    palestijns
# 6                   israëlisch                      nucleair
# 7                   bilateraal                      militair
# 8                    effectief                 terroristisch
# 9                     afghaans                    bilateraal
#
#   opinion_79_Rutte I-Opposition
# 0                   buitenlands
# 1                      arabisch
# 2                    palestijns
# 3                     effectief
# 4                        iraans
# 5                      militair
# 6                        actief
# 7                   amerikaanse
# 8                   diplomatiek
# 9                    wereldwijd
#
# [10 rows x 13 columns]
#
# JSD: 0.695619352497
#      topic_61 opinion_61_Balkenende I-Government  \
# 0     verzoek                            plenair
# 1    stemming                                 na
# 2  spoeddebat                        buitenlands
# 3      agenda                          overbodig
# 4         uur                            actueel
# 5    behoefte                        interessant
# 6     uitstel                          wekelijks
# 7     bericht                        inhoudelijk
# 8   uitspraak                         uitstekend
# 9       reces                              trouw
#
#   opinion_61_Balkenende I-Opposition opinion_61_Balkenende II-Government  \
# 0                            plenair                             plenair
# 1                           aanwezig                         inhoudelijk
# 2                          mondeling                            aanwezig
# 3                              klaar                           aanstaand
# 4                            normaal                          zorgvuldig
# 5                          aanstaand                           volstrekt
# 6                            spoedig                             normaal
# 7                       gebruikelijk                              overig
# 8                        spoedeisend                           feitelijk
# 9                       demissionair                              jammer
#
#   opinion_61_Balkenende II-Opposition opinion_61_Balkenende III-Government  \
# 0                             plenair                              plenair
# 1                            aanwezig                            aanstaand
# 2                         inhoudelijk                              logisch
# 3                           aanstaand                       controversieel
# 4                             spoedig                               simpel
# 5                           overbodig                            onverkort
# 6                                  na                          jongstleden
# 7                              vreemd                               divers
# 8                            verleden                                   na
# 9                          zorgvuldig                           zorgvuldig
#
#   opinion_61_Balkenende III-Opposition opinion_61_Balkenende IV-Government  \
# 0                              plenair                          zorgvuldig
# 1                           zorgvuldig                         inhoudelijk
# 2                              spoedig                           anderhalf
# 3                          inhoudelijk                             plenair
# 4                       controversieel                           overbodig
# 5                               vreemd                           aanstaand
# 6                            aanstaand                           mondeling
# 7                          procedureel                         afhankelijk
# 8                                  dik                             onnodig
# 9                          tussentijds                            ontijdig
#
#   opinion_61_Balkenende IV-Opposition opinion_61_Kok II-Government  \
# 0                             plenair                      plenair
# 1                           anderhalf                  buitenlands
# 2                             spoedig                           na
# 3                         jongstleden                      spoedig
# 4                           aanstaand                    uitvoerig
# 5                          kamerbreed                    aanstaand
# 6                                diep                  procedureel
# 7                           mondeling                    mondeling
# 8                            vervelen                   zorgvuldig
# 9                         fatsoenlijk                      normaal
#
#   opinion_61_Kok II-Opposition opinion_61_Rutte I-Government  \
# 0                      plenair                       plenair
# 1               controversieel                       spoedig
# 2                      spoedig                   inhoudelijk
# 3                 demissionair                   buitenlands
# 4                  buitenlands                     aanstaand
# 5                     verleden                    definitief
# 6                     aanwezig                       voldoen
# 7                    aanstaand                     mondeling
# 8                           na                    zorgvuldig
# 9                    overbodig                      aanwezig
#
#   opinion_61_Rutte I-Opposition
# 0                       plenair
# 1                   inhoudelijk
# 2                       spoedig
# 3                     aanstaand
# 4                   buitenlands
# 5                      aanwezig
# 6                     mondeling
# 7                         apart
# 8                  onbeantwoord
# 9                     inclusief
#
# [10 rows x 13 columns]
#
# JSD: 0.692443739776
#          topic_12 opinion_12_Balkenende I-Government  \
# 0         memorie                        voorliggend
# 1     toelichting                            plenair
# 2          advies                         onderhavig
# 3   voorbereiding                           redelijk
# 4       wijziging                       ministerieel
# 5           state                          voorlopig
# 6   wetswijziging                           relevant
# 7  belangstelling                         letterlijk
# 8          begrip                          wezenlijk
# 9         verslag                    respectievelijk
#
#   opinion_12_Balkenende I-Opposition opinion_12_Balkenende II-Government  \
# 0                        voorliggend                         voorliggend
# 1                         onderhavig                           voorlopig
# 2                           relevant                           feitelijk
# 3                        principieel                          onderhavig
# 4                          zogenaamd                           uitvoerig
# 5                          wenselijk                            kritisch
# 6                          voorlopig                             plenair
# 7                          volstrekt                           wezenlijk
# 8                            logisch                        parlementair
# 9                           benieuwd                        fundamenteel
#
#   opinion_12_Balkenende II-Opposition opinion_12_Balkenende III-Government  \
# 0                         voorliggend                            voorlopig
# 1                           feitelijk                          voorliggend
# 2                           voorlopig                                   na
# 3                         principieel                             kritisch
# 4                          onderhavig                         parlementair
# 5                            kritisch                          afhankelijk
# 6                           toenmalig                          uitsluitend
# 7                            destijds                          principieel
# 8                             uiterst                               recent
# 9                               vroeg                            feitelijk
#
#   opinion_12_Balkenende III-Opposition opinion_12_Balkenende IV-Government  \
# 0                          voorliggend                         voorliggend
# 1                         fundamenteel                                  na
# 2                          uitsluitend                           voorlopig
# 3                              formeel                          onderhavig
# 4                           onmogelijk                             formeel
# 5                             benieuwd                            redelijk
# 6                                apart                         uitsluitend
# 7                               bewust                         principieel
# 8                               gerust                           feitelijk
# 9                           zorgvuldig                           uitvoerig
#
#   opinion_12_Balkenende IV-Opposition opinion_12_Kok II-Government  \
# 0                         voorliggend                  voorliggend
# 1                           voorlopig                   onderhavig
# 2                          onderhavig                     redelijk
# 3                           feitelijk                     relevant
# 4                      oorspronkelijk                    uitvoerig
# 5                          zorgvuldig                    expliciet
# 6                         inhoudelijk                  principieel
# 7                           wenselijk                      formeel
# 8                           expliciet                    wenselijk
# 9                         jongstleden                    voorlopig
#
#   opinion_12_Kok II-Opposition opinion_12_Rutte I-Government  \
# 0                  voorliggend                    onderhavig
# 1                    voorlopig                   voorliggend
# 2                   onderhavig                     technisch
# 3                    uitvoerig                     praktisch
# 4                     benieuwd                     voorlopig
# 5                          vol                   principieel
# 6                    zogenaamd                oorspronkelijk
# 7                      terzake                     zogenaamd
# 8                 aanvankelijk                     wenselijk
# 9                  interessant                     feitelijk
#
#   opinion_12_Rutte I-Opposition
# 0                   voorliggend
# 1                            na
# 2                        divers
# 3                     praktisch
# 4                   aanzienlijk
# 5                    onderhavig
# 6                      adequaat
# 7                        recent
# 8                oorspronkelijk
# 9                        overig
#
# [10 rows x 13 columns]
