# %% [markdown]
# # View CPT Results for experiment "all_years-adj-gov_opp"

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (10, 7)

# %% [markdown]
# ## Topic word perplexity

# %%
import os

def load_perplexity_results(results_dir):
    perplexity_topic = pd.read_csv(os.path.join(results_dir, 'perplexity_topic.csv'), index_col=0)
    perplexity_opinion = pd.read_csv(os.path.join(results_dir, 'perplexity_opinion.csv'), index_col=0)
    
    return perplexity_topic, perplexity_opinion

# %%
results_dir = '/home/jvdzwaan/data/dilipad/results/all_years/all_years-adj-gov_opp/'

# %%
perplexity_topic, perplexity_opinion = load_perplexity_results(results_dir)
perplexity_topic.plot();
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=medium. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
# change intervals if needed
intervals = ['20', '60', '80', '100', '180']

# %%
perplexity_topic[intervals].plot();

# %% [markdown]
# ## Opinion word perplexity

# %%
perplexity_opinion.plot();

# %%
perplexity_opinion[intervals].plot();

# %% [markdown]
# ## Results for topics and opinions

# %%
# choose optimal number of topics based on perplexity results
nTopics = 100

# %%
# load results
import glob
import os
import re

def load_experiment_results(nTopics, results_dir):

    # document topic matrix (theta)
    theta = pd.read_csv(os.path.join(results_dir, 'theta_{}.csv'.format(nTopics)), index_col=0)

    # phi topic (transposed)
    phi_topic_t = pd.read_csv(os.path.join(results_dir, 'topics_{}.csv'.format(nTopics)), index_col=0, encoding='utf-8')

    # phi opinion (transposed) per perspective
    opinion_files = glob.glob('{}/opinions_*_{}.csv'.format(results_dir, nTopics))
    phis_opinion_t = {}
    for f in opinion_files:
        m = re.match(r'.+opinions_(.+).csv', f)
        name = m.group(1).replace('_{}'.format(nTopics), '')
        phis_opinion_t[name] = pd.read_csv(f, index_col=0, encoding='utf-8')
    return theta, phi_topic_t, phis_opinion_t

# %%
theta, phi_topic_t, phis_opinion_t = load_experiment_results(nTopics, results_dir)

# %% [markdown]
# ### 'Weight' of the most important topic per document
#
# Each topic has a certain weight in the document. We would like to see one (or a few) topics with high weight per document. Below are some basic statistics on the most important topic (highest weight) per document.

# %%
def print_topic_weights(theta):
    a = theta.copy().apply(max, axis=1)
    a.sort(ascending=False)

    print 'Mean weight of most important topic: {} (std: {})'.format(a.mean(), a.std())
    print 'Min and max of most important topic: min: {}, max: {}'.format(a.min(), a.max())
    print 'Median weight of most important topic: ', a.median()

print_topic_weights(theta)
# Out:
# Mean weight of most important topic: 0.217946891107 (std: 0.127422739023)
# Min and max of most important topic: min: 0.01, max: 0.722204054938
# Median weight of most important topic:  0.202643409427

# %% [markdown]
# Line graph of the sorted topic weigths:

# %%
def plot_topic_weights(theta):
    theta.copy().apply(lambda row:sorted(row)[::-1], axis=1).transpose().plot(legend=None);

plot_topic_weights(theta)

# %% [markdown]
# ### Number of topics per document
#
# The number of topics per document is calculated by counting the number of topic with weight above a certain threshold. The numer of topics per document should (roughly) be equivalent to the number of ``pm:topic``s per document (however, at the moment we do not have statistics of this).

# %%
def display_number_of_topics_per_document(theta, threshold=0.05):
    topic_counts = theta.apply(lambda row: np.sum(row > threshold), axis=1)
    print topic_counts.value_counts(sort=False)
    topic_counts.hist(bins=len(topic_counts.value_counts()), figsize=(5,3));

display_number_of_topics_per_document(theta)
# Out:
# 0     975
# 8       7
# 1    2159
# 9       1
# 2    2965
# 3    2988
# 4    1953
# 5     868
# 6     318
# 7      66
# dtype: int64

# %% [markdown]
# ### Topics

# %%
def show_topic(t, top=10):
    """Return dataframe containing <top> topic words, weights of topic words and per perspective opinion words and
    weigths of opinion words.
    
    Parameters
        t : str - index of topic number
        top : int - the number of words to store in the dataframe
    
    Returns Pandas DataFrame
    """
    topic = phi_topic_t[t].copy()
    topic.sort(ascending=False)
    topic = topic[0:top]
    df_t = pd.DataFrame(topic)
    df_t.reset_index(level=0, inplace=True)
    df_t.columns = ['topic_{}'.format(t), 'weights_topic_{}'.format(t)]

    dfs = [df_t]

    for p, o in phis_opinion_t.iteritems():
        opinion = o[t].copy()
        opinion.sort(ascending=False)
        opinion = opinion[0:top]
        df_o = pd.DataFrame(opinion)
        df_o.reset_index(level=0, inplace=True)
        df_o.columns = ['opinion_{}_{}'.format(t, p), 'weights_opinion_{}_{}'.format(t, p)]
        dfs.append(df_o)
        
    return pd.concat(dfs, axis=1)

def print_topics(phi_topic_t, phis_opinion_t, nTopics):
    jsd = None
    jsdFile = os.path.join(results_dir, 'jsd_{}.csv'.format(nTopics))
    if os.path.isfile(jsdFile):
        print 'Ordering topics by Jensen-Shannon divergence of the opinions'
        print
        jsd = pd.read_csv(jsdFile, index_col=0)
        r = jsd.sort(['jsd'], ascending=False)
        print 'Min jsd: {}, max jsd: {}'.format(np.min(jsd['jsd']), np.max(jsd['jsd']))
        print 'Average jsd: {} (std: {}), median jsd: {}'.format(np.mean(jsd['jsd']), np.std(jsd['jsd']), np.median(jsd['jsd']))
        print
        loop = r.index
    else:
        print 'Ordering topics by topic number'
        print '(To order topics by Jensen-Shannon divergence of the opinions run the experiment_jsd_opinions script.)'
        print
        loop = range(nTopics)
    for i in loop:
        if not jsd is None:
            print 'JSD:', jsd.at[i, 'jsd']
        pLabels = ['opinion_{}_{}'.format(i, p) for p, o in phis_opinion_t.iteritems()]
        print show_topic(str(i))[['topic_{}'.format(i)] + pLabels]
        print

# %%
print_topics(phi_topic_t, phis_opinion_t, nTopics)
# Out:
# Ordering topics by Jensen-Shannon divergence of the opinions
#
# Min jsd: 0.160444381982, max jsd: 0.358576408916
# Average jsd: 0.25241102491 (std: 0.0410429059655), median jsd: 0.248299335581
#
# JSD: 0.358576408916
#       topic_28 opinion_28_Opposition opinion_28_Government
# 0  aanbeveling         onafhankelijk          parlementair
# 1    convenant             expliciet                    na
# 2       proces          parlementair           inhoudelijk
# 3         hart           afhankelijk             waardevol
# 4         stap               primair              aanwezig
# 5        regel             tijdelijk            essentieel
# 6   uitvoering              kritisch           transparant
# 7  verbetering             ongewenst                jammer
# 8     opdracht           onduidelijk            toekomstig
# 9     monument                   vol              tevreden
#
# [10 rows x 3 columns]
#
# JSD: 0.336982366296
#           topic_69 opinion_69_Opposition opinion_69_Government
# 0           dienst         huishoudelijk              redelijk
# 1     aanbesteding           commercieel            onmogelijk
# 2        kwaliteit              minimaal           commercieel
# 3         contract              goedkoop             zogenaamd
# 4              eis           fatsoenlijk             technisch
# 5            prijs                gratis                 klaar
# 6         opdracht               logisch           ingewikkeld
# 7        aanbieder           ingewikkeld             efficiënt
# 8           aanbod             efficiënt               onnodig
# 9  dienstverlening           kwalitatief               normaal
#
# [10 rows x 3 columns]
#
# JSD: 0.329219403456
#          topic_84 opinion_84_Opposition opinion_84_Government
# 0       consument              duurzaam        administratief
# 1          sector        administratief             oneerlijk
# 2          schuld            vrijwillig              maximaal
# 3         product              illegaal            collectief
# 4  zelfregulering             effectief              redelijk
# 5            hout              malafide              negatief
# 6           markt             makkelijk              tevreden
# 7            bouw            behoorlijk         belanghebbend
# 8       schikking              maximaal                lastig
# 9         branche                    na                bewust
#
# [10 rows x 3 columns]
#
# JSD: 0.327668148663
#          topic_70 opinion_70_Opposition opinion_70_Government
# 0      experiment               primair            zorgvuldig
# 1       invoering               voldoen           automatisch
# 2            veld             landelijk             tijdelijk
# 3        knelpunt                divers             regionaal
# 4           regel           structureel                totaal
# 5         bestuur            zorgvuldig                    na
# 6    deregulering            behoorlijk           gezamenlijk
# 7          risico             materieel           structureel
# 8  randvoorwaarde              adequaat             eenvoudig
# 9      voorwaarde             integraal           principieel
#
# [10 rows x 3 columns]
#
# JSD: 0.320700142433
#        topic_32 opinion_32_Opposition opinion_32_Government
# 0          stad               voldoen          gemeentelijk
# 1          wijk                   vol             landelijk
# 2         buurt              goedkoop                  waar
# 3        aanpak             stedelijk             stedelijk
# 4          huis             landelijk                divers
# 5       bewoner             integraal                veilig
# 6   huisvesting          substantieel             zogenaamd
# 7  problematiek                  leuk                actief
# 8         regio             tijdelijk               normaal
# 9  leefbaarheid          gemeentelijk            ruimtelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.319783964229
#       topic_96 opinion_96_Opposition opinion_96_Government
# 0   buitenland            gevaarlijk           buitenlands
# 1       fraude             genetisch      wetenschappelijk
# 2         stof              chemisch             genetisch
# 3       risico                veilig                streng
# 4        lijst      wetenschappelijk              chemisch
# 5    toelating            schadelijk        landbouwkundig
# 6  beoordeling           buitenlands            gevaarlijk
# 7   toepassing                streng             blijkbaar
# 8    criterium              aanwezig              kritisch
# 9       effect         onafhankelijk              aanwezig
#
# [10 rows x 3 columns]
#
# JSD: 0.317527683736
#         topic_1 opinion_1_Opposition opinion_1_Government
# 0         water        archeologisch            integraal
# 1    waterschap              primair           ruimtelijk
# 2   alternatief             indirect             indirect
# 3         schip               vlaams          gezamenlijk
# 4         haven               schoon                  sec
# 5  ontpoldering     wetenschappelijk               divers
# 6    veiligheid         gemeentelijk              primair
# 7          dijk               zeeuws            technisch
# 8  financiering            zogenaamd            efficiënt
# 9        rivier          alternatief        archeologisch
#
# [10 rows x 3 columns]
#
# JSD: 0.315049390002
#   topic_86 opinion_86_Opposition opinion_86_Government
# 0    maand             blijkbaar                  half
# 1  signaal                  fout                jammer
# 2  bericht                  waar                tijdig
# 3  gesprek                  half                  fout
# 4    actie                   mis                 klaar
# 5     fout          onacceptabel            definitief
# 6  contact             eindelijk                  waar
# 7     gang           jongstleden               onnodig
# 8   onrust        onaanvaardbaar             jarenlang
# 9   hoogte                   vol             anderhalf
#
# [10 rows x 3 columns]
#
# JSD: 0.311382651703
#          topic_53 opinion_53_Opposition opinion_53_Government
# 0      vergunning          parlementair          parlementair
# 1         besluit                tijdig            zorgvuldig
# 2  bestuursorgaan               ethisch             volstrekt
# 3          sector         belanghebbend               bevoegd
# 4          verbod                  bont              redelijk
# 5          advies              redelijk                tijdig
# 6     verordening                 reëel         belanghebbend
# 7     investering             eenvoudig                streng
# 8         bestuur             werkelijk                scherp
# 9        aanvraag              geschikt              relevant
#
# [10 rows x 3 columns]
#
# JSD: 0.310194368239
#       topic_67 opinion_67_Opposition opinion_67_Government
# 0   voorwaarde             voorlopig        voorwaardelijk
# 1     advocaat             deskundig            forensisch
# 2           tb        voorwaardelijk             deskundig
# 3      notaris                veilig         psychiatrisch
# 4  samenleving                actief             blijkbaar
# 5           er            levenslang            levenslang
# 6  beëindiging             wenselijk          gebruikelijk
# 7  gemeenschap          onmiddellijk                  duur
# 8      periode             notarieel              destijds
# 9       verlof                  fout             notarieel
#
# [10 rows x 3 columns]
#
# JSD: 0.308761337327
#        topic_4 opinion_4_Opposition opinion_4_Government
# 0      systeem               actief           zorgvuldig
# 1    invoering          ingewikkeld               bewust
# 2      stelsel          principieel          ingewikkeld
# 3        keuze            feitelijk               divers
# 4      bezwaar           zorgvuldig            feitelijk
# 5         idee            technisch                klaar
# 6      prikkel               bewust       administratief
# 7  systematiek       administratief             centraal
# 8     voordeel            gemiddeld            effectief
# 9        donor               moreel               actief
#
# [10 rows x 3 columns]
#
# JSD: 0.307728343221
#             topic_75 opinion_75_Opposition opinion_75_Government
# 0            premier           inhoudelijk           inhoudelijk
# 1      regeerakkoord                   vol             volstrekt
# 2           coalitie             blijkbaar               normaal
# 3          oppositie            letterlijk            letterlijk
# 4           mijnheer              dadelijk                 links
# 5           politiek             volstrekt                totaal
# 6     coalitiepartij                  waar             eindelijk
# 7         verklaring                  bang             toenmalig
# 8  fractievoorzitter                 links                stevig
# 9          standpunt                simpel            onmogelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.306629521227
#        topic_82 opinion_82_Opposition opinion_82_Government
# 0       vervoer            decentraal            decentraal
# 1      reiziger                  duur                veilig
# 2         kaart                gratis                  duur
# 3     concessie             landelijk                  krom
# 4    vervoerder                 stads               privaat
# 5  ov-chipkaart                veilig           betrouwbaar
# 6         trein                  fors                 kwijt
# 7           bus                 blind   grensoverschrijdend
# 8          stad             voorlopig                 stads
# 9          lijn             blijkbaar                aardig
#
# [10 rows x 3 columns]
#
# JSD: 0.302402370911
#          topic_60 opinion_60_Opposition opinion_60_Government
# 0               d               akkoord           inhoudelijk
# 1         akkoord           inhoudelijk              tevreden
# 2           inzet              tevreden               akkoord
# 3  onderhandeling               voldoen                 klaar
# 4            stap              cruciaal               logisch
# 5       resultaat               uiterst             werkelijk
# 6           tafel          demissionair            ontzettend
# 7       draagvlak             werkelijk              maximaal
# 8     meerderheid            definitief              aanwezig
# 9        uitkomst            onmogelijk             eindelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.301058790219
#           topic_5 opinion_5_Opposition opinion_5_Government
# 0            norm             omwonend               schoon
# 1  luchtkwaliteit               schoon            effectief
# 2          geluid        gelijkwaardig                 stil
# 3          risico            landelijk                 fijn
# 4          effect            technisch              voldoen
# 5         bewoner                 stil               streng
# 6           grens             maximaal             omwonend
# 7      gezondheid             gevoelig            feitelijk
# 8           lucht                 ruim          ingewikkeld
# 9        omgeving               streng             gevoelig
#
# [10 rows x 3 columns]
#
# JSD: 0.300973048417
#           topic_57 opinion_57_Opposition opinion_57_Government
# 0           klacht         onafhankelijk         onafhankelijk
# 1        ombudsman                actief           structureel
# 2             taak            behoorlijk             jaarlijks
# 3        instituut           inhoudelijk               jeugdig
# 4      jaarverslag                divers                 apart
# 5            loket              kritisch              kritisch
# 6  kinderombudsman             jaarlijks              centraal
# 7      organisatie           structureel             wenselijk
# 8        instantie                lastig           inhoudelijk
# 9      bevoegdheid                 apart                intern
#
# [10 rows x 3 columns]
#
# JSD: 0.299057741315
#           topic_13 opinion_13_Opposition opinion_13_Government
# 0            grond             permanent             permanent
# 1       instrument            ruimtelijk             effectief
# 2         eigenaar              redelijk          gemeentelijk
# 3     overeenkomst             onroerend             technisch
# 4             pand          gemeentelijk            ruimtelijk
# 5  instrumentarium                actief              aanwezig
# 6             nota             effectief                actief
# 7             huis                nuttig           ingewikkeld
# 8         eigendom              centraal                  leeg
# 9   voorkeursrecht             zogenaamd           particulier
#
# [10 rows x 3 columns]
#
# JSD: 0.297620746203
#    topic_88 opinion_88_Opposition opinion_88_Government
# 0    kennis              kritisch              aanwezig
# 1      fase           inhoudelijk             deskundig
# 2    risico              cruciaal              kritisch
# 3   kritiek             toenmalig            zorgvuldig
# 4     beeld             feitelijk                    na
# 5    advies                divers                 vroeg
# 6    proces             deskundig             toenmalig
# 7   periode              destijds                divers
# 8  opdracht             volstrekt               uiterst
# 9     begin          parlementair              relevant
#
# [10 rows x 3 columns]
#
# JSD: 0.297226452861
#          topic_43 opinion_43_Opposition opinion_43_Government
# 0      vertrouwen           persoonlijk                  waar
# 1      bewindsman               onjuist                   vol
# 2           beeld              kritisch            zorgvuldig
# 3       interview             werkelijk                 klaar
# 4  bewindspersoon                  fout             blijkbaar
# 5         kwestie                  waar             volstrekt
# 6        politiek             blijkbaar                scherp
# 7           krant            letterlijk                  fout
# 8          gevoel                 klaar               onjuist
# 9         verhaal                   mis                stevig
#
# [10 rows x 3 columns]
#
# JSD: 0.296161189379
#        topic_99 opinion_99_Opposition opinion_99_Government
# 0       cultuur             cultureel             cultureel
# 1      subsidie             succesvol                 apart
# 2     stichting           inhoudelijk            historisch
# 3         fonds            historisch               privaat
# 4    instelling                 apart             overbodig
# 5         kunst      wetenschappelijk                gratis
# 6   organisatie              creatief                vreemd
# 7        museum           particulier                 uniek
# 8    activiteit                gratis                divers
# 9  geschiedenis           zelfstandig             regionaal
#
# [10 rows x 3 columns]
#
# JSD: 0.294037170427
#       topic_34 opinion_34_Opposition opinion_34_Government
# 0      verdrag            historisch        grondwettelijk
# 1   minderheid        grondwettelijk          parlementair
# 2    parlement           buitenlands            bilateraal
# 3     protocol            bilateraal             praktisch
# 4  goedkeuring                  ruim                dubbel
# 5      werking              belgisch                 duits
# 6        staat          rechtstreeks                  ruim
# 7          hof                  iers            historisch
# 8  ratificatie                vreemd              belgisch
# 9       comité                dubbel   grensoverschrijdend
#
# [10 rows x 3 columns]
#
# JSD: 0.292824100654
#      topic_66 opinion_66_Opposition opinion_66_Government
# 0      sector           structureel           structureel
# 1  wachtlijst               voldoen               voldoen
# 2      cijfer             gemiddeld                  fors
# 3      tekort              regulier              regulier
# 4      aanpak                  fors                recent
# 5   personeel                  ruim              centraal
# 6     oorzaak             jarenlang                 paars
# 7  capaciteit             jaarlijks                 vroeg
# 8    knelpunt             blijkbaar          substantieel
# 9    werkdruk              tevreden             zorgelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.291116839041
#        topic_17 opinion_17_Opposition opinion_17_Government
# 0     evaluatie             effectief             uitvoerig
# 1        effect              kritisch              negatief
# 2       element             uitvoerig              kritisch
# 3          maat             voorlopig              relevant
# 4    benadering                 reëel             wezenlijk
# 5       opzicht            behoorlijk           aanzienlijk
# 6      noodzaak                    na               voldoen
# 7  ontwikkeling             zogenaamd            allereerst
# 8       twijfel                totaal             werkelijk
# 9    instrument                gering                 reëel
#
# [10 rows x 3 columns]
#
# JSD: 0.286147146362
#          topic_36 opinion_36_Opposition opinion_36_Government
# 0         memorie           voorliggend           voorliggend
# 1     toelichting            onderhavig             voorlopig
# 2          begrip                  ruim            onderhavig
# 3       criterium               plenair                    na
# 4           grond             uitvoerig              adequaat
# 5   voorbereiding              relevant             uitvoerig
# 6         verslag                    na             wenselijk
# 7       definitie             feitelijk              redelijk
# 8        argument           jongstleden                  ruim
# 9  belangstelling               voldoen              denkbaar
#
# [10 rows x 3 columns]
#
# JSD: 0.282925908207
#         topic_85 opinion_85_Opposition opinion_85_Government
# 0     ondernemer        administratief        administratief
# 1           last           zelfstandig           zelfstandig
# 2  bedrijfsleven           toeristisch             regionaal
# 3            mkb                divers                actief
# 4    onderneming             regionaal              centraal
# 5     ministerie                  ruim                jammer
# 6          regel              prachtig            innovatief
# 7         midden           gezamenlijk               fiscaal
# 8   kleinbedrijf               onnodig          substantieel
# 9             ez                vreemd              digitaal
#
# [10 rows x 3 columns]
#
# JSD: 0.279567377611
#             topic_24 opinion_24_Opposition opinion_24_Government
# 0         vergoeding           zelfstandig           zelfstandig
# 1             schade            collectief           principieel
# 2        verzekering              redelijk         aansprakelijk
# 3             bedrag         aansprakelijk          onrechtmatig
# 4             kracht          onmiddellijk        oorspronkelijk
# 5        slachtoffer                 recht             uitvoerig
# 6  overgangsregeling           persoonlijk           uitsluitend
# 7            persoon               billijk                  ruim
# 8     overgangsrecht            onredelijk             feitelijk
# 9            werking            burgerlijk              redelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.275929753495
#          topic_14 opinion_14_Opposition opinion_14_Government
# 0     bezuiniging                  fors                  fors
# 1      hervorming                  rijk              pijnlijk
# 2            baan                 links             gemiddeld
# 3        economie                totaal           structureel
# 4           keuze             kwetsbaar             eindelijk
# 5       begroting           structureel                gezond
# 6          crisis           hardwerkend                 links
# 7          effect                  duur             werkelijk
# 8          cijfer              werkloos                stevig
# 9  tegenbegroting                  waar            allereerst
#
# [10 rows x 3 columns]
#
# JSD: 0.27363141557
#            topic_97 opinion_97_Opposition opinion_97_Government
# 0        veiligheid            gevaarlijk                veilig
# 1              ramp              adequaat             integraal
# 2         brandweer         onafhankelijk            gevaarlijk
# 3  veiligheidsregio                veilig              centraal
# 4      vrijwilliger             regionaal             eenduidig
# 5             brand              aanwezig         onafhankelijk
# 6        handhaving             landelijk                bewust
# 7            risico            vrijwillig                    na
# 8             regel          ministerieel                extern
# 9           ongeval                  dood                actief
#
# [10 rows x 3 columns]
#
# JSD: 0.272520295089
#        topic_38 opinion_38_Opposition opinion_38_Government
# 0   samenleving              centraal              centraal
# 1      politiek          fundamenteel             cultureel
# 2         visie             wezenlijk           interessant
# 3  ontwikkeling                modern           persoonlijk
# 4         staat          parlementair                actief
# 5         thema             cultureel          democratisch
# 6     opvatting             zichtbaar              kritisch
# 7      bijdrage            uitstekend                bewust
# 8          eeuw                  waar                 vroeg
# 9    democratie       vanzelfsprekend     gemeenschappelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.271543005074
#            topic_62 opinion_62_Opposition opinion_62_Government
# 0         indiening         onafhankelijk         onafhankelijk
# 1            dictum               spoedig             uiterlijk
# 2           besluit             wenselijk           onwenselijk
# 3            risico             overbodig              aanwezig
# 4                 f           onwenselijk              relevant
# 5         industrie                  duur           onvoldoende
# 6           toestel                tijdig             technisch
# 7   volksgezondheid             technisch            definitief
# 8  belastingbetaler              kritisch                totaal
# 9        sp-fractie             effectief            zorgvuldig
#
# [10 rows x 3 columns]
#
# JSD: 0.270742041695
#         topic_26 opinion_26_Opposition opinion_26_Government
# 0           auto               fiscaal               fiscaal
# 1        heffing                  duur                zuinig
# 2      belasting                 groen            elektrisch
# 3         effect             effectief           ingewikkeld
# 4      verhoging                zuinig           principieel
# 5  belastingplan           ingewikkeld                 groen
# 6         tarief             gemiddeld                schoon
# 7    vergroening              goedkoop                  duur
# 8          prijs                schoon                totaal
# 9      invoering                  fors            budgettair
#
# [10 rows x 3 columns]
#
# JSD: 0.270629653357
#                   topic_18 opinion_18_Opposition opinion_18_Government
# 0                   oorlog              militair              militair
# 1                resolutie           amerikaanse                actief
# 2                  verzoek      volkenrechtelijk             wenselijk
# 3                  besluit           buitenlands           amerikaanse
# 4                standpunt                actief           buitenlands
# 5  massavernietigingswapen            humanitair              seksueel
# 6               bewijslast            preventief              destijds
# 7                      vis             wenselijk                totaal
# 8                     druk              seksueel              maximaal
# 9                    vrede             ongewenst           gezamenlijk
#
# [10 rows x 3 columns]
#
# JSD: 0.26918173453
#         topic_59 opinion_59_Opposition opinion_59_Government
# 0          boete                 zwart       strafrechtelijk
# 1     handhaving       strafrechtelijk    bestuursrechtelijk
# 2        sanctie    bestuursrechtelijk                 zwart
# 3    overtreding             effectief             effectief
# 4     luchthaven             strafbaar           principieel
# 5          kaart              maximaal                 licht
# 6       controle              redelijk              maximaal
# 7         handel             feitelijk            preventief
# 8  bestuursrecht            preventief            koninklijk
# 9     strafrecht             ongewenst             ongewenst
#
# [10 rows x 3 columns]
#
# JSD: 0.266718452456
#          topic_3 opinion_3_Opposition opinion_3_Government
# 0          ouder         kindgebonden         kindgebonden
# 1   kinderopvang        buitenschools         alleenstaand
# 2         opvang        tussenschools            landelijk
# 3      kwaliteit         alleenstaand            informeel
# 4          gezin                 duur             minimaal
# 5  kinderbijslag            naschools               lastig
# 6          vrouw           betaalbaar             redelijk
# 7      gastouder          pedagogisch               veilig
# 8       bijdrage            informeel              logisch
# 9         budget               gratis              formeel
#
# [10 rows x 3 columns]
#
# JSD: 0.265442618792
#         topic_42 opinion_42_Opposition opinion_42_Government
# 0      richtlijn               formeel               formeel
# 1      wetgeving             technisch        administratief
# 2    regelgeving                  ruim         uitdrukkelijk
# 3          regel           ingewikkeld           voorliggend
# 4  implementatie        administratief          ministerieel
# 5       bepaling               onnodig             praktisch
# 6    bescherming                tijdig             overbodig
# 7            kop             eenvoudig                  ruim
# 8    verordening             wenselijk             materieel
# 9     toepassing                lastig         desbetreffend
#
# [10 rows x 3 columns]
#
# JSD: 0.265359236361
#         topic_19 opinion_19_Opposition opinion_19_Government
# 0       pensioen            toekomstig            vrijwillig
# 1  pensioenfonds             gemiddeld               fiscaal
# 2            aow               fiscaal           zelfstandig
# 3        partner            collectief            collectief
# 4      werknemer    pensioengerechtigd            toekomstig
# 5      werkgever                 jarig            essentieel
# 6       leeftijd                  rijk             gemiddeld
# 7          fonds           evenwichtig                totaal
# 8        bestuur               onnodig                 jarig
# 9      deelnemer                actief           evenwichtig
#
# [10 rows x 3 columns]
#
# JSD: 0.265348118416
#         topic_45 opinion_45_Opposition opinion_45_Government
# 0     toezegging              tevreden              tevreden
# 1  beantwoording             uitvoerig             hartelijk
# 2  duidelijkheid                jammer             uitvoerig
# 3        aanzien                lastig             overbodig
# 4      werkgroep             hartelijk            allereerst
# 5           hart                scherp         uitdrukkelijk
# 6      suggestie             overbodig            uitbreiden
# 7           slot                aardig                lastig
# 8           paar                 klaar                scherp
# 9      bedoeling             mondeling            uitgebreid
#
# [10 rows x 3 columns]
#
# JSD: 0.263589491813
#         topic_76 opinion_76_Opposition opinion_76_Government
# 0       economie              duurzaam              duurzaam
# 1   ontwikkeling                recent            innovatief
# 2      innovatie           structureel             succesvol
# 3          groei            innovatief            toekomstig
# 4          visie              krachtig                recent
# 5    investering             zogenaamd           gezamenlijk
# 6  bedrijfsleven           interessant             integraal
# 7   doelstelling                  rijk          fundamenteel
# 8        terrein              centraal                  fors
# 9         kennis                 vroeg         aantrekkelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.263232456551
#       topic_23 opinion_23_Opposition opinion_23_Government
# 0   ministerie             ambtelijk             ambtelijk
# 1    ambtenaar                intern                intern
# 2  integriteit         onafhankelijk                extern
# 3        regel       strafrechtelijk              kritisch
# 4  departement                extern              relevant
# 5      kwestie               onderst               integer
# 6     Justitie             volstrekt         vertrouwelijk
# 7  organisatie                vreemd         onafhankelijk
# 8       hoogte               onjuist                   mis
# 9       bureau               integer              destijds
#
# [10 rows x 3 columns]
#
# JSD: 0.261494631404
#                 topic_49 opinion_49_Opposition opinion_49_Government
# 0              begroting           structureel           structureel
# 1                 bedrag                  fors                 apart
# 2                    mln            budgettair                  fors
# 3                   euro                totaal            behoorlijk
# 4                dekking             jaarlijks            deugdelijk
# 5                 budget              ongedaan             jaarlijks
# 6                 gulden          substantieel           incidenteel
# 7             ministerie                jammer            sympathiek
# 8  begrotingsbehandeling                  waar                  waar
# 9           financiering                divers                  half
#
# [10 rows x 3 columns]
#
# JSD: 0.258570039505
#            topic_2 opinion_2_Opposition opinion_2_Government
# 0       ziekenhuis                acuut              medisch
# 1        kwaliteit              medisch                acuut
# 2            fusie            regionaal          spoedeisend
# 3            regio          spoedeisend           bereikbaar
# 4       specialist            landelijk              voldoen
# 5   bereikbaarheid          kwalitatief            integraal
# 6       instelling           volwaardig            regionaal
# 7  zorgverzekeraar           bereikbaar            doelmatig
# 8     marktwerking                dicht           academisch
# 9   zorginstelling            doelmatig          kwalitatief
#
# [10 rows x 3 columns]
#
# JSD: 0.25818456467
#          topic_30 opinion_30_Opposition opinion_30_Government
# 0           markt               privaat               privaat
# 1    marktwerking           commercieel              redelijk
# 2    concurrentie           zelfstandig           buitenlands
# 3       consument              redelijk         onafhankelijk
# 4           prijs               normaal           commercieel
# 5   privatisering                actief                actief
# 6  liberalisering              liberaal               voldoen
# 7          sector           fatsoenlijk              relevant
# 8         aandeel              ongelijk              goedkoop
# 9  toezichthouder              goedkoop                 duits
#
# [10 rows x 3 columns]
#
# JSD: 0.25671840934
#       topic_77 opinion_77_Opposition opinion_77_Government
# 0         taal            allochtoon            allochtoon
# 1   integratie            marokkaans            marokkaans
# 2  samenleving                 turks            autochtoon
# 3  inburgering            autochtoon                 turks
# 4  bezuiniging            vrijwillig             cultureel
# 5       niveau          niet-westers               kansarm
# 6  allochtonen                totaal              redelijk
# 7       kennis               etnisch            behoorlijk
# 8      migrant      wetenschappelijk        multicultureel
# 9   nieuwkomer            ontzettend             blijkbaar
#
# [10 rows x 3 columns]
#
# JSD: 0.254738460702
#        topic_41 opinion_41_Opposition opinion_41_Government
# 0          boek              duurzaam              duurzaam
# 1  doelstelling                schoon      wetenschappelijk
# 2       energie                gratis                 groen
# 3        milieu                 groen                schoon
# 4    schoolboek      wetenschappelijk                gratis
# 5       klimaat                zuinig               fossiel
# 6      uitstoot            wereldwijd                  duur
# 7         prijs              goedkoop                zuinig
# 8   boekenprijs               fossiel             efficiënt
# 9      reductie             ambitieus           afhankelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.253738005746
#            topic_87 opinion_87_Opposition opinion_87_Government
# 0     nationaliteit                dubbel                dubbel
# 1          paspoort            marokkaans             tijdelijk
# 2        verklaring                 turks            marokkaans
# 3  nederlanderschap             tijdelijk              regulier
# 4            aanpak            meervoudig            meervoudig
# 5            kracht                vreemd                vreemd
# 6  bolletjesslikker                gratis                gratis
# 7           persoon           principieel             volstrekt
# 8      drugskoerier               geboren              maximaal
# 9             leges          fundamenteel              centraal
#
# [10 rows x 3 columns]
#
# JSD: 0.253737028608
#          topic_94 opinion_94_Opposition opinion_94_Government
# 0            bank              failliet               privaat
# 1          crisis               privaat              centraal
# 2          risico            commissie-           amerikaanse
# 3          sector              centraal             tijdelijk
# 4          lening                   wit                streng
# 5  toezichthouder                gezond                 reëel
# 6      instelling              duurzaam                gezond
# 7           bonus                 reëel                totaal
# 8           staat               pervers              duurzaam
# 9   kredietcrisis              maximaal                moreel
#
# [10 rows x 3 columns]
#
# JSD: 0.249833020312
#             topic_63 opinion_63_Opposition opinion_63_Government
# 0             advies         onafhankelijk           rechterlijk
# 1              state           rechterlijk          gerechtelijk
# 2            college             deskundig         onafhankelijk
# 3        rechtspraak          gerechtelijk          rechtstreeks
# 4              macht          fundamenteel                 apart
# 5           afdeling           ingewikkeld             eenvoudig
# 6  onafhankelijkheid                dubbel           voorliggend
# 7         advisering             wenselijk         professioneel
# 8        organisatie             tijdelijk             deskundig
# 9               taak                    na                civiel
#
# [10 rows x 3 columns]
#
# JSD: 0.249816754521
#                  topic_91 opinion_91_Opposition opinion_91_Government
# 0                indiener           principieel           principieel
# 1         initiatiefnemer            sympathiek             expliciet
# 2  initiatiefwetsvoorstel            collectief        oorspronkelijk
# 3              initiatief           persoonlijk             overbodig
# 4      initiatiefvoorstel           voorliggend           voorliggend
# 5                 bezwaar              kritisch            sympathiek
# 6               wetgeving                  ruim            allereerst
# 7                argument           interessant                jammer
# 8              waardering               normaal           interessant
# 9            woordvoerder             overbodig             praktisch
#
# [10 rows x 3 columns]
#
# JSD: 0.249710544476
#            topic_90 opinion_90_Opposition opinion_90_Government
# 0           salaris                moreel          semi-publiek
# 1        bestuurder               privaat        beursgenoteerd
# 2            sector          semi-publiek              variabel
# 3       onderneming               normaal               privaat
# 4     aandeelhouder        beursgenoteerd                moreel
# 5          beloning                gouden           transparant
# 6  ondernemingsraad             excessief           semipubliek
# 7             bonus           semipubliek             volstrekt
# 8               top               logisch             onderling
# 9       commissaris             volstrekt             excessief
#
# [10 rows x 3 columns]
#
# JSD: 0.248807551254
#       topic_48 opinion_48_Opposition opinion_48_Government
# 0        vrouw             langdurig           zelfstandig
# 1          man             tijdelijk             tijdelijk
# 2       arbeid                  ziek                  ziek
# 3       verlof          alleenstaand             langdurig
# 4       ziekte            vrouwelijk              maximaal
# 5      periode             driekwart               zwanger
# 6   zorgverlof            burgerlijk            kortdurend
# 7      partner            collectief              aanwezig
# 8   vervanging            kortdurend          alleenstaand
# 9  uitbreiding           persoonlijk           zwaarwegend
#
# [10 rows x 3 columns]
#
# JSD: 0.247791119908
#       topic_29 opinion_29_Opposition opinion_29_Government
# 0     bijdrage           gehandicapt           gehandicapt
# 1  alternatief          gemeentelijk          gemeentelijk
# 2  voorziening             chronisch             chronisch
# 3    beperking              redelijk             landelijk
# 4     handicap                  duur              centraal
# 5         last           alternatief                gratis
# 6  afschaffing                gratis          toegankelijk
# 7    autonomie          toegankelijk                  duur
# 8    belasting                  ziek           onevenredig
# 9          ozb             blijkbaar             praktisch
#
# [10 rows x 3 columns]
#
# JSD: 0.247523115168
#       topic_73 opinion_73_Opposition opinion_73_Government
# 0         euro          democratisch             permanent
# 1    parlement                grieks                grieks
# 2          top              monetair           gezamenlijk
# 3         unie           automatisch                stevig
# 4  bevoegdheid                stevig                streng
# 5     lidstaat           gezamenlijk             zogenaamd
# 6    noodfonds                 duits                intern
# 7        markt             permanent             tijdelijk
# 8       schuld                streng              krachtig
# 9      sanctie             effectief              failliet
#
# [10 rows x 3 columns]
#
# JSD: 0.246038293691
#       topic_71 opinion_71_Opposition opinion_71_Government
# 0     koningin            koninklijk            koninklijk
# 1  informateur          ministerieel          parlementair
# 2  staatshoofd      staatsrechtelijk          ministerieel
# 3     formatie          democratisch      staatsrechtelijk
# 4       koning           persoonlijk          democratisch
# 5      premier               formeel          demissionair
# 6         huis           transparant                rechts
# 7    reglement           ceremonieel            toekomstig
# 8       proces            toekomstig             feitelijk
# 9        prins              aanwezig               stabiel
#
# [10 rows x 3 columns]
#
# JSD: 0.2459528054
#         topic_11 opinion_11_Opposition opinion_11_Government
# 0       argument           principieel            zorgvuldig
# 1       afweging           inhoudelijk           inhoudelijk
# 2      standpunt            zorgvuldig           principieel
# 3        besluit             volstrekt           ingewikkeld
# 4          keuze            definitief               logisch
# 5        bezwaar               logisch            definitief
# 6  duidelijkheid                  raar             feitelijk
# 7     redenering           merkwaardig             volstrekt
# 8   pvda-fractie                 reëel             wenselijk
# 9   consequentie                    na              gevoelig
#
# [10 rows x 3 columns]
#
# JSD: 0.243507493703
#           topic_68 opinion_68_Opposition opinion_68_Government
# 0          project            ruimtelijk            ruimtelijk
# 1        procedure            decentraal             integraal
# 2         ordening            zorgvuldig            zorgvuldig
# 3          besluit         belanghebbend         belanghebbend
# 4   besluitvorming      infrastructureel           ingewikkeld
# 5  bestemmingsplan             integraal             tijdelijk
# 6           crisis              centraal           interessant
# 7       herstelwet                 groen                divers
# 8       vertraging              kritisch              centraal
# 9      alternatief                 vroeg           inhoudelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.24340883915
#          topic_9 opinion_9_Opposition opinion_9_Government
# 0      wijziging          voorliggend          voorliggend
# 1           nota       oorspronkelijk             redelijk
# 2        verslag            tijdelijk            expliciet
# 3  wetswijziging             redelijk                apart
# 4    toelichting          inhoudelijk            wenselijk
# 5      wetgeving                apart                   na
# 6      evaluatie           zorgvuldig       oorspronkelijk
# 7     aanpassing         fundamenteel          afhankelijk
# 8        bezwaar              logisch              plenair
# 9    verbetering            praktisch            praktisch
#
# [10 rows x 3 columns]
#
# JSD: 0.242708552452
#      topic_39 opinion_39_Opposition opinion_39_Government
# 0  referendum          democratisch          democratisch
# 1  verkiezing             tijdelijk        representatief
# 2   bevolking            correctief             tijdelijk
# 3      kiezer        grondwettelijk        grondwettelijk
# 4    grondwet        representatief            correctief
# 5  democratie          parlementair          parlementair
# 6   parlement           inhoudelijk               formeel
# 7        stem                  bang         onafhankelijk
# 8   kandidaat             werkelijk           principieel
# 9      advies           principieel            definitief
#
# [10 rows x 3 columns]
#
# JSD: 0.242555357416
#         topic_52 opinion_52_Opposition opinion_52_Government
# 0         sector            biologisch             agrarisch
# 1           boer              duurzaam            biologisch
# 2       landbouw             agrarisch              duurzaam
# 3        product             intensief                 groen
# 4  dierenwelzijn              dierlijk               primair
# 5        voedsel                 groen     gemeenschappelijk
# 6      productie                gezond             intensief
# 7          markt           plantaardig             volstrekt
# 8          vlees     gemeenschappelijk                  fors
# 9    veehouderij          grootschalig                totaal
#
# [10 rows x 3 columns]
#
# JSD: 0.241488263872
#              topic_50 opinion_50_Opposition opinion_50_Government
# 0             student      wetenschappelijk      wetenschappelijk
# 1           opleiding            academisch          universitair
# 2          instelling          universitair            vrijwillig
# 3        universiteit           inhoudelijk              initieel
# 4              studie             werkelijk                  ruim
# 5  studiefinanciering              maximaal              kritisch
# 6           kwaliteit                jammer             landelijk
# 7                 hbo              redelijk           interessant
# 8         collegegeld              flexibel         aantrekkelijk
# 9          hogeschool              relevant               privaat
#
# [10 rows x 3 columns]
#
# JSD: 0.241344941101
#         topic_61 opinion_61_Opposition opinion_61_Government
# 0        politie             landelijk             landelijk
# 1     veiligheid             crimineel                veilig
# 2       Justitie                veilig             crimineel
# 3          agent             effectief           structureel
# 4         straat            preventief             effectief
# 5         geweld            justitieel              illegaal
# 6  criminaliteit                 blauw              aanwezig
# 7         aanpak          operationeel            preventief
# 8   burgemeester           structureel             regionaal
# 9          korps             regionaal                lastig
#
# [10 rows x 3 columns]
#
# JSD: 0.24005009887
#             topic_79 opinion_79_Opposition opinion_79_Government
# 0            enquête          parlementair          parlementair
# 1          parlement         vertrouwelijk         vertrouwelijk
# 2            persoon              adequaat             feitelijk
# 3       openbaarheid          ministerieel             toenmalig
# 4         inlichting               onjuist              adequaat
# 5             kennis            zorgvuldig                geheim
# 6             dienst                    na              relevant
# 7   enquêtecommissie            onvolledig               grondig
# 8  veiligheidsdienst              relevant             uitvoerig
# 9              staat                geheim              destijds
#
# [10 rows x 3 columns]
#
# JSD: 0.236846193739
#              topic_21 opinion_21_Opposition opinion_21_Government
# 0           jeugdzorg               jeugdig               jeugdig
# 1               ouder             landelijk                 licht
# 2              bureau             effectief             landelijk
# 3               gezin            preventief             effectief
# 4               jeugd             huiselijk            justitieel
# 5          wachtlijst                 licht             huiselijk
# 6                hulp            vrijwillig           minderjarig
# 7  kindermishandeling            forensisch             tijdelijk
# 8             centrum           minderjarig            vrijwillig
# 9       hulpverlening            justitieel            preventief
#
# [10 rows x 3 columns]
#
# JSD: 0.23672290356
#          topic_64 opinion_64_Opposition opinion_64_Government
# 0        toezicht         onafhankelijk         onafhankelijk
# 1       inspectie              centraal                intern
# 2      instelling                extern        administratief
# 3       kwaliteit           commercieel              centraal
# 4         bestuur                intern       toezichthoudend
# 5        controle       toezichthoudend                extern
# 6            taak                actief           kwalitatief
# 7  toezichthouder               voldoen              kritisch
# 8      accountant                    na             volstrekt
# 9     organisatie                scherp                scherp
#
# [10 rows x 3 columns]
#
# JSD: 0.232508204659
#             topic_58 opinion_58_Opposition opinion_58_Government
# 0            rechter           rechterlijk           rechterlijk
# 1             beroep           inhoudelijk               formeel
# 2           toetsing            zorgvuldig            burgerlijk
# 3          procedure           principieel         uitdrukkelijk
# 4            bezwaar          fundamenteel             feitelijk
# 5           wetgever          rechtstreeks            zorgvuldig
# 6          wetgeving            burgerlijk             voorlopig
# 7     jurisprudentie                civiel         belanghebbend
# 8              toets               formeel                civiel
# 9  rechtsbescherming             voorlopig           inhoudelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.23247587042
#         topic_81 opinion_81_Opposition opinion_81_Government
# 0           dier               ritueel               ritueel
# 1  dierenwelzijn      wetenschappelijk      wetenschappelijk
# 2         verbod               onnodig             religieus
# 3         slacht             religieus            intrinsiek
# 4        welzijn            intrinsiek                moreel
# 5        ritueel                  wild                  wild
# 6           hond       diervriendelijk                 joods
# 7     dierenleed               ethisch              regulier
# 8          vlees              regulier               ethisch
# 9         waarde             effectief                  dood
#
# [10 rows x 3 columns]
#
# JSD: 0.232121855767
#       topic_10 opinion_10_Opposition opinion_10_Government
# 0   terrorisme         terroristisch         terroristisch
# 1  organisatie              militair           amerikaanse
# 2       strijd           amerikaanse             effectief
# 3        actie           buitenlands           buitenlands
# 4        wapen                geheim              militair
# 5      aanslag             effectief            israëlisch
# 6   veiligheid              illegaal           strategisch
# 7        lijst           gewelddadig            humanitair
# 8    bevolking            humanitair            palestijns
# 9        staat             volstrekt            preventief
#
# [10 rows x 3 columns]
#
# JSD: 0.230912399959
#              topic_6 opinion_6_Opposition opinion_6_Government
# 0  lastenverlichting          structureel          structureel
# 1            uitgaaf           collectief          incidenteel
# 2              groei           budgettair           collectief
# ...
# 5               premie               medisch            collectief
# 6          verzekering           onverzekerd               medisch
# 7      gezondheidszorg           particulier                gezond
# 8  zorgverzekeringswet            collectief           zelfstandig
# 9            apotheker               onnodig                  duur
#
# [10 rows x 3 columns]
#
# JSD: 0.218532651714
#        topic_35 opinion_35_Opposition opinion_35_Government
# 0      bijstand          alleenstaand              regulier
# 1     uitkering              werkloos          alleenstaand
# 2          baan             langdurig              werkloos
# 3  arbeidsmarkt              regulier              maximaal
# 4   minimumloon           categoriaal   bijstandsgerechtigd
# 5        arbeid           afhankelijk          gemeentelijk
# 6          kans   bijstandsgerechtigd             kwetsbaar
# 7      scholing  uitkeringsgerechtigd             tijdelijk
# 8          slag             tijdelijk              duurzaam
# 9       inkomen              maximaal           werkzoekend
#
# [10 rows x 3 columns]
#
# JSD: 0.21817420294
#          topic_8 opinion_8_Opposition opinion_8_Government
# 0          ouder             speciaal             speciaal
# 1       leerling              primair              primair
# 2  schoolbestuur                zwart             regulier
# 3      inspectie             regulier                 zwak
# 4  onderwijsraad                 zwak          particulier
# 5         leraar                  wit               lastig
# 6    bekostiging           allochtoon         vroegschools
# 7         docent          particulier                zwart
# 8      kwaliteit               actief           allochtoon
# 9           klas              bevoegd          pedagogisch
#
# [10 rows x 3 columns]
#
# JSD: 0.214999543046
#          topic_46 opinion_46_Opposition opinion_46_Government
# 0         inkomen                  ziek             chronisch
# 1          bedrag             chronisch                  ziek
# 2           gezin           gehandicapt   inkomensafhankelijk
# 3          effect   inkomensafhankelijk           gehandicapt
# 4         toeslag               fiscaal               fiscaal
# 5     compensatie              negatief             gemiddeld
# 6      huishouden                modaal            zorgvuldig
# 7  tegemoetkoming             kwetsbaar              negatief
# 8        bijdrage             gemiddeld                  fors
# 9      koopkracht          rechtvaardig          rechtvaardig
#
# [10 rows x 3 columns]
#
# JSD: 0.214731624527
#            topic_72 opinion_72_Opposition opinion_72_Government
# 0            omroep             regionaal             regionaal
# 1         programma           commercieel           commercieel
# 2            bestel              digitaal              digitaal
# 3             media         onafhankelijk         onafhankelijk
# 4         televisie               analoog               analoog
# 5           bestuur             landelijk             volstrekt
# 6           reclame              kritisch             landelijk
# 7            zender             technisch           inhoudelijk
# 8  omroepvereniging                gratis           principieel
# 9             radio                totaal           interessant
#
# [10 rows x 3 columns]
#
# JSD: 0.211062407768
#        topic_55 opinion_55_Opposition opinion_55_Government
# 0        woning            betaalbaar              maximaal
# 1       huurder           particulier           particulier
# 2    corporatie              maximaal              goedkoop
# 3    verhuurder                  duur              redelijk
# 4          huur              goedkoop            betaalbaar
# 5       inkomen              redelijk             gemiddeld
# 6    huurwoning             tijdelijk                  duur
# 7  huursubsidie             gemiddeld           commercieel
# 8   huurtoeslag        administratief             regionaal
# 9   woningmarkt              illegaal            burgerlijk
#
# [10 rows x 3 columns]
#
# JSD: 0.210344191303
#           topic_89 opinion_89_Opposition opinion_89_Government
# 0             unie           buitenlands           buitenlands
# 1         lidstaat          democratisch     gemeenschappelijk
# 2        parlement     gemeenschappelijk                intern
# 3      uitbreiding                intern        institutioneel
# 4     samenwerking          parlementair          democratisch
# 5       toetreding          communautair                actief
# 6        conventie              kritisch   grensoverschrijdend
# 7        criterium        institutioneel           gezamenlijk
# 8  voorzitterschap           gezamenlijk                 klaar
# 9          terrein            toekomstig             effectief
#
# [10 rows x 3 columns]
#
# JSD: 0.210170249195
#        topic_25 opinion_25_Opposition opinion_25_Government
# 0        natuur            ecologisch             agrarisch
# 1     provincie             agrarisch           significant
# 2  natuurgebied             kwetsbaar             kwetsbaar
# 3          boer             landelijk            ecologisch
# 4         grond             intensief             landelijk
# 5     landschap                 groen             genetisch
# 6        milieu               robuust             integraal
# 7   veehouderij              duurzaam      wetenschappelijk
# 8      landbouw           significant             intensief
# 9        beheer             genetisch                 groen
#
# [10 rows x 3 columns]
#
# JSD: 0.20992961655
#           topic_80 opinion_80_Opposition opinion_80_Government
# 0            ouder           gezamenlijk            burgerlijk
# 1          rechter            burgerlijk           gezamenlijk
# 2            gezag        administratief        administratief
# 3         huwelijk           rechterlijk            biologisch
# 4        scheiding         gelijkwaardig               geboren
# 5          partner     gemeenschappelijk             praktisch
# 6            vader             praktisch     gemeenschappelijk
# 7  ouderschapsplan           principieel           minderjarig
# 8    echtscheiding              centraal                 haags
# 9           moeder            zorgvuldig              centraal
#
# [10 rows x 3 columns]
#
# JSD: 0.207379138537
#               topic_20 opinion_20_Opposition opinion_20_Government
# 0             grondwet       constitutioneel       constitutioneel
# 1          meerderheid        grondwettelijk      staatsrechtelijk
# 2               lezing               formeel        grondwettelijk
# 3             wetgever      staatsrechtelijk               formeel
# 4            opvatting          democratisch             tweederde
# 5          bevoegdheid           principieel           principieel
# 6             bepaling                 duaal          parlementair
# 7  samenwerkingsschool                  ruim          rechtstreeks
# 8   grondwetswijziging          parlementair              destijds
# 9            wetgeving             wezenlijk          democratisch
#
# [10 rows x 3 columns]
#
# JSD: 0.206713407229
#        topic_0 opinion_0_Opposition opinion_0_Government
# 0     defensie             militair             militair
# 1       missie          buitenlands         operationeel
# 2     militair               civiel               civiel
# 3  krijgsmacht          strategisch          buitenlands
# 4     operatie          amerikaanse               actief
# 5   uitzending             afghaans           humanitair
# 6        inzet           koninklijk           koninklijk
# 7         taak           humanitair             afghaans
# 8    personeel         operationeel          amerikaanse
# 9     veteraan             speciaal            tijdelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.20617494946
#               topic_56 opinion_56_Opposition opinion_56_Government
# 0          bevoegdheid             strafbaar       strafrechtelijk
# 1             Justitie       strafrechtelijk             strafbaar
# 2           aanwijzing             deskundig             crimineel
# 3              getuige             voorlopig             voorlopig
# 4  rechter-commissaris            preventief          grootschalig
# 5             officier             crimineel             deskundig
# 6              persoon         terroristisch       strafvorderlijk
# 7             misdrijf                  ruim              openlijk
# 8              wetboek              openlijk            onschuldig
# 9           ministerie            onschuldig             praktisch
#
# [10 rows x 3 columns]
#
# JSD: 0.198897971457
#          topic_37 opinion_37_Opposition opinion_37_Government
# 0         alcohol              illegaal              illegaal
# 1            drug             effectief             effectief
# 2      coffeeshop              rookvrij             strafbaar
# 3       preventie             strafbaar              rookvrij
# 4      handhaving                legaal            schadelijk
# 5           drank            schadelijk                legaal
# 6         verkoop                jammer                streng
# 7  leeftijdsgrens                streng             crimineel
# 8         reclame             overmatig               keihard
# 9          horeca             landelijk             landelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.198634355566
#         topic_47 opinion_47_Opposition opinion_47_Government
# 0           awbz      persoonsgebonden      persoonsgebonden
# 1         cliënt         huishoudelijk             langdurig
# 2         budget           gehandicapt           gehandicapt
# 3     instelling             kwetsbaar             integraal
# 4            pgb            palliatief         huishoudelijk
# 5    begeleiding             landelijk            collectief
# 6      thuiszorg             langdurig             kwetsbaar
# 7      indicatie         onafhankelijk                 dicht
# 8  ondersteuning         verstandelijk            palliatief
# 9   mantelzorger                jammer         verstandelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.198025401625
#           topic_40 opinion_40_Opposition opinion_40_Government
# 0          rechter             strafbaar             strafbaar
# 1            straf       strafrechtelijk       strafrechtelijk
# 2      slachtoffer        voorwaardelijk           rechterlijk
# 3           delict           rechterlijk        voorwaardelijk
# 4         misdrijf             voorlopig            levenslang
# 5        taakstraf             crimineel             effectief
# 6       strafrecht           principieel             voorlopig
# 7         Justitie             effectief              maximaal
# 8            dader      onvoorwaardelijk          elektronisch
# 9  gevangenisstraf          stelselmatig                civiel
#
# [10 rows x 3 columns]
#
# JSD: 0.194052061391
#            topic_16 opinion_16_Opposition opinion_16_Government
# 0           patiënt         psychiatrisch         psychiatrisch
# 1        inrichting            justitieel        voorwaardelijk
# 2        machtiging        voorwaardelijk            geestelijk
# 3            opname            geestelijk            vrijwillig
# 4            gevaar             psychisch            justitieel
# 5        instelling               jeugdig               jeugdig
# 6        gevangenis            vrijwillig             psychisch
# 7             dwang          penitentiair           rechterlijk
# 8       behandelaar           rechterlijk             voorlopig
# 9  dwangbehandeling      civielrechtelijk           particulier
#
# [10 rows x 3 columns]
#
# JSD: 0.193877806131
#           topic_15 opinion_15_Opposition opinion_15_Government
# 0             arts               medisch               medisch
# 1          patiënt                  ziek            zorgvuldig
# 2            leven             deskundig        verpleegkundig
# 3           ziekte        verpleegkundig           alternatief
# 4  gezondheidszorg               ethisch             menselijk
# 5       euthanasie      wetenschappelijk               ethisch
# 6          abortus                gezond             landelijk
# 7         huisarts           alternatief      wetenschappelijk
# 8  volksgezondheid       medisch-ethisch                  ziek
# 9       gezondheid            zorgvuldig           inhoudelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.190115723394
#               topic_22 opinion_22_Opposition opinion_22_Government
# 0          asielzoeker              illegaal              illegaal
# 1          vreemdeling         discretionair         discretionair
# 2            terugkeer             tijdelijk             crimineel
# 3               opvang            schrijnend                veilig
# 4  verblijfsvergunning              regulier            zorgvuldig
# 5            procedure               medisch             strafbaar
# 6             illegaal           categoriaal                streng
# 7             herkomst                streng            vrijwillig
# 8             verblijf                veilig            schrijnend
# 9           uitzetting            vrijwillig               medisch
#
# [10 rows x 3 columns]
#
# JSD: 0.189100769102
#                  topic_12 opinion_12_Opposition opinion_12_Government
# 0               belasting               fiscaal               fiscaal
# 1         belastingdienst     belastingplichtig     belastingplichtig
# 2                vermogen            budgettair            budgettair
# 3                  tarief                 grijs        administratief
# 4           belastingplan        administratief           buitenlands
# 5  vennootschapsbelasting              redelijk              redelijk
# 6            vrijstelling            forfaitair             eenvoudig
# 7               verlaging             onbedoeld           oneigenlijk
# 8                     box              negatief             technisch
# 9      inkomstenbelasting             marginaal           aanzienlijk
#
# [10 rows x 3 columns]
#
# JSD: 0.166018643517
#                topic_51 opinion_51_Opposition opinion_51_Government
# 0               verzoek               plenair               plenair
# 1              stemming               spoedig           inhoudelijk
# 2            spoeddebat           inhoudelijk             aanstaand
# 3                agenda              aanwezig              aanwezig
# 4                   uur             aanstaand               spoedig
# 5               uitstel             mondeling            zorgvuldig
# 6              behoefte            zorgvuldig           buitenlands
# 7               bericht           buitenlands             mondeling
# 8  procedurevergadering        controversieel               normaal
# 9           meerderheid                 apart                    na
#
# [10 rows x 3 columns]
#
# JSD: 0.162977892571
#                     topic_54 opinion_54_Opposition opinion_54_Government
# 0                mensenrecht           buitenlands           buitenlands
# 1  ontwikkelingssamenwerking            palestijns            bilateraal
# 2                     wereld             effectief             effectief
# 3                organisatie            bilateraal            palestijns
# 4                       hulp              arabisch         multilateraal
# 5               ontwikkeling           diplomatiek           islamitisch
# 6          ontwikkelingsland            israëlisch                actief
# 7                    relatie                iraans           diplomatiek
# 8                      inzet            humanitair                iraans
# 9                      staat                   arm              militair
#
# [10 rows x 3 columns]
#
# JSD: 0.160444381982
#        topic_93 opinion_93_Opposition opinion_93_Government
# 0     provincie           provinciaal             regionaal
# 1   herindeling             regionaal           provinciaal
# 2         regio          gemeentelijk          gemeentelijk
# 3       bestuur          democratisch          democratisch
# 4     draagvlak            ruimtelijk           voorliggend
# 5  samenwerking           zelfstandig              krachtig
# 6         staat             landelijk           zelfstandig
# 7       inwoner             stedelijk             ambtelijk
# 8          taak           inhoudelijk            ruimtelijk
# 9     bevolking           voorliggend           inhoudelijk
#
# [10 rows x 3 columns]
