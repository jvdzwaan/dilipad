# %% [markdown]
# # View CPT Results for experiment "all_years-adj-parties"

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (10, 7)

# %% [markdown]
# ## Topic word perplexity

# %%
import os

def load_perplexity_results(results_dir):
    perplexity_topic = pd.read_csv(os.path.join(results_dir, 'perplexity_topic.csv'), index_col=0)
    perplexity_opinion = pd.read_csv(os.path.join(results_dir, 'perplexity_opinion.csv'), index_col=0)
    
    return perplexity_topic, perplexity_opinion

# %%
results_dir = '/home/jvdzwaan/data/dilipad/results/all_years/all_years-adj-parties/'

# %%
perplexity_topic, perplexity_opinion = load_perplexity_results(results_dir)
perplexity_topic.plot();
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=medium. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
# change intervals if needed
intervals = ['20', '100', '180', '200']

# %%
perplexity_topic[intervals].plot();

# %% [markdown]
# ## Opinion word perplexity

# %%
perplexity_opinion.plot();

# %%
perplexity_opinion[intervals].plot();

# %% [markdown]
# ## Results for topics and opinions

# %%
# choose optimal number of topics based on perplexity results
nTopics = 100

# %%
# load results
import glob
import os
import re

def load_experiment_results(nTopics, results_dir):

    # document topic matrix (theta)
    theta = pd.read_csv(os.path.join(results_dir, 'theta_{}.csv'.format(nTopics)), index_col=0)

    # phi topic (transposed)
    phi_topic_t = pd.read_csv(os.path.join(results_dir, 'topics_{}.csv'.format(nTopics)), index_col=0, encoding='utf-8')

    # phi opinion (transposed) per perspective
    opinion_files = glob.glob('{}/opinions_*_{}.csv'.format(results_dir, nTopics))
    phis_opinion_t = {}
    for f in opinion_files:
        m = re.match(r'.+opinions_(.+).csv', f)
        name = m.group(1).replace('_{}'.format(nTopics), '')
        phis_opinion_t[name] = pd.read_csv(f, index_col=0, encoding='utf-8')
    return theta, phi_topic_t, phis_opinion_t

# %%
theta, phi_topic_t, phis_opinion_t = load_experiment_results(nTopics, results_dir)

# %% [markdown]
# ### 'Weight' of the most important topic per document
#
# Each topic has a certain weight in the document. We would like to see one (or a few) topics with high weight per document. Below are some basic statistics on the most important topic (highest weight) per document.

# %%
def print_topic_weights(theta):
    a = theta.copy().apply(max, axis=1)
    a.sort(ascending=False)

    print 'Mean weight of most important topic: {} (std: {})'.format(a.mean(), a.std())
    print 'Min and max of most important topic: min: {}, max: {}'.format(a.min(), a.max())
    print 'Median weight of most important topic: ', a.median()

print_topic_weights(theta)
# Out:
# Mean weight of most important topic: 0.163849102601 (std: 0.10682004427)
# Min and max of most important topic: min: 0.01, max: 0.703964565786
# Median weight of most important topic:  0.143401255078

# %% [markdown]
# Line graph of the sorted topic weigths:

# %%
def plot_topic_weights(theta):
    theta.copy().apply(lambda row:sorted(row)[::-1], axis=1).transpose().plot(legend=None);

plot_topic_weights(theta)

# %% [markdown]
# ### Number of topics per document
#
# The number of topics per document is calculated by counting the number of topic with weight above a certain threshold. The numer of topics per document should (roughly) be equivalent to the number of ``pm:topic``s per document (however, at the moment we do not have statistics of this).

# %%
def display_number_of_topics_per_document(theta, threshold=0.05):
    topic_counts = theta.apply(lambda row: np.sum(row > threshold), axis=1)
    print topic_counts.value_counts(sort=False)
    topic_counts.hist(bins=len(topic_counts.value_counts()), figsize=(5,3));

display_number_of_topics_per_document(theta)
# Out:
# 0    4549
# 1    8245
# 2    9353
# 3    7307
# 4    3641
# 5    1177
# 6     247
# 7      36
# 8       3
# dtype: int64

# %% [markdown]
# ### Topics

# %%
def show_topic(t, top=10):
    """Return dataframe containing <top> topic words, weights of topic words and per perspective opinion words and
    weigths of opinion words.
    
    Parameters
        t : str - index of topic number
        top : int - the number of words to store in the dataframe
    
    Returns Pandas DataFrame
    """
    topic = phi_topic_t[t].copy()
    topic.sort(ascending=False)
    topic = topic[0:top]
    df_t = pd.DataFrame(topic)
    df_t.reset_index(level=0, inplace=True)
    df_t.columns = ['topic_{}'.format(t), 'weights_topic_{}'.format(t)]

    dfs = [df_t]

    for p, o in phis_opinion_t.iteritems():
        opinion = o[t].copy()
        opinion.sort(ascending=False)
        opinion = opinion[0:top]
        df_o = pd.DataFrame(opinion)
        df_o.reset_index(level=0, inplace=True)
        df_o.columns = ['opinion_{}_{}'.format(t, p), 'weights_opinion_{}_{}'.format(t, p)]
        dfs.append(df_o)
        
    return pd.concat(dfs, axis=1)

def print_topics(phi_topic_t, phis_opinion_t, nTopics):
    jsd = None
    jsdFile = os.path.join(results_dir, 'jsd_{}.csv'.format(nTopics))
    if os.path.isfile(jsdFile):
        print 'Ordering topics by Jensen-Shannon divergence of the opinions'
        print
        jsd = pd.read_csv(jsdFile, index_col=0)
        r = jsd.sort(['jsd'], ascending=False)
        print 'Min jsd: {}, max jsd: {}'.format(np.min(jsd['jsd']), np.max(jsd['jsd']))
        print 'Average jsd: {} (std: {}), median jsd: {}'.format(np.mean(jsd['jsd']), np.std(jsd['jsd']), np.median(jsd['jsd']))
        print
        loop = r.index
    else:
        print 'Ordering topics by topic number'
        print '(To order topics by Jensen-Shannon divergence of the opinions run the experiment_jsd_opinions script.)'
        print
        loop = range(nTopics)
    for i in loop:
        if not jsd is None:
            print 'JSD:', jsd.at[i, 'jsd']
        pLabels = ['opinion_{}_{}'.format(i, p) for p, o in phis_opinion_t.iteritems()]
        print show_topic(str(i))[['topic_{}'.format(i)] + pLabels]
        print

# %%
print_topics(phi_topic_t, phis_opinion_t, nTopics)
# Out:
# Ordering topics by Jensen-Shannon divergence of the opinions
#
# Min jsd: 0.66924303488, max jsd: 0.882472756519
# Average jsd: 0.797081347009 (std: 0.0349622449296), median jsd: 0.794348744669
#
# JSD: 0.882472756519
#        topic_74 opinion_74_50PLUS opinion_74_PvdD opinion_74_D66  \
# 0   samenleving       voorliggend         uiterst         stevig
# 1      politiek        onverdacht        geweldig          prima
# 2        wereld             menig           blind         scherp
# 3         leven         volstrekt           trots     essentieel
# 4     politicus        onverwijld          schoon          paars
# 5        betoog      gebruikelijk    traditioneel   begrijpelijk
# 6          kans       inhoudelijk           links           stil
# 7          idee       hardvochtig            ruim         rechts
# 8         macht        emotioneel        kostbaar       prachtig
# 9  geschiedenis        schrijnend        kritisch    interessant
#
#       opinion_74_CDA opinion_74_PvdA opinion_74_GroenLinks opinion_74_SGP  \
# 0          menselijk        prachtig              kritisch      wezenlijk
# 1             stevig           trots                 links         moreel
# 2               diep        cruciaal                lastig         recent
# 3        persoonlijk            waar             werkelijk   fundamenteel
# 4           prachtig          jammer           voortdurend    persoonlijk
# 5    vanzelfsprekend          stevig                modern          kwaad
# 6             veilig            diep           ideologisch           zwak
# 7          waardevol            ruim             kwetsbaar        voorbij
# 8          werkelijk    rechtvaardig             eindelijk     indringend
# 9  gemeenschappelijk            stil             zichtbaar         heilig
#
#   opinion_74_SP opinion_74_ChristenUnie opinion_74_PVV    opinion_74_RPF  \
# 0     menselijk                    zwak          trots       gezamenlijk
# 1      liberaal                    diep          links      substantieel
# 2         links                   vroeg            vol         intensief
# 3          rijk               eenzijdig          vroeg            scherp
# 4         paars             gezamenlijk         actief            heilig
# 5  fundamenteel              dienstbaar           waar         ongewenst
# 6   neoliberaal                  gezond      diezelfde      gedeeltelijk
# 7         vroeg               kwetsbaar   tegenwoordig  arbeidsintensief
# 8          bang              onmogelijk      jarenlang             vroeg
# 9      geweldig               werkelijk         modern           voldoen
#
#   opinion_74_LPF         opinion_74_GPV opinion_74_VVD opinion_74_OSF  \
# 0         veilig            gezamenlijk         bewust         divers
# 1       krachtig             behoorlijk       liberaal     allereerst
# 2         welkom             collectief       cruciaal    interessant
# 3          links  financieel-economisch       prachtig      werkelijk
# 4           diep            minderjarig      wezenlijk         vreemd
# 5       destijds                   zwak         scherp      volstrekt
# 6      succesvol                  vroeg            vol  onafhankelijk
# 7       compleet           fundamenteel      werkelijk    aanzienlijk
# 8           zwak              enigerlei           diep      jarenlang
# 9       tevreden                 actief    persoonlijk     gevaarlijk
#
#   opinion_74_Leefbaar Nederland
# 0                        fysiek
# 1                      regulier
# 2                         vroeg
# 3                  gemeentelijk
# 4                      goedkoop
# 5                 geloofwaardig
# 6                     plezierig
# 7                   allerlaatst
# 8                  demissionair
# 9                     eenzijdig
#
# [10 rows x 17 columns]
#
# JSD: 0.879239540472
#          topic_76 opinion_76_50PLUS  opinion_76_PvdD opinion_76_D66  \
# 0     bezuiniging            triest            groen       dadelijk
# 1   regeerakkoord              diep      groenrechts           waar
# 2        coalitie         evenredig       toekomstig           fors
# 3      hervorming      alleenstaand          keihard      werkelijk
# 4         ambitie        onvolledig             rood     zorgvuldig
# 5       oppositie                na  rechtsstatelijk         scherp
# 6         belofte            schril      afrekenbaar          prima
# 7         premier      niet-sociaal     inzichtelijk       pijnlijk
# 8       begroting        allochtoon            trots            vol
# 9  coalitiepartij           beroerd        harteloos       liberaal
#
#    opinion_76_CDA opinion_76_PvdA opinion_76_GroenLinks opinion_76_SGP  \
# 0          totaal       werkelijk             kwetsbaar    inhoudelijk
# 1       volstrekt       volstrekt                  fors         stevig
# 2             gek            fors             blijkbaar           fors
# 3      letterlijk          totaal                 klaar      informeel
# 4  oorspronkelijk       blijkbaar                rechts          flink
# 5       werkelijk            waar                 links       pijnlijk
# 6    rechtstreeks          rechts              pijnlijk           slim
# 7     interessant     inhoudelijk                 vroeg      kwetsbaar
# 8           paars      ontzettend           afhankelijk   afzonderlijk
# 9            waar           kwijt                vreemd          prima
#
#   opinion_76_SP opinion_76_ChristenUnie   opinion_76_PVV opinion_76_RPF  \
# 0          fors                    fors          keihard       benodigd
# 1        totaal                  stevig         pijnlijk          paars
# 2          duur              behoorlijk        jarenlang    gezamenlijk
# 3      asociaal                ongedaan            trots           druk
# 4          bang               toenmalig              vol  ondergeschikt
# 5    ontzettend               kwetsbaar  verschrikkelijk        nadelig
# 6       keihard             alternatief             fors      doordacht
# 7      ongedaan             inhoudelijk           jammer   beleidsmatig
# 8   structureel            constructief        langdurig     omvangrijk
# 9         trots                   prima        efficiënt       vermeend
#
#   opinion_76_LPF opinion_76_GPV opinion_76_VVD opinion_76_OSF  \
# 0           fors    inhoudelijk         stevig       relevant
# 1    betrouwbaar        onnodig     ontzettend      wezenlijk
# 2      kwetsbaar          trots         jammer       vermeend
# 3        akkoord    voorzichtig      volstrekt    inhoudelijk
# 4           diep  geloofwaardig          klaar      eenzijdig
# 5         gezond           waar          trots    strategisch
# 6     essentieel          waard    afhankelijk       illusoir
# 7      deskundig          groen        logisch   eigenstandig
# 8      dagelijks     behoorlijk        voorbij   aanmerkelijk
# 9           half     deugdelijk         gezond     desastreus
#
#   opinion_76_Leefbaar Nederland
# 0                    behoorlijk
# 1                    budgettair
# 2                    ingrijpend
# 3                controversieel
# 4                          ruim
# 5                      leefbaar
# 6                         droog
# 7                    sympathiek
# 8                    eenstemmig
# 9                       uiterst
#
# [10 rows x 17 columns]
#
# JSD: 0.871603843959
#       topic_82   opinion_82_50PLUS opinion_82_PvdD  opinion_82_D66  \
# 0      verdrag                  na  grondwettelijk  grondwettelijk
# 1   referendum               wrang    democratisch    democratisch
# 2    bevolking           uitvoerig  ondemocratisch         formeel
# 3    parlement                half     ongewijzigd      correctief
# 4     grondwet         inhoudelijk     ingewikkeld        destijds
# 5   democratie  pensioengerechtigd   ondergeschikt  representatief
# 6  meerderheid           moedeloos     onduidelijk       tijdelijk
# 7       kiezer               kwijt       cultureel       werkelijk
# 8      uitslag      onaanvaardbaar       religieus   onafhankelijk
# 9         stem            onbekend      veelvuldig          jammer
#
#    opinion_82_CDA opinion_82_PvdA opinion_82_GroenLinks  opinion_82_SGP  \
# 0    parlementair       tijdelijk            correctief       tijdelijk
# 1       tijdelijk    democratisch          democratisch    parlementair
# 2  grondwettelijk      correctief             tijdelijk     inhoudelijk
# 3  representatief    parlementair          parlementair  grondwettelijk
# 4    democratisch    rechtstreeks              destijds  representatief
# 5    rechtstreeks       blijkbaar        grondwettelijk      ingrijpend
# 6          dubbel            ruim                  bang        destijds
# 7       praktisch  grondwettelijk             blijkbaar      correctief
# 8         formeel  representatief                vreemd    democratisch
# 9      correctief       praktisch               normaal          lastig
#
#      opinion_82_SP opinion_82_ChristenUnie  opinion_82_PVV opinion_82_RPF  \
# 0   grondwettelijk          grondwettelijk    democratisch           gauw
# 1     democratisch            democratisch            iers   gevoelsmatig
# 2     parlementair              correctief  grondwettelijk          haaks
# 3  constitutioneel                  lastig    rechtstreeks      effectief
# 4             raar             inhoudelijk      bilateraal   tegenwoordig
# 5         neutraal          representatief            rood      landelijk
# 6      buitenlands            fundamenteel    parlementair        stellig
# 7          logisch            parlementair        aanwezig    uitsluitend
# 8            waard                  intern         akkoord  hooggespannen
# 9       historisch                 formeel       werkelijk      intensief
#
#    opinion_82_LPF opinion_82_GPV  opinion_82_VVD opinion_82_OSF  \
# 0    democratisch        primair  grondwettelijk  uitdrukkelijk
# 1      behoorlijk       legitiem       tijdelijk      praktisch
# 2  grondwettelijk      officieel    democratisch         zinvol
# 3          bewust   democratisch      correctief      zichtbaar
# 4       feitelijk         simpel    rechtstreeks     historisch
# 5      toekomstig      impliciet       volstrekt        unaniem
# 6        redelijk         friees    parlementair      officieel
# 7     spijkerhard      cultureel          vreemd    buitenlands
# 8         keihard        actueel       wezenlijk        normaal
# 9        onwillig           wijs  representatief      eindelijk
#
#   opinion_82_Leefbaar Nederland
# 0           grensoverschrijdend
# 1                        legaal
# 2                      optimaal
# 3                    luxemburgs
# 4                      brussels
# 5                      werkbaar
# 6                          leuk
# 7                        bewust
# 8                      beperken
# 9                      verbaasd
#
# [10 rows x 17 columns]
#
# JSD: 0.869546406421
#            topic_27 opinion_27_50PLUS    opinion_27_PvdD opinion_27_D66  \
# 0           verkeer            online         elektrisch        normaal
# 1               weg         effectief         vervuilend    structureel
# 2              auto      doeltreffend               leeg    interessant
# 3  kilometerheffing     tegenstrijdig     milieubelasten      succesvol
# 4        waterstaat       doortastend  milieuvervuilende           slim
# 5        mobiliteit              knap     oorspronkelijk      stedelijk
# 6    infrastructuur         voornoemd       milieubewust        fiscaal
# 7              file             droog               raar      integraal
# 8           vervoer             zwart        provinciaal            nat
# 9                km           oprecht        alternatief           duur
#
#   opinion_27_CDA opinion_27_PvdA opinion_27_GroenLinks opinion_27_SGP  \
# 0           duur          gratis                schoon      integraal
# 1       maximaal     gehandicapt            elektrisch      landelijk
# 2           fors            krom                  duur       relatief
# 3           krom        gevoelig             effectief           fors
# 4         schoon            dood                  fors             na
# 5       kritisch       integraal              goedkoop          reëel
# 6      efficiënt          schoon              duurzaam         veilig
# 7          prima        langzaam             jaarlijks  achterstallig
# 8           stil       regionaal                 flink      volstrekt
# 9       redelijk          fysiek                zuinig        spoedig
#
#     opinion_27_SP opinion_27_ChristenUnie opinion_27_PVV opinion_27_RPF  \
# 0            duur               regionaal           duur     ruimtelijk
# 1     ingewikkeld                 logisch            gek         totaal
# 2     gehandicapt                    fors         mobiel      volstrekt
# 3  controversieel                goedkoop      eindelijk      technisch
# 4       landelijk                   apart           krom      waardevol
# 5     structureel              elektrisch      technisch  aantrekkelijk
# 6          gratis               stedelijk        onnodig      driedaags
# 7     provinciaal                  zuinig     rotterdams      integraal
# 8    demissionair                  schoon       kostbaar       ridicuul
# 9       kwetsbaar                 onnodig          stoer         extern
#
#   opinion_27_LPF opinion_27_GPV opinion_27_VVD opinion_27_OSF  \
# 0      werkelijk          trouw           duur      regionaal
# 1      regionaal    aanzienlijk           krom      effectief
# 2      cultureel       destijds    provinciaal    particulier
# 3   onderliggend           klip         veilig       prachtig
# 4   begrijpelijk           enig          kwijt   fundamenteel
# 5           plat     koninklijk        bebouwd          zwart
# 6      volstrekt     onbenullig    ingewikkeld         ideaal
# 7       variabel        plastic   gemeentelijk      dynamisch
# 8       oneindig  professioneel         gratis   dichtbevolkt
# 9          stads   grootschalig       relatief          licht
#
#   opinion_27_Leefbaar Nederland
# 0                      leefbaar
# 1                        schoon
# 2                           gek
# 3                          duur
# 4                      geweldig
# 5                     werkelijk
# 6                     gemiddeld
# 7                       extreem
# 8                   provinciaal
# 9                   gehandicapt
#
# [10 rows x 17 columns]
#
# JSD: 0.866964657718
#     topic_70 opinion_70_50PLUS opinion_70_PvdD    opinion_70_D66  \
# 0       bank        kunstmatig        monetair  macro-economisch
# 1     crisis            lastig    democratisch            stevig
# 2     schuld            moreel     gezamenlijk       structureel
# 3       euro      betrekkelijk            bang      democratisch
# 4      markt       voorzichtig       werkelijk            grieks
# 5   economie              diep      onmogelijk       automatisch
# 6     risico       willekeurig       zuidelijk          variabel
# 7     sector             zwart        volkomen             duits
# 8  noodfonds            online        vergaand           privaat
# 9     lening       ontstellend          grieks          failliet
#
#           opinion_70_CDA opinion_70_PvdA opinion_70_GroenLinks opinion_70_SGP  \
# 0              tijdelijk          totaal              duurzaam         stevig
# 1                privaat       werkelijk                stevig     essentieel
# 2              permanent         privaat                grieks       cruciaal
# 3                 totaal         akkoord             effectief         grieks
# 4                  reëel          gezond          democratisch         strikt
# 5  financieel-economisch          grieks              monetair      eindelijk
# 6               ongekend      allereerst      macro-economisch         scherp
# 7                 streng        failliet                streng         lastig
# 8             budgettair    onverstandig                  diep         gezond
# 9               relatief          rechts           structureel      eenzijdig
#
#   opinion_70_SP opinion_70_ChristenUnie opinion_70_PVV         opinion_70_RPF  \
# 0        grieks                duurzaam         grieks                conform
# 1    commissie-                  grieks       failliet                   vals
# 2      monetair               permanent         streng  financieel-economisch
# 3          fors                maximaal     gigantisch                 gerust
# 4           wit               tijdelijk  zuid-europees       arbeidsintensief
# 5      failliet                monetair        keihard         onaanvaardbaar
# 6   automatisch                  scherp           diep              uitvoerig
# 7     tijdelijk                 privaat       goedkoop      cultuurhistorisch
# 8  fundamenteel       toekomstbestendig      anderhalf           gelijkgezind
# 9     zogenaamd             structureel            gek               dringend
#
#          opinion_70_LPF opinion_70_GPV opinion_70_VVD         opinion_70_OSF  \
# 0                 duits    inhoudelijk         stevig                   zwak
# 1                  duur    voorzichtig           fors            realistisch
# 2           afhankelijk          flink      tijdelijk               monetair
# 3  voorwaardenscheppend      inflatoir          reëel               failliet
# 4              aanwezig         simpel       cruciaal  financieel-economisch
# 5          onrechtmatig     waardevast        privaat                 grieks
# 6            letterlijk          reëel            wit                   nauw
# 7           gezamenlijk        globaal    automatisch               ongekend
# 8                zinvol    particulier         streng           ontoereikend
# 9           onduidelijk  laaggeschoold         strikt          geloofwaardig
#
#   opinion_70_Leefbaar Nederland
# 0                     rampzalig
# 1                          ruim
# 2                         dicht
# 3                   enthousiast
# 4                  partijgenote
# 5                      rendabel
# 6                       bevoegd
# 7                   inhoudelijk
# 8                     verzoeken
# 9                        kubiek
#
# [10 rows x 17 columns]
#
# JSD: 0.866179934266
#          topic_14 opinion_14_50PLUS     opinion_14_PvdD   opinion_14_D66  \
# 0         project        toejuichen       belanghebbend        kwetsbaar
# 1       procedure         gedupeerd            kritisch  vanzelfsprekend
# 2  besluitvorming         overgroot          zorgvuldig              gek
# 3      vertraging      gebruikelijk             bevoegd       behoorlijk
# 4         besluit      niet-sociaal          decentraal             waar
# 5          crisis     onbestuurbaar  europeesrechtelijk         aanwezig
# 6      herstelwet        doodsimpel           regionaal       decentraal
# 7     versnelling              half            omwonend        werkelijk
# 8     alternatief        volwaardig         ingewikkeld           recent
# 9      uitvoering         vrijelijk            compleet       amsterdams
#
#      opinion_14_CDA   opinion_14_PvdA opinion_14_GroenLinks opinion_14_SGP  \
# 0         integraal        zorgvuldig             permanent      eenvoudig
# 1        ruimtelijk             vroeg             expliciet     decentraal
# 2          destijds         integraal                divers         actief
# 3       ingewikkeld     belanghebbend            ruimtelijk       kritisch
# 4         technisch         eenvoudig             integraal      expliciet
# 5       inhoudelijk         expliciet            zorgvuldig         stevig
# 6        zorgvuldig        ruimtelijk             tijdelijk          flink
# 7       interessant        definitief                jammer      technisch
# 8           complex  infrastructureel          fundamenteel        complex
# 9  infrastructureel       ingewikkeld              cruciaal         nuttig
#
#       opinion_14_SP opinion_14_ChristenUnie opinion_14_PVV  opinion_14_RPF  \
# 0  infrastructureel               tijdelijk     historisch      ruimtelijk
# 1        zorgvuldig              ruimtelijk     amsterdams     rechterlijk
# 2     belanghebbend                  dubbel      effectief            ruim
# 3        ruimtelijk                   prima  klip-en-klaar         formeel
# 4         integraal               integraal   inzichtelijk      historisch
# 5              waar             uitsluitend      technisch        tevreden
# 6          autonoom        infrastructureel    onvoldoende  onherroepelijk
# 7           complex             betrouwbaar     hoegenaamd  bovenregionaal
# 8        amsterdams                 globaal   onrechtmatig         subtiel
# 9              duur                  lastig  onafhankelijk   belanghebbend
#
#      opinion_14_LPF        opinion_14_GPV opinion_14_VVD  opinion_14_OSF  \
# 0          negatief                   vol     definitief    planologisch
# 1  infrastructureel            kamerbreed      inclusief       langdurig
# 2              zwak           afhankelijk     zorgvuldig      onverhoeds
# 3         ambtelijk  sociaal-democratisch          klaar        negatief
# 4         expliciet         onverantwoord          vroeg      behoorlijk
# 5            tijdig           structureel        correct        algeheel
# 6        ruimtelijk        grondwettelijk      tijdelijk  administratief
# 7            recent          gelijktijdig  belanghebbend       inclusief
# 8           onnodig              tactisch          prima      egoïstisch
# 9       statistisch                  zwak    interessant          lastig
#
#   opinion_14_Leefbaar Nederland
# 0                     gemiddeld
# 1                    zorgvuldig
# 2                  aanvankelijk
# 3                      flexibel
# 4                      benodigd
# 5                     jarenlang
# 6                     waardevol
# 7               publiek-privaat
# 8                     voordelig
# 9                          boos
#
# [10 rows x 17 columns]
#
# JSD: 0.855506397702
#              topic_0 opinion_0_50PLUS      opinion_0_PvdD opinion_0_D66  \
# 0              groei          pervers            solidair   structureel
# 1           economie      oneigenlijk  onverantwoordelijk          fors
# 2            uitgaaf       behoorlijk               abuis   interessant
# 3             tekort   mogelijkerwijs           informeel         reëel
# 4  lastenverlichting      onevenredig                wijd         vroeg
# 5       staatsschuld            dicht         hardwerkend       robuust
# 6          begroting        gedupeerd          essentieel          ruim
# 7        beschouwing    klip-en-klaar                  na        lastig
# 8      miljoenennota       kunstmatig           menselijk    budgettair
# 9          meevaller             waar         doortastend       fiscaal
#
#   opinion_0_CDA opinion_0_PvdA opinion_0_GroenLinks opinion_0_SGP  \
# 0   structureel    structureel          structureel   structureel
# 1        solide     collectief           budgettair    budgettair
# 2          fors       nominaal                paars      negatief
# 3          ruim     behoedzaam           trendmatig   jongstleden
# 4     gemiddeld    voortdurend                 fors          fors
# 5    collectief       eenmalig                reëel     volstrekt
# 6      negatief           ruim           behoedzaam         reëel
# 7        gezond     budgettair          merkwaardig         paars
# 8        recent      gemiddeld             duurzaam        recent
# 9      generiek      inclusief            werkelijk          ruim
#
#   opinion_0_SP opinion_0_ChristenUnie opinion_0_PVV opinion_0_RPF  \
# 0  structureel            structureel      onzinnig   structureel
# 1         fors                   fors        modaal      duurzaam
# 2        paars            voortdurend          fors    collectief
# 3         rijk  financieel-economisch      werkloos          waar
# 4    gemiddeld                  reëel         kwijt        moreel
# 5     negatief                  paars         flink      relevant
# 6  interessant              feitelijk         links   luchthartig
# 7        links                  flink        gezond     ongewenst
# 8  alternatief            voorzichtig          half         paars
# 9        flink                onzeker       onzeker     visionair
#
#   opinion_0_LPF          opinion_0_GPV opinion_0_VVD      opinion_0_OSF  \
# 0   structureel               tevreden   structureel           creatief
# 1    behoorlijk                   fors    collectief        ondergronds
# 2   realistisch              langdurig          fors        aanzienlijk
# 3     jaarlijks         onaanvaardbaar   hardwerkend         ingrijpend
# 4         waard  financieel-economisch   interessant            beslist
# 5       voldoen            particulier         links        geleidelijk
# 6     werkelijk      arbeidsongeschikt          ruim             simpel
# 7      kritisch             waardevast    behoorlijk          wezenlijk
# 8         reëel              onderling          rijk            westers
# 9          rijk                  flink    budgettair  gemeenschappelijk
#
#   opinion_0_Leefbaar Nederland
# 0                  aantoonbaar
# 1                         zoet
# 2                         zuur
# 3                         duur
# 4                   koninklijk
# 5                         leuk
# 6               controversieel
# 7                     leefbaar
# 8                   sympathiek
# 9                      akkoord
#
# [10 rows x 17 columns]
#
# JSD: 0.855005689518
#           topic_75 opinion_75_50PLUS opinion_75_PvdD opinion_75_D66  \
# 0             dier            stalen        dierlijk         extern
# 1           sector          emeritus     plantaardig         lastig
# 2            vlees               fit      intrinsiek       virtueel
# 3           verbod          klinisch          gezond        ethisch
# 4    dierenwelzijn            aardig       intensief      intensief
# 5  volksgezondheid          regulier      biologisch        logisch
# 6      veehouderij          optimaal         ethisch      eindelijk
# 7          welzijn          wanhopig     commercieel       gangbaar
# 8         megastal          inlassen            ziek           bont
# 9           waarde     onfatsoenlijk            ruim       redelijk
#
#   opinion_75_CDA opinion_75_PvdA opinion_75_GroenLinks opinion_75_SGP  \
# 0         streng    parlementair             intensief        bijbels
# 1      volstrekt       ontuchtig             blijkbaar      intensief
# 2     preventief          bewust       diervriendelijk      deskundig
# 3         geacht        duurzaam            preventief         gezond
# 4       aanwezig         ethisch                gezond         schoon
# 5        afdoend       intensief           fatsoenlijk   beroepsmatig
# 6      afkomstig        seksueel            intrinsiek       relevant
# 7         moreel        adequaat             effectief     preventief
# 8           waar          moreel                streng      tijdelijk
# 9       dierlijk      preventief            veterinair     veterinair
#
#   opinion_75_SP opinion_75_ChristenUnie   opinion_75_PVV opinion_75_RPF  \
# 0     intensief              behoorlijk       levenslang   vrijblijvend
# 1       ethisch                duurzaam          ritueel        onnodig
# 2  parlementair                 ethisch     parlementair        complex
# 3          bont               afkomstig  verschrikkelijk         tijdig
# 4     wenselijk                    warm             ziek       virtueel
# 5        gezond             binnenlands       onmogelijk      voorlopig
# 6     volstrekt               intensief    onafhankelijk     forfaitair
# 7       onnodig                  gezond          onnodig   operationeel
# 8      dierlijk                 nertsen       veterinair        extreem
# 9        humaan                  recent              net      uiterlijk
#
#    opinion_75_LPF      opinion_75_GPV opinion_75_VVD opinion_75_OSF  \
# 0     sportvisser  bestuursrechtelijk     intrinsiek    uitsluitend
# 1          veilig               ijzer   parlementair          exact
# 2       intensief                puur           dood        beperkt
# 3   vertrouwelijk           inflatoir         moreel       inherent
# 4    besmettelijk           praktisch         totaal    persoonlijk
# 5        dierlijk           eenvoudig     veterinair       tevreden
# 6            kaal             globaal        voldoen        ethisch
# 7  administratief         strategisch        kwalijk       tamelijk
# 8      sympathiek     rechtsstatelijk   onmiddellijk    kritiekloos
# 9     gezamenlijk              legaal       dierlijk         giftig
#
#   opinion_75_Leefbaar Nederland
# 0                    middelbaar
# 1                      minimaal
# 2                  kleinschalig
# 3                   rechterlijk
# 4                   onvoldoende
# 5                         links
# 6                       zonodig
# 7                     efficiënt
# 8                     voormalig
# 9                    budgettair
#
# [10 rows x 17 columns]
#
# JSD: 0.853731742309
#         topic_63 opinion_63_50PLUS opinion_63_PvdD   opinion_63_D66  \
# 0       vrijheid          klinisch       religieus        religieus
# 1          waard       inhoudelijk      zorgvuldig         liberaal
# 2    samenleving        letterlijk     persoonlijk     fundamenteel
# 3  discriminatie      onbehoorlijk     christelijk         seksueel
# 4           norm         eenvoudig    democratisch       geestelijk
# 5  meningsuiting             menig    fundamenteel      islamitisch
# 6         moslim     tegenstrijdig        redelijk       historisch
# 7    rechtsstaat      gedeeltelijk         onnodig           moreel
# 8          islam           correct       welbewust     democratisch
# 9          staat              diep     islamitisch  vanzelfsprekend
#
#   opinion_63_CDA opinion_63_PvdA opinion_63_GroenLinks     opinion_63_SGP  \
# 0      religieus    fundamenteel           islamitisch        christelijk
# 1    islamitisch       cultureel          democratisch               diep
# 2   fundamenteel          moreel             religieus       fundamenteel
# 3   democratisch       religieus       vanzelfsprekend        islamitisch
# 4      cultureel          veilig          fundamenteel          religieus
# 5    persoonlijk     islamitisch           christelijk             bewust
# 6         actief       onderling              liberaal            bijbels
# 7    christelijk          recent                   vol  joods-christelijk
# 8           diep    democratisch              negatief          omstreden
# 9     geestelijk    rechtstreeks                moreel       godsdienstig
#
#      opinion_63_SP opinion_63_ChristenUnie   opinion_63_PVV opinion_63_RPF  \
# 0        religieus            fundamenteel      islamitisch       liberaal
# 1         liberaal               religieus            joods      normatief
# 2        werkelijk            democratisch            links         moreel
# 3             raar                  moreel  verschrikkelijk         modern
# 4           oneens                neutraal          westers      wenselijk
# 5        expliciet               expliciet       letterlijk   dubbelhartig
# 6          onnodig                  scherp      gewelddadig         scherp
# 7           actief              geestelijk     democratisch       werkzaam
# 8            zwart               cultureel      christelijk      ongeboren
# 9  vanzelfsprekend         vanzelfsprekend           welkom           zwak
#
#     opinion_63_LPF        opinion_63_GPV opinion_63_VVD  opinion_63_OSF  \
# 0         neutraal                moreel       liberaal           frans
# 1        religieus             dagelijks   fundamenteel          vreemd
# 2      islamitisch           voortdurend    islamitisch       cultureel
# 3            turks             zichtbaar         recent      broodnodig
# 4      principieel              tolerant         stevig     principieel
# 5     parlementair        onvermijdelijk    buitenlands          moreel
# 6     fundamenteel                recent       radicaal  onvermijdelijk
# 7           modern               schaars      religieus  ongebruikelijk
# 8        praktisch              gevoelig      volstrekt           turks
# 9  vanzelfsprekend  intergouvernementeel      werkelijk       toetsbaar
#
#   opinion_63_Leefbaar Nederland
# 0                       voldoen
# 1                       beperkt
# 2                        divers
# 3                   voortdurend
# 4                        zinnig
# 5                   betrouwbaar
# 6                          bang
# 7                      briljant
# 8                       akkoord
# 9                 allesbepalend
#
# [10 rows x 17 columns]
#
# JSD: 0.850194967691
#                  topic_28 opinion_28_50PLUS  opinion_28_PvdD opinion_28_D66  \
# 0                indiener      parlementair         seksueel    interessant
# 1         initiatiefnemer         langdurig        ontuchtig      praktisch
# 2              initiatief        historisch  sociaal-ethisch   parlementair
# 3  initiatiefwetsvoorstel              ruim     beroepsmatig     behoorlijk
# 4      initiatiefvoorstel           unaniem       verdrietig         zuiver
# 5                  winkel      traditioneel       bescheiden    principieel
# 6                    doel         eenvoudig          nertsen     sympathiek
# 7                 inbreng       voorliggend      enthousiast           raar
# 8              waardering       opmerkelijk          kenbaar        normaal
# 9               wetgeving            actief        selectief         lastig
#
#    opinion_28_CDA opinion_28_PvdA opinion_28_GroenLinks opinion_28_SGP  \
# 0     principieel          jammer            collectief           ruim
# 1      zorgvuldig        redelijk           persoonlijk    oneigenlijk
# 2       expliciet       eenvoudig              kritisch    toeristisch
# 3      sympathiek       overbodig           principieel    gezamenlijk
# 4     voorliggend        maximaal              aanwezig    persoonlijk
# 5      allereerst      sympathiek                jammer       kritisch
# 6     particulier        beperken           inhoudelijk         divers
# 7     interessant  oorspronkelijk        oorspronkelijk    principieel
# 8  oorspronkelijk        aanwezig           oneigenlijk      volstrekt
# 9            ruim        relevant             overbodig       liberaal
#
#   opinion_28_SP opinion_28_ChristenUnie opinion_28_PVV opinion_28_RPF  \
# 0   toeristisch              zorgvuldig      ontuchtig         jammer
# 1      kritisch          oorspronkelijk         jammer    zelfstandig
# 2       logisch            parlementair     subjectief   strafwaardig
# 3          ruim                cruciaal      eenvoudig       kritisch
# 4    sympathiek             voorliggend         fysiek         scherp
# 5      aanwezig               praktisch    gehandicapt         recent
# 6   principieel              allereerst      wenselijk         geacht
# 7         dicht                  bewust           zwak         blanco
# 8          druk              sympathiek          haags    evenwichtig
# 9   structureel                 normaal         rustig     preventief
#
#   opinion_28_LPF opinion_28_GPV opinion_28_VVD   opinion_28_OSF  \
# 0          prima          paars    principieel      voorliggend
# 1    interessant       aanwezig      praktisch        inclusief
# 2         jammer  vergelijkbaar        onjuist           vreemd
# 3    principieel       ongelijk       aanwezig    problematisch
# 4       aanwezig      diezelfde       negatief      weerspannig
# 5      technisch      datzelfde    inhoudelijk        belabberd
# 6      excessief       tevreden    gezamenlijk        eenzijdig
# 7     emotioneel        robuust      werkelijk     decennialang
# 8           smal      onderling      expliciet  vertegenwoordig
# 9           bang        verbaal     allereerst         dusdanig
#
#   opinion_28_Leefbaar Nederland
# 0                    vlekkeloos
# 1                   rechterlijk
# 2                   voortdurend
# 3                      duurzaam
# 4                     afgelopen
# 5                     overbodig
# 6                 uitdrukkelijk
# 7                   inhoudelijk
# 8                   onevenredig
# 9                   requisitoir
#
# [10 rows x 17 columns]
#
# JSD: 0.84989058013
#              topic_26 opinion_26_50PLUS opinion_26_PvdD      opinion_26_D66  \
# 0            pensioen         gemiddeld   gedoogpartner         geleidelijk
# 1                 aow          redelijk             rap          vrijwillig
# 2       pensioenfonds              fors     mediterraan          toekomstig
# 3             partner           talrijk   gedenkwaardig             fiscaal
# 4               fonds             kwijt      toekomstig  pensioengerechtigd
# 5            leeftijd       voorliggend           deels          essentieel
# 6           generatie            recent    aanvankelijk            flexibel
# 7         aowleeftijd            actief   aantrekkelijk        alleenstaand
# 8           verhoging     onbetrouwbaar        leefbaar              jammer
# 9  levensloopregeling           billijk        belgisch         evenwichtig
#
#       opinion_26_CDA opinion_26_PvdA opinion_26_GroenLinks  \
# 0            fiscaal         fiscaal                  rijk
# 1        zelfstandig     zelfstandig               fiscaal
# 2              reëel      collectief             gemiddeld
# 3         collectief      vrijwillig            toekomstig
# 4         toekomstig       gemiddeld                jammer
# 5  arbeidsongeschikt        generiek           fatsoenlijk
# 6              jarig        solidair                 klaar
# 7       gedeeltelijk          totaal               normaal
# 8        gezamenlijk        destijds               onnodig
# 9      aantrekkelijk        adequaat              houdbaar
#
#        opinion_26_SGP       opinion_26_SP opinion_26_ChristenUnie  \
# 0         zelfstandig               jarig                 fiscaal
# 1            cruciaal           gemiddeld               onbetaald
# 2             normaal          toekomstig              toekomstig
# 3          risicovrij                rijk                cruciaal
# 4                druk         fatsoenlijk              collectief
# 5        nieuwsgierig            solidair                    fors
# 6            redelijk             onnodig                  tijdig
# 7                leeg          onmogelijk              vrijwillig
# 8            flexibel  pensioengerechtigd               gemiddeld
# 9  pensioengerechtigd       onbetrouwbaar       toekomstbestendig
#
#   opinion_26_PVV        opinion_26_RPF      opinion_26_LPF opinion_26_GPV  \
# 0    zelfstandig             ongewenst            creatief     principaal
# 1      gemiddeld  medeverantwoordelijk             bejaard     klakkeloos
# 2           ruim          ondeugdelijk  pensioengerechtigd    inhoudelijk
# 3     toekomstig           ideologisch          deugdelijk           raar
# 4     vrijwillig                  stil         structureel           boos
# 5    principieel        administratief           onverkort        correct
# 6          jarig                  waar              gratis           leuk
# 7     zorgvuldig        onoverkomelijk        gelijktijdig      marginaal
# 8     historisch                    na         tegendraads       redelijk
# 9           fors             verplicht           verplicht      zogenaamd
#
#    opinion_26_VVD opinion_26_OSF opinion_26_Leefbaar Nederland
# 0      vrijwillig       negatief                          leuk
# 1  oorspronkelijk    uitsluitend                          duur
# 2            ruim    voorliggend                          zuur
# 3         logisch    merkwaardig                    preventief
# 4      toekomstig        beperkt                    sympathiek
# 5          vreemd   decennialang                     overbodig
# 6     structureel      jarenlang                 geloofwaardig
# 7        maximaal     uitbreiden                     voorlopig
# 8         fiscaal       nominaal                       continu
# 9      ontzettend       maximaal                       vrolijk
#
# [10 rows x 17 columns]
#
# JSD: 0.842951194566
#            topic_57 opinion_57_50PLUS   opinion_57_PvdD   opinion_57_D66  \
# 0           politie           eenzaam          radicaal        landelijk
# 1        veiligheid            ivoren         makkelijk        regionaal
# 2          Justitie            lastig  staatsgevaarlijk  strafrechtelijk
# 3            straat             zijde   misselijkmakend       preventief
# 4             agent          emeritus      stelselmatig        dagelijks
# 5      burgemeester      ontvankelijk       voortdurend     begrijpelijk
# 6        prioriteit   nederlandstalig        hinderlijk       justitieel
# 7             korps         egalitair           bevoegd             fors
# 8              taak     onbestuurbaar     onafhankelijk            blauw
# 9  veiligheidsregio        rekenrente       gewelddadig     operationeel
#
#   opinion_57_CDA opinion_57_PvdA opinion_57_GroenLinks opinion_57_SGP  \
# 0      landelijk       landelijk             landelijk      regionaal
# 1         veilig          veilig             regionaal      landelijk
# 2      effectief       regionaal             effectief         stevig
# 3     preventief          stevig             volstrekt     justitieel
# 4      regionaal       effectief                  bang    incidenteel
# 5       aanwezig       strafbaar         onafhankelijk      huiselijk
# 6      crimineel         formeel           onduidelijk     preventief
# 7   fundamenteel           blauw                veilig   operationeel
# 8    oneigenlijk       integraal            amsterdams   toegankelijk
# 9         actief         primair           rechterlijk       krachtig
#
#   opinion_57_SP opinion_57_ChristenUnie opinion_57_PVV       opinion_57_RPF  \
# 0       voldoen               landelijk     marokkaans               wetens
# 1      kritisch                  veilig      eindelijk           ingrijpend
# 2        veilig               overbodig          blauw             kritisch
# 3     landelijk              justitieel      landelijk         stelselmatig
# 4     crimineel               regionaal           waar           zorgvuldig
# 5   onvoldoende               makkelijk           slap           justitieel
# 6    vrijwillig             commercieel         divers      materialistisch
# 7      aanwezig             principieel      voormalig             sportief
# 8         blauw           ondergeschikt         veilig  binnenlandspolitiek
# 9        simpel            operationeel          prima         situationeel
#
#   opinion_57_LPF    opinion_57_GPV opinion_57_VVD       opinion_57_OSF  \
# 0      effectief  volkenrechtelijk      landelijk     staatsrechtelijk
# 1      crimineel      rechtstreeks         veilig     wetenschappelijk
# 2     rotterdams   organisatorisch      regionaal  grensoverschrijdend
# 3   democratisch         uitvoerig      effectief           monistisch
# 4     preventief        budgettair   operationeel         verdedigbaar
# 5         veilig        regelmatig       aanwezig                 knap
# 6      volstrekt       structureel      integraal                 open
# 7           half         landelijk     justitieel              uiterst
# 8    betrouwbaar          destijds    voortdurend      eendimensionaal
# 9    voortdurend           markant    structureel              formeel
#
#   opinion_57_Leefbaar Nederland
# 0                      aanwezig
# 1                   rechterlijk
# 2                           vol
# 3                     zogenaamd
# 4                     volstrekt
# 5                       voldoen
# 6                   antilliaans
# 7                     werkelijk
# 8                   persoonlijk
# 9                        mobiel
#
# [10 rows x 17 columns]
#
# JSD: 0.841523923884
#          topic_61 opinion_61_50PLUS opinion_61_PvdD opinion_61_D66  \
# 0           markt            dubbel    onomkeerbaar         lastig
# 1       consument            totaal   onafhankelijk       kritisch
# 2    marktwerking          redelijk       deskundig       liberaal
# 3           prijs          aanwezig            half        privaat
# 4    concurrentie              half    fundamenteel       goedkoop
# 5  liberalisering          identiek          jammer  onafhankelijk
# 6   privatisering  niet-gehandicapt  controversieel           slim
# 7          tarief         vrijelijk        goedkoop      blijkbaar
# 8          sector      ontvankelijk     zelfstandig      technisch
# 9  energiebedrijf   nederlandstalig        heilzaam    commercieel
#
#   opinion_61_CDA opinion_61_PvdA opinion_61_GroenLinks  opinion_61_SGP  \
# 0       redelijk     commercieel           commercieel     betrouwbaar
# 1  onafhankelijk         normaal               privaat   onafhankelijk
# 2    commercieel       oneerlijk                vreemd      burgerlijk
# 3        privaat          nuttig           buitenlands      universeel
# 4    buitenlands            duur              cruciaal          stevig
# 5   aanmerkelijk        goedkoop              redelijk     commercieel
# 6    transparant        redelijk           voortdurend         voldoen
# 7      feitelijk     buitenlands              duurzaam        relevant
# 8       relevant   onafhankelijk                  duur      collectief
# 9      uitvoerig      collectief              goedkoop  administratief
#
#   opinion_61_SP opinion_61_ChristenUnie opinion_61_PVV   opinion_61_RPF  \
# 0      redelijk                   duits        primair         dringend
# 1     efficiënt                 voldoen       ongelijk      merkwaardig
# 2       privaat                duurzaam    afhankelijk          voorbij
# 3   buitenlands                  actief      momenteel          onnodig
# 4      goedkoop             commercieel         mobiel  toekomstgericht
# 5   commercieel                relatief        privaat         generiek
# 6          slim                    doof         intern         prachtig
# 7   interessant            aanmerkelijk       dadelijk     vrijblijvend
# 8         duits                goedkoop          duits        ambitieus
# 9         prima              omvangrijk       maximaal      aanzienlijk
#
#   opinion_61_LPF opinion_61_GPV opinion_61_VVD   opinion_61_OSF  \
# 0           fout          reëel        privaat       essentieel
# 1         simpel   onmiskenbaar       redelijk  vanzelfsprekend
# 2    ideologisch   begrijpelijk    commercieel          privaat
# 3      efficiënt        passief         mobiel        makkelijk
# 4          flink    kwalitatief    particulier     onmiddellijk
# 5          groen    opmerkelijk       liberaal         kritisch
# 6        kordaat           lief           duur         dominant
# 7         gratis        spoedig     zorgvuldig         geschikt
# 8        logisch          engel    buitenlands           handig
# 9           diep          vroeg           slim       onvoorzien
#
#   opinion_61_Leefbaar Nederland
# 0                          fors
# 1                      autonoom
# 2                  onomkeerbaar
# 3                        kubiek
# 4                     oneerlijk
# 5            europeesrechtelijk
# 6                  gedeeltelijk
# 7                      ongedaan
# 8                         dwars
# ...
# 6   provinciaal             provinciaal           zout      consequent
# 7       privaat               ongewenst     decentraal       informeel
# 8  planologisch              regelmatig        privaat        parallel
# 9      geschikt              decentraal       benodigd        redelijk
#
#    opinion_92_LPF  opinion_92_GPV opinion_92_VVD opinion_92_OSF  \
# 0        parallel      ruimtelijk     ruimtelijk        akkoord
# 1      ruimtelijk          lastig      integraal    buitendijks
# 2     particulier       risicovol     decentraal     welwillend
# 3       uitvoerig           groen      technisch         zeeuws
# 4       effectief             vol   gemeentelijk    ineffectief
# 5   tegenstrijdig           reëel            sec           duur
# 6       zogenaamd         terzake      stedelijk   onmiddellijk
# 7          jammer      onmogelijk          dicht      oplosbaar
# 8         gedegen  oorspronkelijk          uniek      technisch
# 9  institutioneel        aanwezig   planologisch          paars
#
#   opinion_92_Leefbaar Nederland
# 0                     inventief
# 1               publiek-privaat
# 2                       beperkt
# 3                      optimaal
# 4                       schamel
# 5                     doelmatig
# 6                     risicovol
# 7                       voldoen
# 8                      dadelijk
# 9                          raak
#
# [10 rows x 17 columns]
#
# JSD: 0.747260203099
#      topic_31 opinion_31_50PLUS opinion_31_PvdD opinion_31_D66 opinion_31_CDA  \
# 0         uur           eenzaam        chemisch         veilig         veilig
# 1  veiligheid                na     recentelijk     gevaarlijk     gevaarlijk
# 2      risico       onbesproken         spoedig      tijdelijk     allereerst
# 3       spoor            geldig     buitenlands          apart       adequaat
# 4        ramp              ruim  doorslaggevend           half    automatisch
# 5    incident         materieel        prachtig    onvoldoende        primair
# 6         ure         risicovol          veilig      anderhalf           half
# 7   onderhoud             haags        windstil        complex         totaal
# 8      gevaar             bizar    onderliggend    uitvoerbaar        voldoen
# 9        huis          minimaal    vrijblijvend       dringend  achterstallig
#
#   opinion_31_PvdA opinion_31_GroenLinks opinion_31_SGP opinion_31_SP  \
# 0          veilig                veilig       adequaat        veilig
# 1      gevaarlijk            gevaarlijk         totaal    gevaarlijk
# 2            waar                 klaar      volstrekt          stil
# 3          extern             volstrekt    onvoldoende        extern
# 4            slim                recent       redelijk         prima
# 5     ingewikkeld             deskundig         modern      redelijk
# 6        redelijk                   vol      gemiddeld     wenselijk
# 7            rood         vergelijkbaar   territoriaal          krap
# 8           prima             blijkbaar           half     tijdelijk
# 9          simpel             integraal         veilig        recent
#
#   opinion_31_ChristenUnie opinion_31_PVV  opinion_31_RPF opinion_31_LPF  \
# 0              gevaarlijk       aanwezig   onafhankelijk    aanzienlijk
# 1                  veilig         veilig  doorslaggevend       maximaal
# 2               technisch       onveilig  voorwaardelijk        voorbij
# 3               inclusief     gevaarlijk       objectief      menselijk
# 4                    fors           half        aanwezig      effectief
# 5               tijdelijk      makkelijk          finaal          reëel
# 6                  tijdig    afhankelijk          valide    voorliggend
# 7                minimaal     letterlijk        haalbaar         jammer
# 8                  overig         divers             mis        prettig
# 9             strategisch    structureel         logisch      expliciet
#
#    opinion_31_GPV opinion_31_VVD opinion_31_OSF opinion_31_Leefbaar Nederland
# 0       materieel         veilig      eenvoudig                  demissionair
# 1      machteloos     gevaarlijk          dicht                   hartgrondig
# 2          vitaal           half    structureel                      krachtig
# 3  onaanvaardbaar        voldoen     hardnekkig                         droog
# 4      potentieel       aanwezig     kunstmatig                   radioactief
# 5       overbodig      anderhalf      tijdelijk                      kritisch
# 6      koninklijk         scherp         aardig                        gezond
# 7         evident      integraal    automatisch                      nodeloos
# 8  programmatisch       onveilig         recent                      adequaat
# 9         onnodig     definitief       optimaal                          zuur
#
# [10 rows x 17 columns]
#
# JSD: 0.743335255208
#           topic_60 opinion_60_50PLUS       opinion_60_PvdD opinion_60_D66  \
# 0       ziekenhuis      voorspelbaar                triest      chronisch
# 1      verzekeraar            divers  antibioticaresistent           ziek
# 2  zorgverzekeraar           perfect          gegarandeerd     collectief
# 3           premie          prachtig              doodziek       nominaal
# 4         huisarts              kaal                  lief           duur
# 5          patiënt        onmogelijk       apotheekhoudend      effectief
# 6          systeem          identiek                gezond      gemiddeld
# 7      verzekering  niet-gehandicapt     gemeenschappelijk        medisch
# 8     marktwerking        volwaardig           transparant    particulier
# 9  gezondheidszorg         vrijelijk           commercieel    gezamenlijk
#
#   opinion_60_CDA opinion_60_PvdA opinion_60_GroenLinks opinion_60_SGP  \
# 0      chronisch         medisch                  ziek        medisch
# 1           ziek            duur              nominaal           ziek
# 2    onverzekerd       chronisch            collectief      regionaal
# 3    particulier           acuut             chronisch         gezond
# 4        medisch            ziek                gezond      chronisch
# 5          acuut     onverzekerd               medisch          acuut
# 6    spoedeisend        nominaal           onverzekerd    zelfstandig
# 7       nominaal       doelmatig             gemiddeld       nominaal
# 8    gehandicapt   farmaceutisch             doelmatig    particulier
# 9     collectief          gezond               onnodig       geweldig
#
#   opinion_60_SP opinion_60_ChristenUnie       opinion_60_PVV opinion_60_RPF  \
# 0          ziek                nominaal                 ziek           fors
# 1          duur               chronisch            chronisch           fair
# 2   onverzekerd                    ziek              medisch        onjuist
# 3     chronisch                 medisch                acuut      afnemende
# 4      nominaal     inkomensafhankelijk          spoedeisend   rechtstreeks
# 5       medisch                   acuut                 ruim        gunstig
# 6         acuut               effectief          onverzekerd       duurzaam
# 7        gezond                cruciaal             solidair      ongunstig
# 8      solidair                    duur  inkomensafhankelijk     verregaand
# 9     ongewenst             gehandicapt            tijdelijk   substantieel
#
#   opinion_60_LPF opinion_60_GPV  opinion_60_VVD  opinion_60_OSF  \
# 0          acuut          licht     particulier      onverhoeds
# 1           ziek   onmiskenbaar         medisch          lastig
# 2      chronisch      makkelijk        nominaal        tamelijk
# 3       solidair      zichtbaar          gezond       tibetaans
# 4     budgettair          recht     zelfstandig       italiaans
# 5           duur    geopolitiek          scherp   onontkoombaar
# 6     academisch     onmogelijk            duur       evenredig
# 7    gehandicapt      vervelend            ziek     onevenredig
# 8        privaat         abrupt       werkelijk            iers
# 9           leeg    ondoordacht  administratief  bovenwettelijk
#
#   opinion_60_Leefbaar Nederland
# 0                       medisch
# 1                      nominaal
# 2           inkomensafhankelijk
# 3                        mobiel
# 4                   automatisch
# 5                          ruim
# 6                      leefbaar
# 7                           gek
# 8                        online
# 9                         dicht
#
# [10 rows x 17 columns]
#
# JSD: 0.730269266565
#        topic_44 opinion_44_50PLUS opinion_44_PvdD     opinion_44_D66  \
# 0     provincie        onredelijk             net          regionaal
# 1         regio        allereerst     provinciaal       democratisch
# 2   herindeling            dubbel      gemonitord       gemeentelijk
# 3     draagvlak               bar       olympisch        provinciaal
# 4  samenwerking        doelbewust       aanstaand        zelfstandig
# 5       bestuur         wenselijk          actief         volwaardig
# 6       inwoner            geldig           dwars        inhoudelijk
# 7     bevolking        volwaardig        relevant          stedelijk
# 8          taak            benard      preventief          integraal
# 9  samenvoeging        rekenrente     onduidelijk  intergemeentelijk
#
#   opinion_44_CDA opinion_44_PvdA opinion_44_GroenLinks  opinion_44_SGP  \
# 0      regionaal       regionaal          gemeentelijk    gemeentelijk
# 1   gemeentelijk    gemeentelijk           provinciaal       regionaal
# 2    provinciaal     provinciaal             regionaal     provinciaal
# 3    inhoudelijk       landelijk                 groen     zelfstandig
# 4    zelfstandig    democratisch             landelijk         logisch
# 5   democratisch  grootstedelijk               logisch       landelijk
# 6    voorliggend     inhoudelijk           zelfstandig      toekomstig
# 7    gezamenlijk       stedelijk             stedelijk      vrijwillig
# 8     ruimtelijk        krachtig            toekomstig     voorliggend
# 9      landelijk     zelfstandig                  zwak  doorslaggevend
#
#   opinion_44_SP opinion_44_ChristenUnie opinion_44_PVV   opinion_44_RPF  \
# 0  gemeentelijk             provinciaal   gemeentelijk     gemeentelijk
# 1     regionaal               regionaal      regionaal          onjuist
# 2   provinciaal            gemeentelijk      landelijk         zakelijk
# 3         dicht                aanwezig    provinciaal  landschappelijk
# 4     landelijk              behoorlijk         jammer             gauw
# 5        intern            democratisch      efficiënt        ongunstig
# 6  democratisch                duurzaam     burgerlijk             half
# 7       voldoen       gemeenschappelijk      risicovol            kwijt
# 8   zelfstandig             voorliggend     toekomstig             waar
# 9      optimaal             betrouwbaar   voornamelijk      aanwijsbaar
#
#       opinion_44_LPF      opinion_44_GPV opinion_44_VVD opinion_44_OSF  \
# 0        provinciaal         provinciaal      regionaal   gemeentelijk
# 1          landelijk          ruimtelijk    provinciaal    provinciaal
# 2       gemeentelijk         zelfstandig   gemeentelijk      regionaal
# 3             divers         interactief      landelijk      blijkbaar
# 4          menselijk  binnengemeentelijk    voorliggend   democratisch
# 5          regionaal           landelijk    zelfstandig        voldoen
# 6         historisch         slagvaardig   democratisch  uitdrukkelijk
# 7        zelfstandig           effectief       krachtig        formeel
# 8          werkelijk             evident     decentraal      stedelijk
# 9  intergemeentelijk                 mis        logisch     ruimtelijk
#
#   opinion_44_Leefbaar Nederland
# 0                  gemeentelijk
# 1                  eigenstandig
# 2                         prima
# 3                     menselijk
# 4                bureaucratisch
# 5                     dagelijks
# 6                        schier
# 7                      hogelijk
# 8                   onaangenaam
# 9                       akkoord
#
# [10 rows x 17 columns]
#
# JSD: 0.66924303488
#                topic_73 opinion_73_50PLUS opinion_73_PvdD opinion_73_D66  \
# 0               verzoek            speels         plenair        plenair
# 1                agenda            benard         spoedig    inhoudelijk
# 2               bericht              koud       inclusief          prima
# 3            spoeddebat          identiek        aanwezig      aanstaand
# 4              stemming        volwaardig          vreemd        prettig
# 5              behoefte      ontvankelijk        hopelijk        spoedig
# 6                 reces   nederlandstalig  ongebruikelijk      mondeling
# 7               kwestie         egalitair       omstreden     zorgvuldig
# 8                 krant     onbestuurbaar        dringend       aanwezig
# 9  procedurevergadering        rekenrente       uiterlijk    procedureel
#
#   opinion_73_CDA opinion_73_PvdA opinion_73_GroenLinks  opinion_73_SGP  \
# 0        plenair         plenair               plenair         plenair
# 1     zorgvuldig         spoedig              aanwezig     inhoudelijk
# 2    inhoudelijk       aanstaand             aanstaand    demissionair
# 3      aanstaand     inhoudelijk           buitenlands  controversieel
# 4        spoedig            half             mondeling       aanstaand
# 5          prima       mondeling               spoedig      regelmatig
# 6    buitenlands           prima                  ruim           prima
# 7             na     buitenlands                    na         terzake
# 8      blijkbaar        aanwezig                 apart              na
# 9       aanwezig        dringend               onjuist     procedureel
#
#   opinion_73_SP opinion_73_ChristenUnie opinion_73_PVV opinion_73_RPF  \
# 0       plenair             inhoudelijk          prima          klaar
# 1     mondeling                 plenair      mondeling           waar
# 2     aanstaand                 normaal        plenair           druk
# 3       spoedig               uitvoerig        spoedig          licht
# 4         prima                aanwezig         jammer        extreem
# 5      aanwezig              zorgvuldig    jongstleden         ideëel
# 6   inhoudelijk                   prima      aanstaand      assertief
# 7    zorgvuldig                     gek      surinaams   eerstvolgend
# 8    uitbreiden                relevant    inhoudelijk    hemelsbreed
# 9     inclusief               aanstaand     schandalig      blijkbaar
#
#    opinion_73_LPF         opinion_73_GPV opinion_73_VVD   opinion_73_OSF  \
# 0          actief                normaal        plenair          plenair
# 1        aanwezig                logisch          prima    gelijkwaardig
# 2         plenair            inhoudelijk       aanwezig        opportuun
# 3          vreemd             zorgvuldig     zorgvuldig  opportunistisch
# 4          zinvol  eerstverantwoordelijk    jongstleden         redelijk
# 5   vertrouwelijk            diplomatiek    inhoudelijk         ongezond
# 6      luxemburgs              onderling        spoedig      ondoordacht
# 7  controversieel              diezelfde        normaal        voorlopig
# 8      marokkaans             palestijns      overbodig           oneens
# 9         akkoord            voorzichtig       relevant          akkoord
#
#   opinion_73_Leefbaar Nederland
# 0                           fel
# 1                          raak
# 2                   interessant
# 3                          klip
# 4                      leefbaar
# 5                          ruim
# 6                        gebekt
# 7                       stellig
# 8                   onbelemmerd
# 9                   afdwingbaar
#
# [10 rows x 17 columns]
