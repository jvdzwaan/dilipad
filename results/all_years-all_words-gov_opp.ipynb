# %% [markdown]
# # View CPT Results for experiment "all_years-all_words-gov_opp"

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (10, 7)

# %% [markdown]
# ## Topic word perplexity

# %%
import os

def load_perplexity_results(results_dir):
    perplexity_topic = pd.read_csv(os.path.join(results_dir, 'perplexity_topic.csv'), index_col=0)
    perplexity_opinion = pd.read_csv(os.path.join(results_dir, 'perplexity_opinion.csv'), index_col=0)
    
    return perplexity_topic, perplexity_opinion

# %%
results_dir = '/home/jvdzwaan/data/dilipad/results/all_years/all_years-all_words-gov_opp/'

# %%
perplexity_topic, perplexity_opinion = load_perplexity_results(results_dir)
perplexity_topic.plot();
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=medium. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
# change intervals if needed
intervals = ['60', '80', '100', '180', '200']

# %%
perplexity_topic[intervals].plot();

# %% [markdown]
# ## Opinion word perplexity

# %%
perplexity_opinion.plot();

# %%
perplexity_opinion[intervals].plot();

# %% [markdown]
# ## Results for topics and opinions

# %%
# choose optimal number of topics based on perplexity results
nTopics = 100

# %%
# load results
import glob
import os
import re

def load_experiment_results(nTopics, results_dir):

    # document topic matrix (theta)
    theta = pd.read_csv(os.path.join(results_dir, 'theta_{}.csv'.format(nTopics)), index_col=0)

    # phi topic (transposed)
    phi_topic_t = pd.read_csv(os.path.join(results_dir, 'topics_{}.csv'.format(nTopics)), index_col=0, encoding='utf-8')

    # phi opinion (transposed) per perspective
    opinion_files = glob.glob('{}/opinions_*_{}.csv'.format(results_dir, nTopics))
    phis_opinion_t = {}
    for f in opinion_files:
        m = re.match(r'.+opinions_(.+).csv', f)
        name = m.group(1).replace('_{}'.format(nTopics), '')
        phis_opinion_t[name] = pd.read_csv(f, index_col=0, encoding='utf-8')
    return theta, phi_topic_t, phis_opinion_t

# %%
theta, phi_topic_t, phis_opinion_t = load_experiment_results(nTopics, results_dir)

# %% [markdown]
# ### 'Weight' of the most important topic per document
#
# Each topic has a certain weight in the document. We would like to see one (or a few) topics with high weight per document. Below are some basic statistics on the most important topic (highest weight) per document.

# %%
def print_topic_weights(theta):
    a = theta.copy().apply(max, axis=1)
    a.sort(ascending=False)

    print 'Mean weight of most important topic: {} (std: {})'.format(a.mean(), a.std())
    print 'Min and max of most important topic: min: {}, max: {}'.format(a.min(), a.max())
    print 'Median weight of most important topic: ', a.median()

print_topic_weights(theta)
# Out:
# Mean weight of most important topic: 0.218398112106 (std: 0.128831999057)
# Min and max of most important topic: min: 0.01, max: 0.747070948145
# Median weight of most important topic:  0.201531641641

# %% [markdown]
# Line graph of the sorted topic weigths:

# %%
def plot_topic_weights(theta):
    theta.copy().apply(lambda row:sorted(row)[::-1], axis=1).transpose().plot(legend=None);

plot_topic_weights(theta)

# %% [markdown]
# ### Number of topics per document
#
# The number of topics per document is calculated by counting the number of topic with weight above a certain threshold. The numer of topics per document should (roughly) be equivalent to the number of ``pm:topic``s per document (however, at the moment we do not have statistics of this).

# %%
def display_number_of_topics_per_document(theta, threshold=0.05):
    topic_counts = theta.apply(lambda row: np.sum(row > threshold), axis=1)
    print topic_counts.value_counts(sort=False)
    topic_counts.hist(bins=len(topic_counts.value_counts()), figsize=(5,3));

display_number_of_topics_per_document(theta)
# Out:
# 0     973
# 8       8
# 1    2189
# 9       1
# 2    2959
# 3    2934
# 4    1934
# 5     927
# 6     333
# 7      42
# dtype: int64

# %% [markdown]
# ### Topics

# %%
def show_topic(t, top=10):
    """Return dataframe containing <top> topic words, weights of topic words and per perspective opinion words and
    weigths of opinion words.
    
    Parameters
        t : str - index of topic number
        top : int - the number of words to store in the dataframe
    
    Returns Pandas DataFrame
    """
    topic = phi_topic_t[t].copy()
    topic.sort(ascending=False)
    topic = topic[0:top]
    df_t = pd.DataFrame(topic)
    df_t.reset_index(level=0, inplace=True)
    df_t.columns = ['topic_{}'.format(t), 'weights_topic_{}'.format(t)]

    dfs = [df_t]

    for p, o in phis_opinion_t.iteritems():
        opinion = o[t].copy()
        opinion.sort(ascending=False)
        opinion = opinion[0:top]
        df_o = pd.DataFrame(opinion)
        df_o.reset_index(level=0, inplace=True)
        df_o.columns = ['opinion_{}_{}'.format(t, p), 'weights_opinion_{}_{}'.format(t, p)]
        dfs.append(df_o)
        
    return pd.concat(dfs, axis=1)

def print_topics(phi_topic_t, phis_opinion_t, nTopics):
    jsd = None
    jsdFile = os.path.join(results_dir, 'jsd_{}.csv'.format(nTopics))
    if os.path.isfile(jsdFile):
        print 'Ordering topics by Jensen-Shannon divergence of the opinions'
        print
        jsd = pd.read_csv(jsdFile, index_col=0)
        r = jsd.sort(['jsd'], ascending=False)
        print 'Min jsd: {}, max jsd: {}'.format(np.min(jsd['jsd']), np.max(jsd['jsd']))
        print 'Average jsd: {} (std: {}), median jsd: {}'.format(np.mean(jsd['jsd']), np.std(jsd['jsd']), np.median(jsd['jsd']))
        print
        loop = r.index
    else:
        print 'Ordering topics by topic number'
        print '(To order topics by Jensen-Shannon divergence of the opinions run the experiment_jsd_opinions script.)'
        print
        loop = range(nTopics)
    for i in loop:
        if not jsd is None:
            print 'JSD:', jsd.at[i, 'jsd']
        pLabels = ['opinion_{}_{}'.format(i, p) for p, o in phis_opinion_t.iteritems()]
        print show_topic(str(i))[['topic_{}'.format(i)] + pLabels]
        print

# %%
print_topics(phi_topic_t, phis_opinion_t, nTopics)
# Out:
# Ordering topics by Jensen-Shannon divergence of the opinions
#
# Min jsd: 0.0952746159028, max jsd: 0.335800754629
# Average jsd: 0.215982018593 (std: 0.0510651145786), median jsd: 0.212962748113
#
# JSD: 0.335800754629
#        topic_70 opinion_70_Opposition opinion_70_Government
# 0        sector            financieel            financieel
# 1         model          verschillend                  vast
# 2         fonds                leggen               bepaald
# 3       stelsel                  vast              proberen
# 4  uitgangspunt                helder                  kort
# 5      opdracht                danken             overigens
# 6     resultaat              ontstaan                 lopen
# 7      vermogen              proberen          uiteindelijk
# 8      uitkomst          plaatsvinden               uitgaan
# 9       inzicht         gelijkwaardig               precies
#
# [10 rows x 3 columns]
#
# JSD: 0.313233607031
#         topic_29 opinion_29_Opposition opinion_29_Government
# 0           stad           aanbesteden           aanbesteden
# 1   aanbesteding           verplichten                altijd
# 2      wethouder                   net                zorgen
# 3          keuze                lokaal               bepaald
# 4      kwaliteit                   oop                slecht
# 5     wetenschap              allemaal                eerder
# 6           lijn              besteden               sluiten
# 7    aanbesteden                 hopen                  soms
# 8  wetenschapper              openbaar               regelen
# 9           idee                slecht                straks
#
# [10 rows x 3 columns]
#
# JSD: 0.30876648217
#        topic_91 opinion_91_Opposition opinion_91_Government
# 0       gesprek               regelen                  blij
# 1    voorwaarde              allemaal                zorgen
# 2   voorziening                bieden               sluiten
# 3    toezegging               voldoen                 hopen
# 4      garantie               sluiten                bereid
# 5  problematiek              opzetten                bieden
# 6          kans                praten                  toen
# 7          plek                helpen             inderdaad
# 8    uitvoering                zoeken              allemaal
# 9       contact              oplossen                praten
#
# [10 rows x 3 columns]
#
# JSD: 0.301818223544
#         topic_30 opinion_30_Opposition opinion_30_Government
# 0        energie              duurzaam              duurzaam
# 1      industrie                 groen                 halen
# 2  bedrijfsleven                 halen                 extra
# 3   doelstelling             gebruiken                 klein
# 4    investering            produceren               voldoen
# 5          afval                 klein            investeren
# 6      productie                zetten        internationaal
# 7         wereld            stimuleren            financieel
# 8        product              inzetten                zetten
# 9   ontwikkeling                 lopen                altijd
#
# [10 rows x 3 columns]
#
# JSD: 0.301743376598
#         topic_71 opinion_71_Opposition opinion_71_Government
# 0           stap                danken              allemaal
# 1           idee                helder                zetten
# 2          optie                 breed          uiteindelijk
# 3  beantwoording              proberen                danken
# 4            weg               precies                straks
# 5         betoog                 hopen              beginnen
# 6           lijn                  blij                  snel
# 7      suggestie                ingaan                   erg
# 8      werkgroep                 bezig              bekijken
# 9       richting              allerlei                zoeken
#
# [10 rows x 3 columns]
#
# JSD: 0.2939740168
#        topic_75 opinion_75_Opposition opinion_75_Government
# 0         lijst              illegaal              illegaal
# 1      internet              allemaal                spelen
# 2       website             voorkomen                straks
# 3    vereniging             aanbieden                 vorig
# 4   gedragscode              allerlei                gokken
# 5          site               wanneer                bieden
# 6      register             verbieden             verbieden
# 7  voorlichting                gokken             dergelijk
# 8      computer                zetten             aanbieden
# 9        aanbod                actief                zetten
#
# [10 rows x 3 columns]
#
# JSD: 0.29298159552
#               topic_78 opinion_78_Opposition opinion_78_Government
# 0           vergunning              verlenen               regelen
# 1                  eis               regelen              verlenen
# 2                regel                vallen                vallen
# 3           toepassing                altijd                leiden
# 4  vergunningverlening            historisch              indienen
# 5                tracé             intrekken             aanvragen
# 6             aanvraag                   erg             voorkomen
# 7                 last             aanvragen               voldoen
# 8                  lex               steunen               opnemen
# 9             argument               voldoen             handhaven
#
# [10 rows x 3 columns]
#
# JSD: 0.290402685845
#            topic_5 opinion_5_Opposition opinion_5_Government
# 0        kwaliteit              leveren                extra
# 1       instelling                extra              voldoen
# 2        personeel             allemaal              leveren
# 3     marktwerking               leiden               zorgen
# 4   zorginstelling                  oud     verantwoordelijk
# 5           sector             besteden               slecht
# 6     verpleeghuis              voldoen                klein
# 7  gezondheidszorg                  erg             inzetten
# 8          systeem                 snel             daarvoor
# 9     bureaucratie               altijd              terecht
#
# [10 rows x 3 columns]
#
# JSD: 0.281311455092
#         topic_67 opinion_67_Opposition opinion_67_Government
# 0      evaluatie             evalueren             evalueren
# 1     experiment                lokaal              positief
# 2     instrument          gemeentelijk                danken
# 3         effect              positief             betrekken
# 4  beantwoording            financieel                lokaal
# 5          pilot          plaatsvinden          plaatsvinden
# 6       ervaring                  stem          gemeentelijk
# 7           last                danken              wellicht
# 8         niveau                leiden                leiden
# 9     vertrouwen                 voren             toezeggen
#
# [10 rows x 3 columns]
#
# JSD: 0.278346079471
#          topic_56 opinion_56_Opposition opinion_56_Government
# 0    doelstelling              concreet              concreet
# 1      vertrouwen              politiek              bereiken
# 2  verantwoording            formuleren              politiek
# 3        politiek                vooral                waarop
# 4           regel               aflopen               publiek
# 5       resultaat              bereiken                 terug
# 6     departement                  vaak               vandaag
# 7          aanpak               publiek                zetten
# 8         ambitie                altijd                  mooi
# 9         kritiek                 terug                 zelfs
#
# [10 rows x 3 columns]
#
# JSD: 0.277862327335
#               topic_33 opinion_33_Opposition opinion_33_Government
# 0               schuld               betalen               betalen
# 1               premie            verzekeren            verzekeren
# 2           buitenland             voorkomen             voorkomen
# 3                maand           onverzekerd           onverzekerd
# 4             rekening                  vaak            financieel
# 5          zorgtoeslag                helpen                ervoor
# 6           wanbetaler                   net               sociaal
# 7  schuldhulpverlening               sociaal                leggen
# 8  zorgverzekeringswet               stijgen                immers
# 9         solidariteit             afsluiten             wettelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.277624838998
#             topic_35 opinion_35_Opposition opinion_35_Government
# 0          criterium           terugwerken              indienen
# 1             kracht               voldoen           terugwerken
# 2           paspoort             juridisch             inderdaad
# 3             schade              indienen                  snel
# 4      duidelijkheid              allemaal               voldoen
# 5               hout               vandaag              allemaal
# 6  wetgevingsoverleg             inderdaad              daarvoor
# 7         voorwaarde                eerder                 raken
# 8           protocol                leggen              ontstaan
# 9           noodzaak                helder           vaststellen
#
# [10 rows x 3 columns]
#
# JSD: 0.276484914676
#            topic_40 opinion_40_Opposition opinion_40_Government
# 0            bedrag               betalen              allemaal
# 1            cijfer                kosten          uiteindelijk
# 2        sp-fractie              allemaal               betalen
# 3       pvv-fractie                   net                   net
# 4        vergoeding               kloppen                 terug
# 5  belastingbetaler               snappen                 lezen
# 6           verhaal                 nooit             inderdaad
# 7          rekening               precies                kosten
# 8              paar            financieel               kloppen
# 9              deal                 bijna                slecht
#
# [10 rows x 3 columns]
#
# JSD: 0.2759633461
#            topic_64 opinion_64_Opposition opinion_64_Government
# 0       alternatief               steunen              indienen
# 1        initiatief              indienen               steunen
# 2  burgerinitiatief             uitvoeren                  kort
# 3         dierproef          ondersteunen                altijd
# 4      handtekening                   net                zetten
# 5           besluit              aannemen                 breed
# 6             jacht                 hopen                 lezen
# 7              stap               pleiten             uitvoeren
# 8             zwijn                zoeken               serieus
# 9         standpunt                zetten                helpen
#
# [10 rows x 3 columns]
#
# JSD: 0.273385405194
#        topic_97 opinion_97_Opposition opinion_97_Government
# 0          boek                  vast                  vast
# 1         prijs                gratis      wetenschappelijk
# 2    schoolboek      wetenschappelijk                gratis
# 3   boekenprijs             juridisch                 kopen
# 4        aanbod                 breed                 klein
# 5       methode                  vrij                 lezen
# 6  ontwikkeling                 lezen             schrijven
# 7         markt                 klein                vallen
# 8      uitgever              goedkoop                  vrij
# 9       systeem                altijd              allerlei
#
# [10 rows x 3 columns]
#
# JSD: 0.27147585571
#         topic_27 opinion_27_Opposition opinion_27_Government
# 0    aanbeveling              openbaar                altijd
# 1        functie                altijd              openbaar
# 2   openbaarheid          ministerieel            koninklijk
# 3         koning              politiek          ministerieel
# 4      parlement                spelen               regelen
# 5      kandidaat                huidig             bijzonder
# 6  transparantie                kiezen              politiek
# 7           huis               bepaald                waarop
# 8        persoon          parlementair              beperken
# 9      procedure              benoemen             overigens
#
# [10 rows x 3 columns]
#
# JSD: 0.270744853055
#        topic_8 opinion_8_Opposition opinion_8_Government
# 0  organisatie            wettelijk            wettelijk
# 1     controle            uitvoeren               vallen
# 2         taak              publiek          controleren
# 3   uitvoering          controleren     verantwoordelijk
# 4   accountant        onafhankelijk              publiek
# 5  regelgeving              regelen           financieel
# 6   rapportage               extern               extern
# 7        regel            dergelijk         ministerieel
# 8     opdracht      maatschappelijk              waarbij
# 9      inzicht           financieel            uitvoeren
#
# [10 rows x 3 columns]
#
# JSD: 0.269465796964
#           topic_66 opinion_66_Opposition opinion_66_Government
# 0           klacht             nationaal             nationaal
# 1  belastingdienst                  vaak        administratief
# 2        ombudsman                melden              indienen
# 3           dienst              oplossen            behandelen
# 4  dienstverlening                 extra             voorkomen
# 5  kinderombudsman              indienen                immers
# 6        instantie                  snel                   net
# 7           nummer               regelen            informeren
# 8            loket               sluiten                sturen
# 9      organisatie                zorgen                 extra
#
# [10 rows x 3 columns]
#
# JSD: 0.269060775563
#             topic_52 opinion_52_Opposition opinion_52_Government
# 0             advies         onafhankelijk             adviseren
# 1              state             adviseren         onafhankelijk
# 2         advisering               regelen             betrekken
# 3           afdeling              politiek                eerder
# 4  onafhankelijkheid            uitbrengen              benoemen
# 5            functie             juridisch            uitbrengen
# 6               taak             betrekken                 breed
# 7           adviseur              benoemen                huidig
# 8            kritiek             deskundig              politiek
# 9             kennis              dezelfde                immers
#
# [10 rows x 3 columns]
#
# JSD: 0.265633401063
#           topic_34 opinion_34_Opposition opinion_34_Government
# 0      verzekeraar            verzekeren            verzekeren
# 1          stelsel             aanvullen               regelen
# 2      verzekering               regelen                huidig
# 3           premie                huidig                immers
# 4         contract                immers           particulier
# 5  zorgverzekeraar               privaat          noodzakelijk
# 6       toezegging                leiden             toezeggen
# 7         knelpunt               sluiten            collectief
# 8      ziekenfonds              ontstaan              nominaal
# 9            polis           particulier           zelfstandig
#
# [10 rows x 3 columns]
#
# JSD: 0.264659745719
#          topic_99 opinion_99_Opposition opinion_99_Government
# 0           water               regelen              ontstaan
# 1      waterschap             voorkomen                leiden
# 2           schip                  kort                huidig
# 3           haven                immers                direct
# 4      uitvoering                  snel               voldoen
# 5          aanpak                 klein                  kort
# 6      veiligheid                zorgen             integraal
# 7    financiering                leggen                eerder
# 8            dijk                vallen          verschillend
# 9  kaderrichtlijn                   erg              hierover
#
# [10 rows x 3 columns]
#
# JSD: 0.263767543183
#               topic_57 opinion_57_Opposition opinion_57_Government
# 0                boete           bestuurlijk           bestuurlijk
# 1           handhaving              opleggen              opleggen
# 2              sanctie             handhaven             handhaven
# 3          overtreding       strafrechtelijk       strafrechtelijk
# 4               fraude    bestuursrechtelijk                 klein
# 5                regel                leggen                altijd
# 6             controle             effectief             aanpakken
# 7           strafrecht                 zwaar                leiden
# 8  identificatieplicht             aanpakken    bestuursrechtelijk
# 9           instrument              optreden                 zwaar
#
# [10 rows x 3 columns]
#
# JSD: 0.262955577476
#        topic_94 opinion_94_Opposition opinion_94_Government
# 0  ontwikkeling              politiek                vooral
# 1       notitie                vooral       maatschappelijk
# 2         visie                  vaak              politiek
# 3  samenwerking               richten            versterken
# 4          taak             overigens                  soms
# 5    initiatief                 sterk                 breed
# 6      politiek       maatschappelijk           ontwikkelen
# 7     structuur            versterken               richten
# 8        niveau                vormen             betrekken
# 9       terrein              centraal          verschillend
#
# [10 rows x 3 columns]
#
# JSD: 0.259380311033
#        topic_12 opinion_12_Opposition opinion_12_Government
# 0      misbruik              seksueel              illegaal
# 1   slachtoffer              illegaal              seksueel
# 2  mensenhandel              indienen             betrekken
# 3   prostitutie             voorkomen             strafbaar
# 4        aanpak                  vaak                legaal
# 5   bestrijding           registreren                pakken
# 6   registratie             aanpakken              hierover
# 7    prostituee             strafbaar                   erg
# 8     opsporing             landelijk            bestrijden
# 9        meisje            bestrijden                zorgen
#
# [10 rows x 3 columns]
#
# JSD: 0.256079776638
#       topic_21 opinion_21_Opposition opinion_21_Government
# 0       risico               betalen               betalen
# 1      systeem                  ziek                vallen
# 2     bijdrage              invoeren                kiezen
# 3       effect                leiden                  ziek
# 4    invoering             chronisch               bepaald
# 5        keuze            financieel                immers
# 6      prikkel              verhogen            financieel
# 7        claim                 halen             betekenen
# 8     rekening              allemaal             chronisch
# 9  compensatie            verwachten                  laag
#
# [10 rows x 3 columns]
#
# JSD: 0.255532235532
#         topic_68 opinion_68_Opposition opinion_68_Government
# 0       vrijheid       maatschappelijk       maatschappelijk
# 1           norm                  vrij                gelijk
# 2          waard              politiek                  vrij
# 3    samenleving                gelijk           individueel
# 4     grondrecht          fundamenteel             bijzonder
# 5      opvatting               publiek                passen
# 6       grondwet              openbaar              openbaar
# 7  meningsuiting             bijzonder               bepalen
# 8          staat           individueel               bepaald
# 9          grens        internationaal          democratisch
#
# [10 rows x 3 columns]
#
# JSD: 0.254541100279
#        topic_88 opinion_88_Opposition opinion_88_Government
# 0     convenant              politiek              politiek
# 1      subsidie               regelen              indienen
# 2     stichting              indienen               sluiten
# 3   organisatie                 extra       maatschappelijk
# 4  financiering            financieel               regelen
# 5    sponsoring              daarvoor          ondersteunen
# 6    activiteit             wettelijk            financieel
# 7         regel       maatschappelijk             overigens
# 8     verhoging             betrekken                gelijk
# 9    vereniging               steunen                eerder
#
# [10 rows x 3 columns]
#
# JSD: 0.253588240415
#          topic_96 opinion_96_Opposition opinion_96_Government
# 0        toezicht         onafhankelijk         onafhankelijk
# 1       inspectie                gelijk            financieel
# 2         college             wettelijk              allemaal
# 3            taak           controleren               richten
# 4      instelling          functioneren                waarop
# 5  toezichthouder           individueel             ingrijpen
# 6       kwaliteit                daarop          functioneren
# 7     bevoegdheid               regelen               voldoen
# 8       instituut               voldoen               trekken
# 9      vertrouwen                 hopen      verantwoordelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.252740845371
#       topic_17 opinion_17_Opposition opinion_17_Government
# 0   veiligheid               ernstig                veilig
# 1     incident              openbaar             voorkomen
# 2       risico                beuren                  snel
# 3     controle           onderzoeken                 extra
# 4   vertrouwen                veilig                beuren
# 5         fout          plaatsvinden                altijd
# 6        beeld           controleren           onderzoeken
# 7       dienst      verantwoordelijk                 lopen
# 8      persoon            informeren               trekken
# 9  beveiliging             betrekken            informeren
#
# [10 rows x 3 columns]
#
# JSD: 0.252605254004
#             topic_15 opinion_15_Opposition opinion_15_Government
# 0            besluit           bestuurlijk               regelen
# 1          procedure              indienen              indienen
# 2             beroep             besluiten             besluiten
# 3            bezwaar                leiden           bestuurlijk
# 4     bestuursorgaan                immers                passen
# 5         beslissing             voorkomen                  snel
# 6      bestuursrecht                  snel         belanghebbend
# 7  rechtsbescherming                eerder                geheel
# 8        bevoegdheid             juridisch           zelfstandig
# 9        beschikking                bieden               bepaald
#
# [10 rows x 3 columns]
#
# JSD: 0.249318000054
#         topic_14 opinion_14_Opposition opinion_14_Government
# 0          maand               wachten                  snel
# 1        signaal               aflopen               wachten
# 2  duidelijkheid                 vorig               aflopen
# 3        bericht                  toen                   pas
# 4          krant                  snel                 lezen
# 5          media                sturen                  toen
# 6          tafel                bekend                  kort
# 7          actie                beuren                beuren
# 8          beeld                helder               kloppen
# 9         indruk                   pas               vandaag
#
# [10 rows x 3 columns]
#
# JSD: 0.247511941756
#        topic_51 opinion_51_Opposition opinion_51_Government
# 0    bewindsman                vooral                vooral
# 1   samenleving              toenemen             overigens
# 2  ontwikkeling       maatschappelijk              politiek
# 3          maat             overigens       maatschappelijk
# 4    benadering                wijzen                  vaak
# 5   beschouwing                 menen                 sterk
# 6         beeld              geworden                wijzen
# 7       terrein            realiseren                 breed
# 8        effect              wellicht             uiteraard
# 9   perspectief               bepaald               sociaal
#
# [10 rows x 3 columns]
#
# JSD: 0.24586330857
#            topic_2 opinion_2_Opposition opinion_2_Government
# 0           sector               eerder              trekken
# 1  volksgezondheid           economisch            verzoeken
# 2           verbod            verbieden               leggen
# 3          product            genetisch             absoluut
# 4       ondernemer      maatschappelijk            specifiek
# 5             kooi               zetten              terecht
# 6            schap                  net               zetten
# 7            vlees              ethisch                klein
# 8              kip            verrijken                  net
# 9        consument                klein         parlementair
#
# [10 rows x 3 columns]
#
# JSD: 0.244997800488
#      topic_28 opinion_28_Opposition opinion_28_Government
# 0       vrouw               regelen               opnemen
# 1         man                zorgen               regelen
# 2      verlof               opnemen                zorgen
# 3      arbeid               betalen               betalen
# 4     periode                 klein             wettelijk
# 5       vader              indienen              indienen
# 6      ziekte                  vaak                  ziek
# 7  zorgverlof             wettelijk            combineren
# 8  vervanging               dwingen                kiezen
# 9      moeder             langdurig             betrekken
#
# [10 rows x 3 columns]
#
# JSD: 0.242845850283
#             topic_80 opinion_80_Opposition opinion_80_Government
# 0            premier            koninklijk              allemaal
# 1          interview              politiek                waarop
# 2           koningin              gisteren            koninklijk
# 3               huis              allemaal              politiek
# 4            kwestie               vandaag               aflopen
# 5  fractievoorzitter               aflopen             inderdaad
# 6             inhoud            vervolgens             schrijven
# 7     kabinetsbeleid                 raken                 lezen
# 8       ministerraad      verantwoordelijk              gisteren
# 9              staat                vallen               precies
#
# [10 rows x 3 columns]
#
# JSD: 0.239750831341
#                  topic_46 opinion_46_Opposition opinion_46_Government
# 0                indiener               regelen                altijd
# 1         initiatiefnemer              aannemen              aannemen
# 2  initiatiefwetsvoorstel             bijzonder               regelen
# 3              initiatief                altijd              indienen
# 4      initiatiefvoorstel             overigens                kiezen
# 5                 bezwaar               steunen                immers
# 6              waardering                vallen             bijzonder
# 7                argument                  vaak              wijzigen
# 8              compliment          uiteindelijk                huidig
# 9                 inbreng              indienen             overigens
#
# [10 rows x 3 columns]
#
# JSD: 0.238999670961
#        topic_76 opinion_76_Opposition opinion_76_Government
# 0       cultuur             cultureel             cultureel
# 1        schade              ontstaan                vallen
# 2         kunst         archeologisch                bieden
# 3        museum                vallen              absoluut
# 4  geschiedenis                bekend                altijd
# 5    kunstenaar            collectief                wijzen
# 6   slachtoffer             nationaal               vandaag
# 7     verjaring                  mooi               waarbij
# 8        gebouw            historisch            historisch
# 9        asbest                wijzen         aansprakelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.237876432615
#           topic_55 opinion_55_Opposition opinion_55_Government
# 0             baan               sociaal               sociaal
# 1     arbeidsmarkt                  jong                  jong
# 2             kans                zorgen                zorgen
# 3      minimumloon                 sterk                helpen
# 4     werkloosheid                helpen                ervoor
# 5  werkgelegenheid              concreet                bieden
# 6     ontslagrecht                   net          uiteindelijk
# 7               er                ervoor                   net
# 8      samenleving              allemaal              regulier
# 9       hervorming                  hard             tijdelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.234887355471
#         topic_10 opinion_10_Opposition opinion_10_Government
# 0      richtlijn             nationaal             nationaal
# 1      wetgeving               regelen         implementeren
# 2    regelgeving         implementeren                vallen
# 3  implementatie                  laag               bepalen
# 4          regel             gebruiken             voorkomen
# 5       lidstaat             aanpassen              beperken
# 6           stof                vallen               vandaag
# 7    verordening            vervolgens             dergelijk
# 8            kop              afwijken              ontstaan
# 9        werking               bepalen             juridisch
#
# [10 rows x 3 columns]
#
# JSD: 0.233834718661
#         topic_83 opinion_83_Opposition opinion_83_Government
# 0           nota               regelen               regelen
# 1      wijziging              indienen              indienen
# 2        verslag              wijzigen               opnemen
# 3  wetswijziging               opnemen              wijzigen
# 4    toelichting           voorliggend                huidig
# 5    verbetering          schriftelijk           voorliggend
# 6     aanpassing                 nader                 nader
# 7      wetgeving                huidig          schriftelijk
# 8      bedoeling                beogen             technisch
# 9      beperking        oorspronkelijk               bepalen
#
# [10 rows x 3 columns]
#
# JSD: 0.232870561719
#              topic_13 opinion_13_Opposition opinion_13_Government
# 0              milieu                schoon              duurzaam
# 1                norm                 halen             nationaal
# 2            uitstoot                 extra                schoon
# 3          luchthaven                leiden               richten
# 4              opslag             verzoeken                 halen
# 5            reductie                bouwen              daarvoor
# 6             klimaat              duurzaam            realiseren
# 7      luchtkwaliteit                zetten                leiden
# 8        doelstelling            economisch                huidig
# 9  klimaatverandering               vliegen              concreet
#
# [10 rows x 3 columns]
#
# JSD: 0.230999438166
#       topic_81 opinion_81_Opposition opinion_81_Government
# 0    consument               regelen                  snel
# 1     internet                zorgen                bieden
# 2       dienst                  snel                leiden
# 3        markt                   net              digitaal
# 4    aanbieder                  vrij                  kort
# 5      netwerk              indienen                 kopen
# 6        kabel                ervoor                  vaak
# 7        klant                bieden          ondersteunen
# 8  bescherming               vandaag               betalen
# 9      toegang               waarbij                bellen
#
# [10 rows x 3 columns]
#
# JSD: 0.228927761949
#                 topic_74 opinion_74_Opposition opinion_74_Government
# 0            bezuiniging            bezuinigen                 extra
# 1              begroting                 extra            financieel
# 2                 budget            financieel            bezuinigen
# 3                 bedrag                 vorig                 vorig
# 4                dekking            investeren           beschikbaar
# 5                  keuze              indienen              indienen
# 6  begrotingsbehandeling                 halen            realiseren
# 7             ministerie               betalen            investeren
# 8            investering                bereid               aflopen
# 9               bijdrage                zorgen                   net
#
# [10 rows x 3 columns]
#
# JSD: 0.226431661934
#          topic_86 opinion_86_Opposition opinion_86_Government
# 0           markt               publiek               publiek
# 1    marktwerking                 klein               privaat
# 2    concurrentie                 sterk            economisch
# 3           prijs                gelijk               regelen
# 4  liberalisering            economisch                   net
# 5   privatisering                altijd                  laag
# 6       consument                  vrij                gelijk
# 7     onderneming           concurreren                 klein
# 8       speelveld                 zelfs                immers
# 9      ondernemer          privatiseren              ontstaan
#
# [10 rows x 3 columns]
#
# JSD: 0.225845508865
#             topic_50 opinion_50_Opposition opinion_50_Government
# 0              kaart              openbaar              openbaar
# 1             handel             strafbaar             effectief
# 2              wapen                 zwart                kraken
# 3  strafbaarstelling           bestuurlijk             strafbaar
# 4               pand            preventief             gebruiken
# 5               goed                kraken          grootschalig
# 6         handhaving                wijzen       strafrechtelijk
# 7         strafrecht       strafrechtelijk             aanpakken
# 8         instrument                ingaan              optreden
# 9          wetgeving              optreden              aannemen
#
# [10 rows x 3 columns]
#
# JSD: 0.225465444701
#       topic_69 opinion_69_Opposition opinion_69_Government
# 0      rechter           rechterlijk           rechterlijk
# 1  rechtspraak               toetsen               toetsen
# 2        macht             juridisch                  kort
# 3       beroep             voorkomen                civiel
# 4     advocaat                leiden             juridisch
# 5     toetsing            burgerlijk            burgerlijk
# 6    procedure            behandelen          gerechtelijk
# 7    rechtbank                  vaak             betekenen
# 8          hof                  snel               waarbij
# 9    instantie             betekenen                  snel
#
# [10 rows x 3 columns]
#
# JSD: 0.22415278356
#          topic_87 opinion_87_Opposition opinion_87_Government
# 0         project                  snel                  snel
# 1       procedure             betrekken             betekenen
# 2         besluit              allemaal              indienen
# 3  besluitvorming                 lopen                eerder
# 4      vertraging                eerder                daarin
# 5          crisis                  vaak                passen
# 6     alternatief                   erg               trekken
# 7         variant                vooral            zorgvuldig
# 8      herstelwet             dergelijk                leiden
# 9          proces                altijd            realiseren
#
# [10 rows x 3 columns]
#
# JSD: 0.215476345913
#         topic_25 opinion_25_Opposition opinion_25_Government
# 0     ondernemer            economisch            economisch
# 1  bedrijfsleven        administratief        administratief
# 2      innovatie                 klein            ondernemen
# 3           last            ondernemen                  vaak
# 4       economie                vooral            stimuleren
# 5     ministerie       maatschappelijk       maatschappelijk
# 6         kennis                zorgen                 klein
# 7          regel                  vaak                vooral
# 8            mkb            investeren                zorgen
# 9             ez                 vorig        internationaal
#
# [10 rows x 3 columns]
#
# JSD: 0.213445728605
#                topic_39 opinion_39_Opposition opinion_39_Government
# 0               bestuur               regelen              openbaar
# 1                 fusie                 klein               regelen
# 2       medezeggenschap             betrekken             bijzonder
# 3         schoolbestuur               primair                 klein
# 4  medezeggenschapsraad             wettelijk             wettelijk
# 5             personeel            financieel                leiden
# 6  samenwerkingsverband             betekenen            financieel
# 7                 gezag              indienen               primair
# 8             invoering           bestuurlijk             betrekken
# 9           bekostiging              ontstaan                waarop
#
# [10 rows x 3 columns]
#
# JSD: 0.213134757005
#         topic_58 opinion_58_Opposition opinion_58_Government
# 0           dier              slachten              slachten
# 1  dierenwelzijn                lijden                lijden
# 2         verbod      wetenschappelijk               ritueel
# 3         slacht               ritueel      wetenschappelijk
# 4          vlees             verbieden             voorkomen
# 5        ritueel               vandaag             verbieden
# 6        welzijn                 leven               steunen
# 7     dierenleed                 extra              indienen
# 8      handeling            verbeteren             religieus
# 9           hond             religieus              allemaal
#
# [10 rows x 3 columns]
#
# JSD: 0.212790739221
#        topic_16 opinion_16_Opposition opinion_16_Government
# 0        natuur            ecologisch           significant
# 1     provincie            beschermen             kwetsbaar
# 2  natuurgebied             kwetsbaar            ecologisch
# 3        milieu                 halen             agrarisch
# 4   veehouderij            realiseren          ondersteunen
# 5         grond             agrarisch             betrekken
# 6    activiteit                leiden                 halen
# 7        effect             betekenen                 extra
# 8    beheerplan                leggen            economisch
# 9        beheer                 zelfs          plaatsvinden
#
# [10 rows x 3 columns]
#
# JSD: 0.210635901563
#      topic_90 opinion_90_Opposition opinion_90_Government
# 0   jeugdzorg                  jong                  jong
# 1  wachtlijst               wachten               jeugdig
# 2      bureau                 extra                 extra
# 3       gezin                  snel                bieden
# 4       jeugd              oplossen              plaatsen
# 5        hulp                eerder                eerder
# 6     centrum               jeugdig                zetten
# 7  pleegouder                zorgen               sluiten
# 8   wachttijd             wegwerken                helpen
# 9   provincie               sluiten                  snel
#
# [10 rows x 3 columns]
#
# JSD: 0.207839723573
#          topic_61 opinion_61_Opposition opinion_61_Government
# 0            boer             agrarisch             agrarisch
# 1        landbouw            biologisch            biologisch
# 2          sector              duurzaam              duurzaam
# 3      platteland                zetten                vooral
# 4           markt              inzetten              inzetten
# 5  landbouwbeleid              indienen                  blij
# 6         product                bereid              wellicht
# 7       consument            produceren               aflopen
# 8      ministerie                 klein                  kort
# 9            mest             intensief                zetten
#
# [10 rows x 3 columns]
#
# JSD: 0.205647220045
#           topic_37 opinion_37_Opposition opinion_37_Government
# 0          gegeven          elektronisch             gebruiken
# 1          privacy           verstrekken             landelijk
# 2          dossier             landelijk             betrekken
# 3          systeem             gebruiken          elektronisch
# 4  persoonsgegeven             betrekken               bewaren
# 5      bescherming               regelen               regelen
# 6    nationaliteit           verplichten               precies
# 7      toestemming           persoonlijk          plaatsvinden
# 8               ep             betekenen               voldoen
# 9          toegang          verschillend                vallen
#
# [10 rows x 3 columns]
#
# JSD: 0.20490087006
#        topic_36 opinion_36_Opposition opinion_36_Government
# 0       vervoer              openbaar              openbaar
# 1         spoor                rijden                rijden
# 2         trein             verzoeken              indienen
# 3      reiziger          ondersteunen                 extra
# 4     concessie              indienen                zorgen
# 5    vervoerder      verantwoordelijk                altijd
# 6     onderhoud                huidig                 halen
# 7  ov-chipkaart                reizen                eerder
# 8       station             gebruiken             gebruiken
# 9         kaart             betekenen                ervoor
#
# [10 rows x 3 columns]
#
# JSD: 0.204771121704
#               topic_63 opinion_63_Opposition opinion_63_Government
# 0                ouder                  jong                  jong
# 1         kinderopvang               regelen       maatschappelijk
# 2               opvang       maatschappelijk           verplichten
# 3                stage                zorgen               voldoen
# 4                  uur                ervoor               regelen
# 5        kinderbijslag           verplichten                   oud
# 6  leerplichtambtenaar                  vaak                altijd
# 7            gastouder               betalen                 halen
# 8                  ure                altijd                leggen
# 9            kwaliteit                 thuis           particulier
#
# [10 rows x 3 columns]
#
# JSD: 0.203570228928
#            topic_89 opinion_89_Opposition opinion_89_Government
# 0         provincie            ruimtelijk            ruimtelijk
# 1             regio             regionaal             regionaal
# 2          ordening                lokaal           provinciaal
# 3              stad           bestuurlijk           bestuurlijk
# 4   bestemmingsplan             landelijk             landelijk
# 5      ontwikkeling                spelen          verschillend
# 6              nota           provinciaal            realiseren
# 7  bedrijventerrein                bieden                bouwen
# 8             grond             betrekken                helder
# 9        instrument             betekenen             stedelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.203447347987
#          topic_95 opinion_95_Opposition opinion_95_Government
# 0         energie              duurzaam              duurzaam
# 1  energiebedrijf                 groen                   net
# 2          stroom            economisch                 groen
# 3           meter               publiek               betalen
# 4             gas                  slim                  slim
# 5       consument               betalen                leiden
# 6       splitsing                  laag            economisch
# 7    netbeheerder               regelen             overigens
# 8             net           buitenlands              allemaal
# 9   elektriciteit                immers               regelen
#
# [10 rows x 3 columns]
#
# JSD: 0.202670411905
#        topic_9 opinion_9_Opposition opinion_9_Government
# 0      memorie                nader         schriftelijk
# 1  toelichting         schriftelijk                nader
# 2       begrip          voorliggend               immers
# 3        grond              bepalen              opnemen
# 4     bepaling               vallen                reeds
# 5    wetgeving               beogen               vallen
# 6   toepassing              opnemen          voorliggend
# 7     wetgever            bijzonder               beogen
# 8  onderscheid            overigens            dergelijk
# 9      werking             redelijk            wettelijk
#
# [10 rows x 3 columns]
#
# JSD: 0.202575824583
#         topic_41 opinion_41_Opposition opinion_41_Government
# 0    samenleving                dubbel                 leren
# 1     integratie                 leren            allochtoon
# 2           taal            marokkaans           islamitisch
# 3  nationaliteit                 sterk                  jong
# 4    inburgering            allochtoon                  vaak
# 5     minderheid               sociaal             cultureel
# 6        cultuur                  jong            marokkaans
# 7    allochtonen                kennen              beginnen
# 8           wijk           islamitisch                 lezen
# 9          islam                 wonen                   net
#
# [10 rows x 3 columns]
#
# JSD: 0.200320059178
#          topic_82 opinion_82_Opposition opinion_82_Government
# 0         inkomen                  laag                  laag
# 1           gezin             chronisch               betalen
# 2          bedrag                  ziek   inkomensafhankelijk
# 3       verhoging   inkomensafhankelijk                   oud
# 4      huishouden                   oud             chronisch
# 5         toeslag             bijzonder                 klein
# 6          effect               sociaal                  ziek
# 7  tegemoetkoming           gehandicapt             betekenen
# 8      koopkracht               betalen                 extra
# 9            last             achteruit               fiscaal
#
# [10 rows x 3 columns]
#
# JSD: 0.19581641116
#         topic_24 opinion_24_Opposition opinion_24_Government
# 0              d               vandaag                praten
# 1  regeerakkoord               aflopen              allemaal
# 2       coalitie              politiek                   net
# 3       mijnheer               steunen                  toen
# 4        akkoord              allemaal                 nooit
# 5    meerderheid                   net              proberen
# 6     vertrouwen                  toen              politiek
# 7          tafel               eerlijk               aflopen
# 8       politiek                 vorig               steunen
# 9      oppositie                praten                helder
#
# [10 rows x 3 columns]
#
# JSD: 0.193752852147
#         topic_85 opinion_85_Opposition opinion_85_Government
# 0           drug                  jong             aanpakken
# 1       overlast             aanpakken                  jong
# 2  criminaliteit              illegaal                pakken
# 3         aanpak             verbieden        internationaal
# 4     coffeeshop             gebruiken             gebruiken
# 5      crimineel           organiseren             crimineel
# 6     achterdeur             crimineel              illegaal
# 7       softdrug        internationaal           organiseren
# 8       Justitie             reguleren              allemaal
# 9          lijst               sluiten                zorgen
#
# [10 rows x 3 columns]
#
# JSD: 0.192081535102
#            topic_49 opinion_49_Opposition opinion_49_Government
# 0           politie                lokaal             landelijk
# 1        veiligheid             landelijk                  vaak
# 2             agent             regionaal              concreet
# 3              ramp             nationaal                  snel
# 4      burgemeester                zorgen                zorgen
# 5            straat           bestuurlijk             nationaal
# 6  veiligheidsregio                  snel             specifiek
# 7              taak              ontstaan                lokaal
# 8         brandweer      verantwoordelijk             regionaal
# 9             korps                leiden                waarop
#
# [10 rows x 3 columns]
#
# JSD: 0.190510402519
#        topic_65 opinion_65_Opposition opinion_65_Government
# 0     werkgever               sociaal               sociaal
# 1     werknemer                   oud                   oud
# 2     uitkering     arbeidsongeschikt     arbeidsongeschikt
# 3  reïntegratie          gedeeltelijk                  ziek
# 4       partner                leiden                passen
# 5            er                  ziek                leiden
# 6      instroom              volledig              volledig
# 7    uitvoering                immers             betekenen
# 8     zekerheid                  snel                eerder
# 9  arbeidsmarkt                altijd                immers
#
# [10 rows x 3 columns]
#
# JSD: 0.188930331281
#        topic_47 opinion_47_Opposition opinion_47_Government
# 0      argument            overtuigen            vervolgens
# 1      afweging              indienen              aannemen
# 2       bezwaar           principieel           principieel
# 3     standpunt              politiek           inhoudelijk
# 4    redenering              aannemen               bepalen
# 5   meerderheid           inhoudelijk                  toen
# 6  argumentatie               steunen                 voren
# 7     opvatting                  stem             overigens
# ...
#         topic_48 opinion_48_Opposition opinion_48_Government
# 0          ouder               regelen           registreren
# 1       huwelijk           registreren               regelen
# 2        notaris           gezamenlijk           gezamenlijk
# 3          gezag                   oud            burgerlijk
# 4        partner            burgerlijk              indienen
# 5      scheiding              scheiden                immers
# 6        relatie                gelijk              scheiden
# 7          vader        administratief        administratief
# 8        rechter             wettelijk                   oud
# 9  echtscheiding                huidig                huidig
#
# [10 rows x 3 columns]
#
# JSD: 0.168329141536
#             topic_6 opinion_6_Opposition opinion_6_Government
# 0            omroep              publiek              publiek
# 1         programma          commercieel            regionaal
# 2            bestel            regionaal          commercieel
# 3             media                  net               lokaal
# 4           bestuur               huidig              geleden
# 5  omroepvereniging               lokaal                  net
# 6           reclame            uitzenden              bepalen
# 7            zender           financieel               vooral
# 8         televisie               leggen             allemaal
# 9           publiek              regelen         verschillend
#
# [10 rows x 3 columns]
#
# JSD: 0.167389440857
#        topic_3 opinion_3_Opposition opinion_3_Government
# 0        straf             opleggen             opleggen
# 1  slachtoffer            strafbaar          veroordelen
# 2      rechter            verdenken            verdenken
# 3       delict               plegen            strafbaar
# 4     Justitie               leggen               leggen
# 5   strafrecht              ernstig      strafrechtelijk
# 6     misdrijf          veroordelen              ernstig
# 7    taakstraf      strafrechtelijk               plegen
# 8        dader                zwaar             openbaar
# 9      wetboek       voorwaardelijk            vervolgen
#
# [10 rows x 3 columns]
#
# JSD: 0.166921180194
#               topic_23 opinion_23_Opposition opinion_23_Government
# 0             Justitie             verdenken             verdenken
# 1          bevoegdheid              openbaar              openbaar
# 2              getuige         terroristisch             crimineel
# 3             officier             gebruiken             strafbaar
# 4           aanwijzing             strafbaar         terroristisch
# 5  rechter-commissaris               bepaald             deskundig
# 6             misdrijf                altijd             gebruiken
# 7           terrorisme                immers             voorkomen
# 8           ministerie       strafrechtelijk             voorlopig
# 9              persoon             voorkomen               bepaald
#
# [10 rows x 3 columns]
#
# JSD: 0.165582634171
#               topic_92 opinion_92_Opposition opinion_92_Government
# 0             grondwet              politiek       constitutioneel
# 1           verkiezing             bijzonder             bijzonder
# 2          meerderheid              openbaar      staatsrechtelijk
# 3               lezing       constitutioneel              openbaar
# 4          informateur                kiezen               regelen
# 5  samenwerkingsschool                  stem                  stem
# 6                 stem               regelen                kiezen
# 7            parlement          democratisch          democratisch
# 8             formatie                  toen          parlementair
# 9   grondwetswijziging                huidig              politiek
#
# [10 rows x 3 columns]
#
# JSD: 0.164575620748
#            topic_42 opinion_42_Opposition opinion_42_Government
# 0              auto                rijden                rijden
# 1               weg                 extra              openbaar
# 2           verkeer               betalen               betalen
# 3  kilometerheffing              openbaar                  snel
# 4              file                  snel                 extra
# 5           vervoer                 halen                altijd
# 6        mobiliteit              invoeren                  vaak
# 7                km                  duur                   weg
# 8        waterstaat                   weg              beginnen
# 9    infrastructuur             aanleggen                eerder
#
# [10 rows x 3 columns]
#
# JSD: 0.163499263878
#                  topic_73 opinion_73_Opposition opinion_73_Government
# 0               belasting               fiscaal               fiscaal
# 1           belastingplan               betalen               betalen
# 2                  tarief                  laag                  laag
# 3                 heffing              indienen     belastingplichtig
# 4  vennootschapsbelasting            budgettair            budgettair
# 5                vermogen              verlagen              belasten
# 6                    auto                 klein                vallen
# 7            vrijstelling              belasten                leiden
# 8               verlaging                 vorig                 klein
# 9                     box                immers              verlagen
#
# [10 rows x 3 columns]
#
# JSD: 0.160377368495
#        topic_7 opinion_7_Opposition opinion_7_Government
# 0      patiënt              dwingen       voorwaardelijk
# 1   inrichting            detineren        psychiatrisch
# 2           tb       voorwaardelijk            detineren
# 3          cel        psychiatrisch              dwingen
# 4   machtiging           behandelen              opnemen
# 5       opname           justitieel             plaatsen
# 6   gevangenis             plaatsen               eerder
# 7       gevaar              opnemen           behandelen
# 8   voorwaarde              ernstig              ernstig
# 9  samenleving              sluiten           justitieel
#
# [10 rows x 3 columns]
#
# JSD: 0.160247908163
#          topic_93 opinion_93_Opposition opinion_93_Government
# 0         alcohol                  jong                  jong
# 1       preventie                 roken                 roken
# 2      handhaving               drinken             handhaven
# 3        leeftijd             handhaven             verbieden
# 4  leeftijdsgrens               steunen               regelen
# 5           drank                 klein               drinken
# 6  zelfregulering             verbieden             voorkomen
# 7          horeca              indienen               richten
# 8         reclame              verkopen              indienen
# 9          verbod               richten               steunen
#
# [10 rows x 3 columns]
#
# JSD: 0.155758360927
#       topic_22 opinion_22_Opposition opinion_22_Government
# 0  mensenrecht        internationaal        internationaal
# 1       oorlog           buitenlands              politiek
# 2   terrorisme              militair           buitenlands
# 3    resolutie              politiek              militair
# 4        actie           amerikaanse           amerikaanse
# 5    bevolking            palestijns               aflopen
# 6       strijd               steunen               steunen
# 7       wereld             verenigen            humanitair
# 8        staat             betekenen            palestijns
# 9    president                bereid           islamitisch
#
# [10 rows x 3 columns]
#
# JSD: 0.154352623574
#        topic_98 opinion_98_Opposition opinion_98_Government
# 0          awbz           gehandicapt           gehandicapt
# 1        cliënt                   oud               regelen
# 2        budget                zorgen                   oud
# 3   begeleiding         huishoudelijk                 wonen
# 4           pgb            financieel                zorgen
# 5     thuiszorg                 wonen               leveren
# 6     indicatie               regelen           individueel
# 7          hulp                vallen                  vaak
# 8   voorziening      persoonsgebonden                vallen
# 9  mantelzorger                bieden                bieden
#
# [10 rows x 3 columns]
#
# JSD: 0.15038302854
#              topic_31 opinion_31_Opposition opinion_31_Government
# 0             student              studeren      wetenschappelijk
# 1           opleiding                 extra               regelen
# 2          instelling                 halen                 extra
# 3        universiteit                  snel               precies
# 4              studie               betalen              studeren
# 5  studiefinanciering                immers              beginnen
# 6         collegegeld      wetenschappelijk              indienen
# 7                 hbo              daarvoor                bieden
# 8           kwaliteit             betekenen                zorgen
# 9          hogeschool                altijd                  snel
#
# [10 rows x 3 columns]
#
# JSD: 0.143806850228
#        topic_44 opinion_44_Opposition opinion_44_Government
# 0    referendum                kiezen                kiezen
# 1  burgemeester           provinciaal              politiek
# 2  gemeenteraad              politiek                lokaal
# 3         staat                lokaal           provinciaal
# 4    democratie          democratisch          democratisch
# 5      grondwet                direct           bestuurlijk
# 6       bestuur           bestuurlijk                direct
# 7   bevoegdheid          gemeentelijk              openbaar
# 8     wethouder             tijdelijk          gemeentelijk
# 9       college            raadplegen                leggen
#
# [10 rows x 3 columns]
#
# JSD: 0.140781532274
#        topic_4 opinion_4_Opposition opinion_4_Government
# 0     defensie             militair             militair
# 1       missie       internationaal       internationaal
# 2     militair             inzetten         operationeel
# 3  krijgsmacht            betekenen             inzetten
# 4     operatie               civiel              aflopen
# 5        inzet             daarvoor             hierover
# 6            f                vorig               eerder
# 7    personeel              leveren                vorig
# 8         taak               eerder               altijd
# 9     veteraan               vallen               civiel
#
# [10 rows x 3 columns]
#
# JSD: 0.140145576079
#       topic_59 opinion_59_Opposition opinion_59_Government
# 0       woning                 wonen               sociaal
# 1      huurder                bouwen                 wonen
# 2   corporatie                  laag                  laag
# 3   verhuurder               sociaal                 kopen
# 4         wijk                 huren                bouwen
# 5         huur                 kopen                 huren
# 6      inkomen               betalen               betalen
# 7         huis            betaalbaar              maximaal
# 8   huurwoning              indienen              verkopen
# 9  woningmarkt                 extra                immers
#
# [10 rows x 3 columns]
#
# JSD: 0.138812368544
#         topic_26 opinion_26_Opposition opinion_26_Government
# 0      indiening             verzoeken             verzoeken
# 1     toezegging          ondersteunen          ondersteunen
# 2  beantwoording              indienen                danken
# 3         dictum            informeren              indienen
# 4        gesprek                danken             toezeggen
# 5       stemming             toezeggen            informeren
# 6        aanzien           onderzoeken                  blij
# 7  ondersteuning          schriftelijk          schriftelijk
# 8      resultaat                voorts              gisteren
# 9          zomer                tevens                voorts
#
# [10 rows x 3 columns]
#
# JSD: 0.138705182664
#               topic_38 opinion_38_Opposition opinion_38_Government
# 0          asielzoeker                 terug                 terug
# 1          vreemdeling             uitzetten              illegaal
# 2               opvang              illegaal            verblijven
# 3            terugkeer            verblijven           individueel
# 4  verblijfsvergunning             verzoeken                  snel
# 5            procedure                bieden            terugkeren
# 6             herkomst           individueel                vallen
# 7          vluchteling                zetten         uitprocederen
# 8             verblijf          ondersteunen             uitzetten
# 9               pardon         uitprocederen                altijd
#
# [10 rows x 3 columns]
#
# JSD: 0.135378766551
#        topic_84 opinion_84_Opposition opinion_84_Government
# 0   herindeling          gemeentelijk           bestuurlijk
# 1     draagvlak           bestuurlijk             betrekken
# 2     provincie             betrekken          gemeentelijk
# 3     bevolking                lokaal                 klein
# 4       bestuur                altijd                altijd
# 5      argument           provinciaal                 sterk
# 6       inwoner                 klein                kiezen
# 7  samenvoeging            financieel               vandaag
# 8  samenwerking               vandaag               steunen
# 9         staat                 sterk              ontstaan
#
# [10 rows x 3 columns]
#
# JSD: 0.131739532806
#             topic_62 opinion_62_Opposition opinion_62_Government
# 0                mln                 extra                 extra
# 1               euro            economisch            economisch
# 2             gulden            financieel           structureel
# 3          begroting           structureel            financieel
# 4             bedrag              politiek                 vorig
# 5  lastenverlichting                  laag             overigens
# 6              groei               sociaal                  toen
# 7             tekort               aflopen                 zelfs
# 8           economie                 vorig               aflopen
# 9            uitgaaf                 terug            verwachten
#
# [10 rows x 3 columns]
#
# JSD: 0.118476611085
#     topic_53 opinion_53_Opposition opinion_53_Government
# 0   leerling                 leren           voortzetten
# 1     leraar                 extra                 leren
# 2     docent           voortzetten                 extra
# 3  kwaliteit                passen                bieden
# 4        vak                 halen                 halen
# 5       klas              speciaal              daarvoor
# 6       taal                  vaak                leggen
# 7        mbo                altijd                  snel
# 8  inspectie                zorgen               precies
# 9     niveau              daarvoor               primair
#
# [10 rows x 3 columns]
#
# JSD: 0.115595387891
#          topic_32 opinion_32_Opposition opinion_32_Government
# 0         verdrag             nationaal             nationaal
# 1            unie              politiek              politiek
# 2        lidstaat          democratisch        internationaal
# 3       parlement             betekenen           buitenlands
# 4     uitbreiding           buitenlands             betekenen
# 5      referendum                eerder     gemeenschappelijk
# 6    samenwerking              daarvoor          democratisch
# 7      toetreding                vooral                waarop
# 8             top                 zelfs                ervoor
# 9  onderhandeling                 vorig               voldoen
#
# [10 rows x 3 columns]
#
# JSD: 0.0952746159028
#                topic_11 opinion_11_Opposition opinion_11_Government
# 0               verzoek               steunen               steunen
# 1            spoeddebat             verzoeken             verzoeken
# 2              stemming                  snel                 eerst
# 3                agenda             ontvangen               sluiten
# 4                   uur              hierover             ontvangen
# 5               uitstel                 vorig                 vorig
# 6              behoefte               vandaag              hierover
# 7               bericht               plenair               plenair
# 8  procedurevergadering                morgen                  snel
# 9                 reces                sturen                morgen
#
# [10 rows x 3 columns]
