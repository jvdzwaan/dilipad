# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.rcParams['figure.figsize'] = (5, 5)

# %%
config = {
    "inputData": "/path/to/input/data/*",
    "outDir": "/home/jvdzwaan/data/dilipad/results/all_years-adj-cabinets_selected-parties/{}",
    "nTopics": 100
}

data = pd.read_csv(config.get('outDir').format('topics_100_data.csv'), index_col=0, encoding='utf-8')
print data.columns
#data
# Out:
# Index([u'words', u'usefulness_A', u'usefulness_B', u'usefulness_C', u'cap',
#        u'C_A', u'C_P', u'C_V', u'NPMI', u'UCI', u'UMass', u'mean_usefulness',
#        u'usefulness', u'cap_svm'],
#       dtype='object')

# %%
data.hist('C_A')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff8d14224d0>]], dtype=object)

# %%
fig, ax = plt.subplots()
data.plot('mean_usefulness', 'C_A', kind='scatter', ax=ax)

# %%
data.hist('NPMI')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff8d14bd490>]], dtype=object)

# %%
fig, ax = plt.subplots()
data.plot('mean_usefulness', 'NPMI', kind='scatter', ax=ax)

# %%
# select high quality topics
hq_topics = data[data['NPMI'] > data['NPMI'].mean()]
print len(hq_topics)
hq_topics.to_csv(config.get('outDir').format('hq_topics_npmi_100.csv'), encoding='utf-8')
# Out:
# 48

# %%
hq_topics = data[data['usefulness'] == 3.0]
print len(hq_topics)
hq_topics.to_csv(config.get('outDir').format('hq_topics_usefulness==3_100.csv'), encoding='utf-8')
# Out:
# 54
